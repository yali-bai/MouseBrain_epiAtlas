# %%
# "indir" is a custom input path, and "outdir" is a custom output path.
# indir=""
# outdir=""

# %%
dirs <- c(
  paste0(indir,"/01_hmCH_open_peak/"),
  paste0(indir,"/01_hmCH_close_peak/"),
  paste0(indir,"/01_mCH_close_peak/"),
  paste0(indir,"/01_mCH_open_peak/")
)

dirs
# Out:
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak/"
# [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak/"
# [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak/"
# [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak/"

# %%
result <- data.frame(
  subclass = character(),
  mean_diff = numeric(),
  modification = character(),
  statement = character(),
  stringsAsFactors = FALSE
)

# %%
result
# Out:
#      subclass mean_diff modification statement

# %%
basename(paste0(indir,"/01_hmCH_open_peak/"))
# Out:
# [1] "01_hmCH_open_peak"

# %%
for (dir in dirs) {
  dir_name <- basename(dir)
  modification <- sub("01_(.*)_(open|close)_peak", "\\1", dir_name)
  statement <- sub("01_(.*)_(open|close)_peak", "\\2", dir_name)
#   modification_clean <- gsub("H", "", modification)
  
  files <- list.files(dir, pattern = "\\.tmp$", full.names = TRUE)
  subclasses <- unique(sub("_(old|young)_(5hmCH|5mCH)\\.mm10\\.tmp$", "", basename(files)))
  
  for (subclass in subclasses) {
    old_file <- file.path(dir, paste0(subclass, "_old_5", modification, ".mm10.tmp"))
    young_file <- file.path(dir, paste0(subclass, "_young_5", modification, ".mm10.tmp"))
    
    if (!file.exists(old_file) || !file.exists(young_file)) {
      cat("Skipping missing files for subclass:", subclass, "\n")
      next
    }
    
    old_data <- read.table(old_file, header = TRUE, sep = "\t", stringsAsFactors = FALSE)
    young_data <- read.table(young_file, header = TRUE, sep = "\t", stringsAsFactors = FALSE)

    old_data_filtered <- old_data[!is.na(old_data[, 2]), ]
    young_data_filtered <- young_data[!is.na(young_data[, 2]), ]
    common_ids <- intersect(old_data_filtered[, 1], young_data_filtered[, 1])
    old_data_final <- old_data_filtered[old_data_filtered[, 1] %in% common_ids, ]
    young_data_final <- young_data_filtered[young_data_filtered[, 1] %in% common_ids, ]
    old_data_final <- old_data_final[match(common_ids, old_data_final[, 1]), ]
    young_data_final <- young_data_final[match(common_ids, young_data_final[, 1]), ]
    
    if (!identical(old_data_final$peak, young_data_final$peak)) {
      stop(paste("The peak columns in", old_file, "and", young_file, "do not match."))
    }
    
    mean_diff <- mean(old_data_final$Mean_ratio - young_data_final$Mean_ratio)
    result <- rbind(result, data.frame(
      subclass = subclass,
      mean_diff = mean_diff,
      modification = modification,
      statement = statement
    ))
  }
}

# %%
result
# Out:
#     subclass              mean_diff     modification statement
# 1   ACB-BST-FS.D1.Gaba     2.350797e-04 hmCH         open
# 2   Astro-TE.NN           -1.075859e-04 hmCH         open
# 3   CA1-ProS.Glut          3.701380e-04 hmCH         open
# 4   CA3.Glut               3.507117e-04 hmCH         open
# 5   CLA-EPd-CTX.Car3.Glut  7.611426e-04 hmCH         open
# 6   DG.Glut               -2.040388e-04 hmCH         open
# 7   IT.AON-TT-DP.Glut      1.466493e-04 hmCH         open
# 8   L2.3.IT.CTX.Glut       3.638056e-04 hmCH         open
# 9   L2.3.IT.RSP.Glut       1.557721e-04 hmCH         open
# 10  L4.5.IT.CTX.Glut       2.149471e-04 hmCH         open
# 11  L5.ET.CTX.Glut         4.817440e-04 hmCH         open
# 12  L5.IT.CTX.Glut         6.622708e-04 hmCH         open
# 13  L5.NP.CTX.Glut         7.382534e-05 hmCH         open
# 14  L6.CT.CTX.Glut         5.346198e-04 hmCH         open
# 15  Lamp5.Gaba             1.830057e-04 hmCH         open
# 16  Microglia.NN          -1.745517e-04 hmCH         open
# 17  OB-in.Frmd7.Gaba      -1.035783e-04 hmCH         open
# 18  OB-out.Frmd7.Gaba     -3.159195e-04 hmCH         open
# 19  OB.Eomes.Ms4a15.Glut   2.529653e-05 hmCH         open
# 20  OEC.NN                -1.947232e-04 hmCH         open
# 21  Oligo.NN               1.219840e-04 hmCH         open
# 22  OPC.NN                -2.812211e-04 hmCH         open
# 23  Pvalb.Gaba             1.322983e-04 hmCH         open
# 24  Sncg.Gaba              2.085192e-04 hmCH         open
# 25  STR.D1.Gaba            1.274126e-04 hmCH         open
# 26  STR.D1.Sema5a.Gaba     1.384113e-04 hmCH         open
# 27  STR.D2.Gaba            3.205528e-04 hmCH         open
# 28  ACB-BST-FS.D1.Gaba    -6.533498e-04 hmCH         close
# 29  Astro-TE.NN           -5.306247e-04 hmCH         close
# 30  CA1-ProS.Glut         -6.244352e-04 hmCH         close
# ⋮   ⋮                     ⋮             ⋮            ⋮
# 79  STR.D1.Gaba            3.434058e-05 mCH          close
# 80  STR.D1.Sema5a.Gaba    -7.254301e-04 mCH          close
# 81  STR.D2.Gaba           -1.697081e-04 mCH          close
# 82  ACB-BST-FS.D1.Gaba     1.144046e-03 mCH          open
# 83  Astro-TE.NN            6.844956e-05 mCH          open
# 84  CA1-ProS.Glut          2.082941e-03 mCH          open
# 85  CA3.Glut               6.246425e-04 mCH          open
# 86  CLA-EPd-CTX.Car3.Glut  1.411799e-03 mCH          open
# 87  DG.Glut               -3.771253e-04 mCH          open
# 88  IT.AON-TT-DP.Glut     -7.431683e-04 mCH          open
# 89  L2.3.IT.CTX.Glut       8.166545e-04 mCH          open
# 90  L2.3.IT.RSP.Glut       2.582197e-04 mCH          open
# 91  L4.5.IT.CTX.Glut       1.165128e-03 mCH          open
# 92  L5.ET.CTX.Glut         1.032680e-03 mCH          open
# 93  L5.IT.CTX.Glut         1.275514e-03 mCH          open
# 94  L5.NP.CTX.Glut         1.009681e-03 mCH          open
# 95  L6.CT.CTX.Glut         4.984139e-04 mCH          open
# 96  Lamp5.Gaba             7.278897e-05 mCH          open
# 97  Microglia.NN           7.812502e-04 mCH          open
# 98  OB-in.Frmd7.Gaba       1.404809e-03 mCH          open
# 99  OB-out.Frmd7.Gaba      6.686378e-04 mCH          open
# 100 OB.Eomes.Ms4a15.Glut   1.082453e-03 mCH          open
# 101 OEC.NN                -3.621106e-04 mCH          open
# 102 Oligo.NN               9.564434e-04 mCH          open
# 103 OPC.NN                -4.699654e-04 mCH          open
# 104 Pvalb.Gaba             7.691633e-05 mCH          open
# 105 Sncg.Gaba              2.139762e-03 mCH          open
# 106 STR.D1.Gaba            3.517515e-04 mCH          open
# 107 STR.D1.Sema5a.Gaba     1.463139e-03 mCH          open
# 108 STR.D2.Gaba            1.573412e-03 mCH          open

# %%
library(ggplot2)
library(dplyr)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.2”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
unique(result$subclass)
# Out:
#  [1] "ACB-BST-FS.D1.Gaba"    "Astro-TE.NN"           "CA1-ProS.Glut"
#  [4] "CA3.Glut"              "CLA-EPd-CTX.Car3.Glut" "DG.Glut"
#  [7] "IT.AON-TT-DP.Glut"     "L2.3.IT.CTX.Glut"      "L2.3.IT.RSP.Glut"
# [10] "L4.5.IT.CTX.Glut"      "L5.ET.CTX.Glut"        "L5.IT.CTX.Glut"
# [13] "L5.NP.CTX.Glut"        "L6.CT.CTX.Glut"        "Lamp5.Gaba"
# [16] "Microglia.NN"          "OB-in.Frmd7.Gaba"      "OB-out.Frmd7.Gaba"
# [19] "OB.Eomes.Ms4a15.Glut"  "OEC.NN"                "Oligo.NN"
# [22] "OPC.NN"                "Pvalb.Gaba"            "Sncg.Gaba"
# [25] "STR.D1.Gaba"           "STR.D1.Sema5a.Gaba"    "STR.D2.Gaba"

# %%
c('ACB-BST-FS D1 Gaba','Astro-TE NN','CA1-ProS Glut','CA3 Glut','CLA-EPd-CTX Car3 Glut','DG Glut','IT AON-TT-DP Glut','L2/3 IT CTX Glut',
 'L2/3 IT RSP Glut','L4/5 IT CTX Glut','L5 ET CTX Glut','L5 IT CTX Glut','L5 NP CTX Glut','L6 CT CTX Glut','Lamp5 Gaba','Microglia NN',
 'OB-in Frmd7 Gaba','OB-out Frmd7 Gaba','OB Eomes Ms4a15 Glut','OEC NN','Oligo NN','OPC NN','Pvalb Gaba',
 'Sncg Gaba','STR D1 Gaba','STR D1 Sema5a Gaba','STR D2 Gaba')

# %%
subclass_info <- data.frame(subclass_v1=unique(result$subclass),
                           subclass_v2=c('ACB-BST-FS D1 Gaba','Astro-TE NN','CA1-ProS Glut','CA3 Glut','CLA-EPd-CTX Car3 Glut','DG Glut','IT AON-TT-DP Glut','L2/3 IT CTX Glut',
 'L2/3 IT RSP Glut','L4/5 IT CTX Glut','L5 ET CTX Glut','L5 IT CTX Glut','L5 NP CTX Glut','L6 CT CTX Glut','Lamp5 Gaba','Microglia NN',
 'OB-in Frmd7 Gaba','OB-out Frmd7 Gaba','OB Eomes Ms4a15 Glut','OEC NN','Oligo NN','OPC NN','Pvalb Gaba',
 'Sncg Gaba','STR D1 Gaba','STR D1 Sema5a Gaba','STR D2 Gaba'))

# %%
subclass_info
# Out:
#    subclass_v1           subclass_v2
# 1  ACB-BST-FS.D1.Gaba    ACB-BST-FS D1 Gaba
# 2  Astro-TE.NN           Astro-TE NN
# 3  CA1-ProS.Glut         CA1-ProS Glut
# 4  CA3.Glut              CA3 Glut
# 5  CLA-EPd-CTX.Car3.Glut CLA-EPd-CTX Car3 Glut
# 6  DG.Glut               DG Glut
# 7  IT.AON-TT-DP.Glut     IT AON-TT-DP Glut
# 8  L2.3.IT.CTX.Glut      L2/3 IT CTX Glut
# 9  L2.3.IT.RSP.Glut      L2/3 IT RSP Glut
# 10 L4.5.IT.CTX.Glut      L4/5 IT CTX Glut
# 11 L5.ET.CTX.Glut        L5 ET CTX Glut
# 12 L5.IT.CTX.Glut        L5 IT CTX Glut
# 13 L5.NP.CTX.Glut        L5 NP CTX Glut
# 14 L6.CT.CTX.Glut        L6 CT CTX Glut
# 15 Lamp5.Gaba            Lamp5 Gaba
# 16 Microglia.NN          Microglia NN
# 17 OB-in.Frmd7.Gaba      OB-in Frmd7 Gaba
# 18 OB-out.Frmd7.Gaba     OB-out Frmd7 Gaba
# 19 OB.Eomes.Ms4a15.Glut  OB Eomes Ms4a15 Glut
# 20 OEC.NN                OEC NN
# 21 Oligo.NN              Oligo NN
# 22 OPC.NN                OPC NN
# 23 Pvalb.Gaba            Pvalb Gaba
# 24 Sncg.Gaba             Sncg Gaba
# 25 STR.D1.Gaba           STR D1 Gaba
# 26 STR.D1.Sema5a.Gaba    STR D1 Sema5a Gaba
# 27 STR.D2.Gaba           STR D2 Gaba

# %%
result$subclass <- subclass_info$subclass_v2[match(result$subclass,subclass_info$subclass_v1)]

# %%
result
# Out:
#     subclass              mean_diff     modification statement
# 1   ACB-BST-FS D1 Gaba     2.350797e-04 hmCH         open
# 2   Astro-TE NN           -1.075859e-04 hmCH         open
# 3   CA1-ProS Glut          3.701380e-04 hmCH         open
# 4   CA3 Glut               3.507117e-04 hmCH         open
# 5   CLA-EPd-CTX Car3 Glut  7.611426e-04 hmCH         open
# 6   DG Glut               -2.040388e-04 hmCH         open
# 7   IT AON-TT-DP Glut      1.466493e-04 hmCH         open
# 8   L2/3 IT CTX Glut       3.638056e-04 hmCH         open
# 9   L2/3 IT RSP Glut       1.557721e-04 hmCH         open
# 10  L4/5 IT CTX Glut       2.149471e-04 hmCH         open
# 11  L5 ET CTX Glut         4.817440e-04 hmCH         open
# 12  L5 IT CTX Glut         6.622708e-04 hmCH         open
# 13  L5 NP CTX Glut         7.382534e-05 hmCH         open
# 14  L6 CT CTX Glut         5.346198e-04 hmCH         open
# 15  Lamp5 Gaba             1.830057e-04 hmCH         open
# 16  Microglia NN          -1.745517e-04 hmCH         open
# 17  OB-in Frmd7 Gaba      -1.035783e-04 hmCH         open
# 18  OB-out Frmd7 Gaba     -3.159195e-04 hmCH         open
# 19  OB Eomes Ms4a15 Glut   2.529653e-05 hmCH         open
# 20  OEC NN                -1.947232e-04 hmCH         open
# 21  Oligo NN               1.219840e-04 hmCH         open
# 22  OPC NN                -2.812211e-04 hmCH         open
# 23  Pvalb Gaba             1.322983e-04 hmCH         open
# 24  Sncg Gaba              2.085192e-04 hmCH         open
# 25  STR D1 Gaba            1.274126e-04 hmCH         open
# 26  STR D1 Sema5a Gaba     1.384113e-04 hmCH         open
# 27  STR D2 Gaba            3.205528e-04 hmCH         open
# 28  ACB-BST-FS D1 Gaba    -6.533498e-04 hmCH         close
# 29  Astro-TE NN           -5.306247e-04 hmCH         close
# 30  CA1-ProS Glut         -6.244352e-04 hmCH         close
# ⋮   ⋮                     ⋮             ⋮            ⋮
# 79  STR D1 Gaba            3.434058e-05 mCH          close
# 80  STR D1 Sema5a Gaba    -7.254301e-04 mCH          close
# 81  STR D2 Gaba           -1.697081e-04 mCH          close
# 82  ACB-BST-FS D1 Gaba     1.144046e-03 mCH          open
# 83  Astro-TE NN            6.844956e-05 mCH          open
# 84  CA1-ProS Glut          2.082941e-03 mCH          open
# 85  CA3 Glut               6.246425e-04 mCH          open
# 86  CLA-EPd-CTX Car3 Glut  1.411799e-03 mCH          open
# 87  DG Glut               -3.771253e-04 mCH          open
# 88  IT AON-TT-DP Glut     -7.431683e-04 mCH          open
# 89  L2/3 IT CTX Glut       8.166545e-04 mCH          open
# 90  L2/3 IT RSP Glut       2.582197e-04 mCH          open
# 91  L4/5 IT CTX Glut       1.165128e-03 mCH          open
# 92  L5 ET CTX Glut         1.032680e-03 mCH          open
# 93  L5 IT CTX Glut         1.275514e-03 mCH          open
# 94  L5 NP CTX Glut         1.009681e-03 mCH          open
# 95  L6 CT CTX Glut         4.984139e-04 mCH          open
# 96  Lamp5 Gaba             7.278897e-05 mCH          open
# 97  Microglia NN           7.812502e-04 mCH          open
# 98  OB-in Frmd7 Gaba       1.404809e-03 mCH          open
# 99  OB-out Frmd7 Gaba      6.686378e-04 mCH          open
# 100 OB Eomes Ms4a15 Glut   1.082453e-03 mCH          open
# 101 OEC NN                -3.621106e-04 mCH          open
# 102 Oligo NN               9.564434e-04 mCH          open
# 103 OPC NN                -4.699654e-04 mCH          open
# 104 Pvalb Gaba             7.691633e-05 mCH          open
# 105 Sncg Gaba              2.139762e-03 mCH          open
# 106 STR D1 Gaba            3.517515e-04 mCH          open
# 107 STR D1 Sema5a Gaba     1.463139e-03 mCH          open
# 108 STR D2 Gaba            1.573412e-03 mCH          open

# %%
subclass_order <- unlist(strsplit("L2/3 IT CTX Glut
L4/5 IT CTX Glut
L5 IT CTX Glut
IT AON-TT-DP Glut
L2/3 IT RSP Glut
L5 ET CTX Glut
CA1-ProS Glut
CA3 Glut
CLA-EPd-CTX Car3 Glut
L5 NP CTX Glut
L6 CT CTX Glut
DG Glut
OB Eomes Ms4a15 Glut
OB-in Frmd7 Gaba
OB-out Frmd7 Gaba
Sncg Gaba
Lamp5 Gaba
Pvalb Gaba
STR D1 Gaba
STR D2 Gaba
STR D1 Sema5a Gaba
ACB-BST-FS D1 Gaba
Astro-TE NN
Oligo NN
OPC NN
OEC NN
Microglia NN","\n"))

subclass_order
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"                "Microglia NN"

# %%
table(result$subclass %in% subclass_order)
# Out:
# TRUE
#  108

# %%
levels(result$subclass)
# Out:
# NULL

# %%
result$subclass <- factor(result$subclass,levels = subclass_order)

# %%
levels(result$subclass)
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"                "Microglia NN"

# %%
levels(result$statement)
# Out:
# NULL

# %%
result$statement <- factor(result$statement,levels = c("open","close"))

# %%
levels(result$statement)
# Out:
# [1] "open"  "close"

# %%
hmCH_data <- subset(result, modification == "hmCH")

# %%
hmCH_data
# Out:
#    subclass              mean_diff     modification statement
# 1  ACB-BST-FS D1 Gaba     2.350797e-04 hmCH         open
# 2  Astro-TE NN           -1.075859e-04 hmCH         open
# 3  CA1-ProS Glut          3.701380e-04 hmCH         open
# 4  CA3 Glut               3.507117e-04 hmCH         open
# 5  CLA-EPd-CTX Car3 Glut  7.611426e-04 hmCH         open
# 6  DG Glut               -2.040388e-04 hmCH         open
# 7  IT AON-TT-DP Glut      1.466493e-04 hmCH         open
# 8  L2/3 IT CTX Glut       3.638056e-04 hmCH         open
# 9  L2/3 IT RSP Glut       1.557721e-04 hmCH         open
# 10 L4/5 IT CTX Glut       2.149471e-04 hmCH         open
# 11 L5 ET CTX Glut         4.817440e-04 hmCH         open
# 12 L5 IT CTX Glut         6.622708e-04 hmCH         open
# 13 L5 NP CTX Glut         7.382534e-05 hmCH         open
# 14 L6 CT CTX Glut         5.346198e-04 hmCH         open
# 15 Lamp5 Gaba             1.830057e-04 hmCH         open
# 16 Microglia NN          -1.745517e-04 hmCH         open
# 17 OB-in Frmd7 Gaba      -1.035783e-04 hmCH         open
# 18 OB-out Frmd7 Gaba     -3.159195e-04 hmCH         open
# 19 OB Eomes Ms4a15 Glut   2.529653e-05 hmCH         open
# 20 OEC NN                -1.947232e-04 hmCH         open
# 21 Oligo NN               1.219840e-04 hmCH         open
# 22 OPC NN                -2.812211e-04 hmCH         open
# 23 Pvalb Gaba             1.322983e-04 hmCH         open
# 24 Sncg Gaba              2.085192e-04 hmCH         open
# 25 STR D1 Gaba            1.274126e-04 hmCH         open
# 26 STR D1 Sema5a Gaba     1.384113e-04 hmCH         open
# 27 STR D2 Gaba            3.205528e-04 hmCH         open
# 28 ACB-BST-FS D1 Gaba    -6.533498e-04 hmCH         close
# 29 Astro-TE NN           -5.306247e-04 hmCH         close
# 30 CA1-ProS Glut         -6.244352e-04 hmCH         close
# 31 CA3 Glut              -3.241098e-04 hmCH         close
# 32 CLA-EPd-CTX Car3 Glut -9.306024e-04 hmCH         close
# 33 DG Glut               -6.621183e-04 hmCH         close
# 34 IT AON-TT-DP Glut     -1.496198e-03 hmCH         close
# 35 L2/3 IT CTX Glut      -6.794747e-04 hmCH         close
# 36 L2/3 IT RSP Glut      -6.220277e-04 hmCH         close
# 37 L4/5 IT CTX Glut       1.313786e-04 hmCH         close
# 38 L5 ET CTX Glut        -6.352458e-04 hmCH         close
# 39 L5 IT CTX Glut         3.585836e-05 hmCH         close
# 40 L5 NP CTX Glut        -9.148342e-04 hmCH         close
# 41 L6 CT CTX Glut        -5.711743e-04 hmCH         close
# 42 Lamp5 Gaba            -4.250057e-04 hmCH         close
# 43 Microglia NN          -5.925771e-04 hmCH         close
# 44 OB-in Frmd7 Gaba      -9.373673e-04 hmCH         close
# 45 OB-out Frmd7 Gaba     -5.395622e-04 hmCH         close
# 46 OB Eomes Ms4a15 Glut  -8.931591e-04 hmCH         close
# 47 OEC NN                -6.132334e-04 hmCH         close
# 48 Oligo NN              -3.321005e-04 hmCH         close
# 49 OPC NN                -3.680276e-04 hmCH         close
# 50 Pvalb Gaba            -4.326590e-04 hmCH         close
# 51 Sncg Gaba             -5.799238e-04 hmCH         close
# 52 STR D1 Gaba           -6.203570e-04 hmCH         close
# 53 STR D1 Sema5a Gaba    -1.812819e-03 hmCH         close
# 54 STR D2 Gaba           -2.529552e-04 hmCH         close

# %%
# options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
# ggplot(hmCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
#   geom_bar(stat = "identity", position = position_dodge()) + 
#   labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH") +
#   theme_minimal(base_size = 18) +
#   theme(
#     panel.grid = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1.2),
#     axis.text = element_text(color = "black"),
#     axis.text.x = element_text(angle = 45, hjust = 1),
#     axis.title = element_text(face = "bold"),
#     plot.title = element_text(hjust = 0.5, face = "bold")
#   ) +
#   scale_fill_manual(values = c("open" = "#D7272A", "close" = "#2077B5"))
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
ggplot(hmCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# plot without title

# %%
p1 <- ggplot(hmCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))

# %%
mCH_data <- subset(result, modification == "mCH")

# %%
mCH_data
# Out:
#     subclass              mean_diff     modification statement
# 55  ACB-BST-FS D1 Gaba    -3.908244e-04 mCH          close
# 56  Astro-TE NN            2.973198e-05 mCH          close
# 57  CA1-ProS Glut         -7.828405e-04 mCH          close
# 58  CA3 Glut               3.831804e-04 mCH          close
# 59  CLA-EPd-CTX Car3 Glut -4.240454e-04 mCH          close
# 60  DG Glut               -5.161877e-04 mCH          close
# 61  IT AON-TT-DP Glut     -7.341732e-04 mCH          close
# 62  L2/3 IT CTX Glut      -4.489731e-04 mCH          close
# 63  L2/3 IT RSP Glut      -8.169216e-04 mCH          close
# 64  L4/5 IT CTX Glut       1.689741e-03 mCH          close
# 65  L5 ET CTX Glut        -2.753165e-04 mCH          close
# 66  L5 IT CTX Glut         8.291220e-04 mCH          close
# 67  L5 NP CTX Glut        -6.921888e-04 mCH          close
# 68  L6 CT CTX Glut        -3.829088e-04 mCH          close
# 69  Lamp5 Gaba            -1.987526e-04 mCH          close
# 70  Microglia NN          -5.377836e-04 mCH          close
# 71  OB-in Frmd7 Gaba      -2.654793e-04 mCH          close
# 72  OB-out Frmd7 Gaba     -4.759158e-05 mCH          close
# 73  OB Eomes Ms4a15 Glut  -2.575447e-04 mCH          close
# 74  OEC NN                -4.899603e-04 mCH          close
# 75  Oligo NN               3.038393e-04 mCH          close
# 76  OPC NN                -4.132993e-04 mCH          close
# 77  Pvalb Gaba             6.752612e-04 mCH          close
# 78  Sncg Gaba             -1.884882e-04 mCH          close
# 79  STR D1 Gaba            3.434058e-05 mCH          close
# 80  STR D1 Sema5a Gaba    -7.254301e-04 mCH          close
# 81  STR D2 Gaba           -1.697081e-04 mCH          close
# 82  ACB-BST-FS D1 Gaba     1.144046e-03 mCH          open
# 83  Astro-TE NN            6.844956e-05 mCH          open
# 84  CA1-ProS Glut          2.082941e-03 mCH          open
# 85  CA3 Glut               6.246425e-04 mCH          open
# 86  CLA-EPd-CTX Car3 Glut  1.411799e-03 mCH          open
# 87  DG Glut               -3.771253e-04 mCH          open
# 88  IT AON-TT-DP Glut     -7.431683e-04 mCH          open
# 89  L2/3 IT CTX Glut       8.166545e-04 mCH          open
# 90  L2/3 IT RSP Glut       2.582197e-04 mCH          open
# 91  L4/5 IT CTX Glut       1.165128e-03 mCH          open
# 92  L5 ET CTX Glut         1.032680e-03 mCH          open
# 93  L5 IT CTX Glut         1.275514e-03 mCH          open
# 94  L5 NP CTX Glut         1.009681e-03 mCH          open
# 95  L6 CT CTX Glut         4.984139e-04 mCH          open
# 96  Lamp5 Gaba             7.278897e-05 mCH          open
# 97  Microglia NN           7.812502e-04 mCH          open
# 98  OB-in Frmd7 Gaba       1.404809e-03 mCH          open
# 99  OB-out Frmd7 Gaba      6.686378e-04 mCH          open
# 100 OB Eomes Ms4a15 Glut   1.082453e-03 mCH          open
# 101 OEC NN                -3.621106e-04 mCH          open
# 102 Oligo NN               9.564434e-04 mCH          open
# 103 OPC NN                -4.699654e-04 mCH          open
# 104 Pvalb Gaba             7.691633e-05 mCH          open
# 105 Sncg Gaba              2.139762e-03 mCH          open
# 106 STR D1 Gaba            3.517515e-04 mCH          open
# 107 STR D1 Sema5a Gaba     1.463139e-03 mCH          open
# 108 STR D2 Gaba            1.573412e-03 mCH          open

# %%
levels(mCH_data$statement)
# Out:
# [1] "open"  "close"

# %%
# options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
# ggplot(mCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
#   geom_bar(stat = "identity", position = position_dodge()) + 
#   labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH+5mCH") +
#   theme_minimal(base_size = 18) +
#   theme(
#     panel.grid = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1.2),
#     axis.text = element_text(color = "black"),
#     axis.text.x = element_text(angle = 45, hjust = 1),
#     axis.title = element_text(face = "bold"),
#     plot.title = element_text(hjust = 0.5, face = "bold")
#   ) +
#   scale_fill_manual(values = c("open" = "#D7272A", "close" = "#2077B5"))
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
ggplot(mCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH+5mCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))
# Out:
# plot without title

# %%
p2 <- ggplot(mCH_data, aes(x = subclass, y = mean_diff, fill = statement)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5hmCH+5mCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))

# %%
library(dplyr)

# %%
dir_mCH_open <- paste0(indir,"/01_mCH_open_peak/")
dir_hmCH_open <- paste0(indir,"/01_hmCH_open_peak/")
dir_mCH_close <- paste0(indir,"/01_mCH_close_peak/")
dir_hmCH_close <- paste0(indir,"/01_hmCH_close_peak/")

# %%
files_mCH_open <- list.files(dir_mCH_open, pattern = "5mCH\\.mm10\\.tmp$", full.names = TRUE)
files_hmCH_open <- list.files(dir_hmCH_open, pattern = "5hmCH\\.mm10\\.tmp$", full.names = TRUE)
files_mCH_close <- list.files(dir_mCH_close, pattern = "5mCH\\.mm10\\.tmp$", full.names = TRUE)
files_hmCH_close <- list.files(dir_hmCH_close, pattern = "5hmCH\\.mm10\\.tmp$", full.names = TRUE)

# %%
files_mCH_open;files_hmCH_open;files_mCH_close;files_hmCH_close
# Out:
#  [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//ACB-BST-FS.D1.Gaba_old_5mCH.mm10.tmp"
#  [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//ACB-BST-FS.D1.Gaba_young_5mCH.mm10.tmp"
#  [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Astro-TE.NN_old_5mCH.mm10.tmp"
#  [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Astro-TE.NN_young_5mCH.mm10.tmp"
#  [5] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CA1-ProS.Glut_old_5mCH.mm10.tmp"
#  [6] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CA1-ProS.Glut_young_5mCH.mm10.tmp"
#  [7] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CA3.Glut_old_5mCH.mm10.tmp"
#  [8] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CA3.Glut_young_5mCH.mm10.tmp"
#  [9] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CLA-EPd-CTX.Car3.Glut_old_5mCH.mm10.tmp"
# [10] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//CLA-EPd-CTX.Car3.Glut_young_5mCH.mm10.tmp"
# [11] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//DG.Glut_old_5mCH.mm10.tmp"
# [12] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//DG.Glut_young_5mCH.mm10.tmp"
# [13] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//IT.AON-TT-DP.Glut_old_5mCH.mm10.tmp"
# [14] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//IT.AON-TT-DP.Glut_young_5mCH.mm10.tmp"
# [15] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L2.3.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [16] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L2.3.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [17] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L2.3.IT.RSP.Glut_old_5mCH.mm10.tmp"
# [18] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L2.3.IT.RSP.Glut_young_5mCH.mm10.tmp"
# [19] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L4.5.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [20] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L4.5.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [21] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.ET.CTX.Glut_old_5mCH.mm10.tmp"
# [22] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.ET.CTX.Glut_young_5mCH.mm10.tmp"
# [23] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [24] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [25] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.NP.CTX.Glut_old_5mCH.mm10.tmp"
# [26] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L5.NP.CTX.Glut_young_5mCH.mm10.tmp"
# [27] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L6.CT.CTX.Glut_old_5mCH.mm10.tmp"
# [28] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//L6.CT.CTX.Glut_young_5mCH.mm10.tmp"
# [29] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Lamp5.Gaba_old_5mCH.mm10.tmp"
# [30] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Lamp5.Gaba_young_5mCH.mm10.tmp"
# [31] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Microglia.NN_old_5mCH.mm10.tmp"
# [32] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Microglia.NN_young_5mCH.mm10.tmp"
# [33] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB-in.Frmd7.Gaba_old_5mCH.mm10.tmp"
# [34] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB-in.Frmd7.Gaba_young_5mCH.mm10.tmp"
# [35] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB-out.Frmd7.Gaba_old_5mCH.mm10.tmp"
# [36] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB-out.Frmd7.Gaba_young_5mCH.mm10.tmp"
# [37] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB.Eomes.Ms4a15.Glut_old_5mCH.mm10.tmp"
# [38] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OB.Eomes.Ms4a15.Glut_young_5mCH.mm10.tmp"
# [39] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OEC.NN_old_5mCH.mm10.tmp"
# [40] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OEC.NN_young_5mCH.mm10.tmp"
# [41] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Oligo.NN_old_5mCH.mm10.tmp"
# [42] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Oligo.NN_young_5mCH.mm10.tmp"
# [43] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OPC.NN_old_5mCH.mm10.tmp"
# [44] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//OPC.NN_young_5mCH.mm10.tmp"
# [45] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Pvalb.Gaba_old_5mCH.mm10.tmp"
# [46] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Pvalb.Gaba_young_5mCH.mm10.tmp"
# [47] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Sncg.Gaba_old_5mCH.mm10.tmp"
# [48] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//Sncg.Gaba_young_5mCH.mm10.tmp"
# [49] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D1.Gaba_old_5mCH.mm10.tmp"
# [50] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D1.Gaba_young_5mCH.mm10.tmp"
# [51] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D1.Sema5a.Gaba_old_5mCH.mm10.tmp"
# [52] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D1.Sema5a.Gaba_young_5mCH.mm10.tmp"
# [53] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D2.Gaba_old_5mCH.mm10.tmp"
# [54] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_open_peak//STR.D2.Gaba_young_5mCH.mm10.tmp"
#  [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//ACB-BST-FS.D1.Gaba_old_5hmCH.mm10.tmp"
#  [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//ACB-BST-FS.D1.Gaba_young_5hmCH.mm10.tmp"
#  [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Astro-TE.NN_old_5hmCH.mm10.tmp"
#  [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Astro-TE.NN_young_5hmCH.mm10.tmp"
#  [5] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CA1-ProS.Glut_old_5hmCH.mm10.tmp"
#  [6] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CA1-ProS.Glut_young_5hmCH.mm10.tmp"
#  [7] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CA3.Glut_old_5hmCH.mm10.tmp"
#  [8] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CA3.Glut_young_5hmCH.mm10.tmp"
#  [9] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CLA-EPd-CTX.Car3.Glut_old_5hmCH.mm10.tmp"
# [10] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//CLA-EPd-CTX.Car3.Glut_young_5hmCH.mm10.tmp"
# [11] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//DG.Glut_old_5hmCH.mm10.tmp"
# [12] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//DG.Glut_young_5hmCH.mm10.tmp"
# [13] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//IT.AON-TT-DP.Glut_old_5hmCH.mm10.tmp"
# [14] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//IT.AON-TT-DP.Glut_young_5hmCH.mm10.tmp"
# [15] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L2.3.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [16] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L2.3.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [17] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L2.3.IT.RSP.Glut_old_5hmCH.mm10.tmp"
# [18] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L2.3.IT.RSP.Glut_young_5hmCH.mm10.tmp"
# [19] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L4.5.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [20] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L4.5.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [21] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.ET.CTX.Glut_old_5hmCH.mm10.tmp"
# [22] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.ET.CTX.Glut_young_5hmCH.mm10.tmp"
# [23] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [24] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [25] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.NP.CTX.Glut_old_5hmCH.mm10.tmp"
# [26] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L5.NP.CTX.Glut_young_5hmCH.mm10.tmp"
# [27] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L6.CT.CTX.Glut_old_5hmCH.mm10.tmp"
# [28] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//L6.CT.CTX.Glut_young_5hmCH.mm10.tmp"
# [29] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Lamp5.Gaba_old_5hmCH.mm10.tmp"
# [30] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Lamp5.Gaba_young_5hmCH.mm10.tmp"
# [31] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Microglia.NN_old_5hmCH.mm10.tmp"
# [32] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Microglia.NN_young_5hmCH.mm10.tmp"
# [33] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB-in.Frmd7.Gaba_old_5hmCH.mm10.tmp"
# [34] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB-in.Frmd7.Gaba_young_5hmCH.mm10.tmp"
# [35] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB-out.Frmd7.Gaba_old_5hmCH.mm10.tmp"
# [36] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB-out.Frmd7.Gaba_young_5hmCH.mm10.tmp"
# [37] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB.Eomes.Ms4a15.Glut_old_5hmCH.mm10.tmp"
# [38] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OB.Eomes.Ms4a15.Glut_young_5hmCH.mm10.tmp"
# [39] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OEC.NN_old_5hmCH.mm10.tmp"
# [40] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OEC.NN_young_5hmCH.mm10.tmp"
# [41] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Oligo.NN_old_5hmCH.mm10.tmp"
# [42] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Oligo.NN_young_5hmCH.mm10.tmp"
# [43] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OPC.NN_old_5hmCH.mm10.tmp"
# [44] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//OPC.NN_young_5hmCH.mm10.tmp"
# [45] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Pvalb.Gaba_old_5hmCH.mm10.tmp"
# [46] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Pvalb.Gaba_young_5hmCH.mm10.tmp"
# [47] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Sncg.Gaba_old_5hmCH.mm10.tmp"
# [48] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//Sncg.Gaba_young_5hmCH.mm10.tmp"
# [49] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D1.Gaba_old_5hmCH.mm10.tmp"
# [50] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D1.Gaba_young_5hmCH.mm10.tmp"
# [51] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D1.Sema5a.Gaba_old_5hmCH.mm10.tmp"
# [52] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D1.Sema5a.Gaba_young_5hmCH.mm10.tmp"
# [53] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D2.Gaba_old_5hmCH.mm10.tmp"
# [54] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_open_peak//STR.D2.Gaba_young_5hmCH.mm10.tmp"
#  [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//ACB-BST-FS.D1.Gaba_old_5mCH.mm10.tmp"
#  [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//ACB-BST-FS.D1.Gaba_young_5mCH.mm10.tmp"
#  [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Astro-TE.NN_old_5mCH.mm10.tmp"
#  [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Astro-TE.NN_young_5mCH.mm10.tmp"
#  [5] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CA1-ProS.Glut_old_5mCH.mm10.tmp"
#  [6] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CA1-ProS.Glut_young_5mCH.mm10.tmp"
#  [7] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CA3.Glut_old_5mCH.mm10.tmp"
#  [8] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CA3.Glut_young_5mCH.mm10.tmp"
#  [9] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CLA-EPd-CTX.Car3.Glut_old_5mCH.mm10.tmp"
# [10] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//CLA-EPd-CTX.Car3.Glut_young_5mCH.mm10.tmp"
# [11] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//DG.Glut_old_5mCH.mm10.tmp"
# [12] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//DG.Glut_young_5mCH.mm10.tmp"
# [13] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//IT.AON-TT-DP.Glut_old_5mCH.mm10.tmp"
# [14] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//IT.AON-TT-DP.Glut_young_5mCH.mm10.tmp"
# [15] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L2.3.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [16] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L2.3.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [17] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L2.3.IT.RSP.Glut_old_5mCH.mm10.tmp"
# [18] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L2.3.IT.RSP.Glut_young_5mCH.mm10.tmp"
# [19] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L4.5.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [20] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L4.5.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [21] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.ET.CTX.Glut_old_5mCH.mm10.tmp"
# [22] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.ET.CTX.Glut_young_5mCH.mm10.tmp"
# [23] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.IT.CTX.Glut_old_5mCH.mm10.tmp"
# [24] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.IT.CTX.Glut_young_5mCH.mm10.tmp"
# [25] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.NP.CTX.Glut_old_5mCH.mm10.tmp"
# [26] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L5.NP.CTX.Glut_young_5mCH.mm10.tmp"
# [27] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L6.CT.CTX.Glut_old_5mCH.mm10.tmp"
# [28] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//L6.CT.CTX.Glut_young_5mCH.mm10.tmp"
# [29] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Lamp5.Gaba_old_5mCH.mm10.tmp"
# [30] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Lamp5.Gaba_young_5mCH.mm10.tmp"
# [31] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Microglia.NN_old_5mCH.mm10.tmp"
# [32] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Microglia.NN_young_5mCH.mm10.tmp"
# [33] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB-in.Frmd7.Gaba_old_5mCH.mm10.tmp"
# [34] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB-in.Frmd7.Gaba_young_5mCH.mm10.tmp"
# [35] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB-out.Frmd7.Gaba_old_5mCH.mm10.tmp"
# [36] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB-out.Frmd7.Gaba_young_5mCH.mm10.tmp"
# [37] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB.Eomes.Ms4a15.Glut_old_5mCH.mm10.tmp"
# [38] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OB.Eomes.Ms4a15.Glut_young_5mCH.mm10.tmp"
# [39] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OEC.NN_old_5mCH.mm10.tmp"
# [40] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OEC.NN_young_5mCH.mm10.tmp"
# [41] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Oligo.NN_old_5mCH.mm10.tmp"
# [42] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Oligo.NN_young_5mCH.mm10.tmp"
# [43] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OPC.NN_old_5mCH.mm10.tmp"
# [44] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//OPC.NN_young_5mCH.mm10.tmp"
# [45] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Pvalb.Gaba_old_5mCH.mm10.tmp"
# [46] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Pvalb.Gaba_young_5mCH.mm10.tmp"
# [47] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Sncg.Gaba_old_5mCH.mm10.tmp"
# [48] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//Sncg.Gaba_young_5mCH.mm10.tmp"
# [49] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D1.Gaba_old_5mCH.mm10.tmp"
# [50] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D1.Gaba_young_5mCH.mm10.tmp"
# [51] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D1.Sema5a.Gaba_old_5mCH.mm10.tmp"
# [52] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D1.Sema5a.Gaba_young_5mCH.mm10.tmp"
# [53] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D2.Gaba_old_5mCH.mm10.tmp"
# [54] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_mCH_close_peak//STR.D2.Gaba_young_5mCH.mm10.tmp"
#  [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//ACB-BST-FS.D1.Gaba_old_5hmCH.mm10.tmp"
#  [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//ACB-BST-FS.D1.Gaba_young_5hmCH.mm10.tmp"
#  [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Astro-TE.NN_old_5hmCH.mm10.tmp"
#  [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Astro-TE.NN_young_5hmCH.mm10.tmp"
#  [5] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CA1-ProS.Glut_old_5hmCH.mm10.tmp"
#  [6] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CA1-ProS.Glut_young_5hmCH.mm10.tmp"
#  [7] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CA3.Glut_old_5hmCH.mm10.tmp"
#  [8] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CA3.Glut_young_5hmCH.mm10.tmp"
#  [9] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CLA-EPd-CTX.Car3.Glut_old_5hmCH.mm10.tmp"
# [10] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//CLA-EPd-CTX.Car3.Glut_young_5hmCH.mm10.tmp"
# [11] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//DG.Glut_old_5hmCH.mm10.tmp"
# [12] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//DG.Glut_young_5hmCH.mm10.tmp"
# [13] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//IT.AON-TT-DP.Glut_old_5hmCH.mm10.tmp"
# [14] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//IT.AON-TT-DP.Glut_young_5hmCH.mm10.tmp"
# [15] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L2.3.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [16] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L2.3.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [17] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L2.3.IT.RSP.Glut_old_5hmCH.mm10.tmp"
# [18] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L2.3.IT.RSP.Glut_young_5hmCH.mm10.tmp"
# [19] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L4.5.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [20] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L4.5.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [21] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.ET.CTX.Glut_old_5hmCH.mm10.tmp"
# [22] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.ET.CTX.Glut_young_5hmCH.mm10.tmp"
# [23] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.IT.CTX.Glut_old_5hmCH.mm10.tmp"
# [24] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.IT.CTX.Glut_young_5hmCH.mm10.tmp"
# [25] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.NP.CTX.Glut_old_5hmCH.mm10.tmp"
# [26] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L5.NP.CTX.Glut_young_5hmCH.mm10.tmp"
# [27] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L6.CT.CTX.Glut_old_5hmCH.mm10.tmp"
# [28] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//L6.CT.CTX.Glut_young_5hmCH.mm10.tmp"
# [29] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Lamp5.Gaba_old_5hmCH.mm10.tmp"
# [30] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Lamp5.Gaba_young_5hmCH.mm10.tmp"
# [31] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Microglia.NN_old_5hmCH.mm10.tmp"
# [32] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Microglia.NN_young_5hmCH.mm10.tmp"
# [33] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB-in.Frmd7.Gaba_old_5hmCH.mm10.tmp"
# [34] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB-in.Frmd7.Gaba_young_5hmCH.mm10.tmp"
# [35] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB-out.Frmd7.Gaba_old_5hmCH.mm10.tmp"
# [36] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB-out.Frmd7.Gaba_young_5hmCH.mm10.tmp"
# [37] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB.Eomes.Ms4a15.Glut_old_5hmCH.mm10.tmp"
# [38] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OB.Eomes.Ms4a15.Glut_young_5hmCH.mm10.tmp"
# [39] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OEC.NN_old_5hmCH.mm10.tmp"
# [40] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OEC.NN_young_5hmCH.mm10.tmp"
# [41] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Oligo.NN_old_5hmCH.mm10.tmp"
# [42] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Oligo.NN_young_5hmCH.mm10.tmp"
# [43] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OPC.NN_old_5hmCH.mm10.tmp"
# [44] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//OPC.NN_young_5hmCH.mm10.tmp"
# [45] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Pvalb.Gaba_old_5hmCH.mm10.tmp"
# [46] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Pvalb.Gaba_young_5hmCH.mm10.tmp"
# [47] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Sncg.Gaba_old_5hmCH.mm10.tmp"
# [48] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//Sncg.Gaba_young_5hmCH.mm10.tmp"
# [49] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D1.Gaba_old_5hmCH.mm10.tmp"
# [50] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D1.Gaba_young_5hmCH.mm10.tmp"
# [51] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D1.Sema5a.Gaba_old_5hmCH.mm10.tmp"
# [52] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D1.Sema5a.Gaba_young_5hmCH.mm10.tmp"
# [53] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D2.Gaba_old_5hmCH.mm10.tmp"
# [54] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_latest_20250216/output/01_hmCH_close_peak//STR.D2.Gaba_young_5hmCH.mm10.tmp"

# %%
process_files <- function(files1, files2) {
  result_list <- list()
  
  for (file1 in files1) {
    
    file_name <- basename(file1)
    corresponding_file <- files2[grepl(gsub("5mC", "5hmC", file_name), files2)]
    
    if (length(corresponding_file) == 1) {

      data1 <- read.table(file1, header = TRUE, stringsAsFactors = FALSE)
#       print(head(data1))
      data2 <- read.table(corresponding_file, header = TRUE, stringsAsFactors = FALSE)
#       print(head(data2))

      data1 <- data1[!is.na(data1[, 2]), ]
      data2 <- data2[!is.na(data2[, 2]), ]
      common_ids <- intersect(data1[, 1], data2[, 1])
      data1 <- data1[data1[, 1] %in% common_ids, ]
      data2 <- data2[data2[, 1] %in% common_ids, ]
      data1 <- data1[match(common_ids, data1[, 1]), ]
      data2 <- data2[match(common_ids, data2[, 1]), ]

      if (!identical(data1[, 1], data2[, 1])) {
        stop(paste("The first columns of", file1, "and", corresponding_file, "are not identical"))
      }

      diff <- data1[, 2] - data2[, 2]
      diff[diff < 0] <- 0
      avg_diff <- mean(diff, na.rm = TRUE)

      subclass <- gsub("_5mC.*$", "", file_name) %>% gsub("_(old|young)","",.)
      age_group <- ifelse(grepl("young", file_name), "young", "old")

      result_list[[file_name]] <- data.frame(Subclass = subclass,
                                             Age_Group = age_group,
                                             Difference = avg_diff)
    }
  }

  bind_rows(result_list)
}

# %%
result_open <- process_files(files_mCH_open, files_hmCH_open)
result_close <- process_files(files_mCH_close, files_hmCH_close)

# %%
result_open;result_close
# Out:
#    Subclass              Age_Group Difference
# 1  ACB-BST-FS.D1.Gaba    old       0.024438896
# 2  ACB-BST-FS.D1.Gaba    young     0.023532397
# 3  Astro-TE.NN           old       0.006125225
# 4  Astro-TE.NN           young     0.005953991
# 5  CA1-ProS.Glut         old       0.014591722
# 6  CA1-ProS.Glut         young     0.012882959
# 7  CA3.Glut              old       0.015657925
# 8  CA3.Glut              young     0.015379125
# 9  CLA-EPd-CTX.Car3.Glut old       0.019876131
# 10 CLA-EPd-CTX.Car3.Glut young     0.019240119
# 11 DG.Glut               old       0.004892522
# 12 DG.Glut               young     0.005049983
# 13 IT.AON-TT-DP.Glut     old       0.016279655
# 14 IT.AON-TT-DP.Glut     young     0.017201234
# 15 L2.3.IT.CTX.Glut      old       0.016377583
# 16 L2.3.IT.CTX.Glut      young     0.015944471
# 17 L2.3.IT.RSP.Glut      old       0.013417851
# 18 L2.3.IT.RSP.Glut      young     0.013318476
# 19 L4.5.IT.CTX.Glut      old       0.014069848
# 20 L4.5.IT.CTX.Glut      young     0.013128869
# 21 L5.ET.CTX.Glut        old       0.020112199
# 22 L5.ET.CTX.Glut        young     0.019570783
# 23 L5.IT.CTX.Glut        old       0.018289220
# 24 L5.IT.CTX.Glut        young     0.017683500
# 25 L5.NP.CTX.Glut        old       0.020390547
# 26 L5.NP.CTX.Glut        young     0.019452788
# 27 L6.CT.CTX.Glut        old       0.016098713
# 28 L6.CT.CTX.Glut        young     0.016140356
# 29 Lamp5.Gaba            old       0.013316607
# 30 Lamp5.Gaba            young     0.013428996
# 31 Microglia.NN          old       0.004552078
# 32 Microglia.NN          young     0.003609555
# 33 OB-in.Frmd7.Gaba      old       0.010305397
# 34 OB-in.Frmd7.Gaba      young     0.008804640
# 35 OB-out.Frmd7.Gaba     old       0.010105686
# 36 OB-out.Frmd7.Gaba     young     0.009151475
# 37 OB.Eomes.Ms4a15.Glut  old       0.014920172
# 38 OB.Eomes.Ms4a15.Glut  young     0.013884439
# 39 OEC.NN                old       0.004839755
# 40 OEC.NN                young     0.005007223
# 41 Oligo.NN              old       0.010995959
# 42 Oligo.NN              young     0.010162669
# 43 OPC.NN                old       0.003544611
# 44 OPC.NN                young     0.003723576
# 45 Pvalb.Gaba            old       0.024106848
# 46 Pvalb.Gaba            young     0.024162561
# 47 Sncg.Gaba             old       0.022590424
# 48 Sncg.Gaba             young     0.020659419
# 49 STR.D1.Gaba           old       0.011896903
# 50 STR.D1.Gaba           young     0.011724752
# 51 STR.D1.Sema5a.Gaba    old       0.015391395
# 52 STR.D1.Sema5a.Gaba    young     0.014144808
# 53 STR.D2.Gaba           old       0.016849438
# 54 STR.D2.Gaba           young     0.015609149
#    Subclass              Age_Group Difference
# 1  ACB-BST-FS.D1.Gaba    old       0.003899757
# 2  ACB-BST-FS.D1.Gaba    young     0.004134238
# 3  Astro-TE.NN           old       0.002553543
# 4  Astro-TE.NN           young     0.002381452
# 5  CA1-ProS.Glut         old       0.002680970
# 6  CA1-ProS.Glut         young     0.002768719
# 7  CA3.Glut              old       0.013082225
# 8  CA3.Glut              young     0.012443760
# 9  CLA-EPd-CTX.Car3.Glut old       0.004237652
# 10 CLA-EPd-CTX.Car3.Glut young     0.004215351
# 11 DG.Glut               old       0.002919094
# 12 DG.Glut               young     0.002531534
# 13 IT.AON-TT-DP.Glut     old       0.003936474
# 14 IT.AON-TT-DP.Glut     young     0.004755869
# 15 L2.3.IT.CTX.Glut      old       0.001924281
# 16 L2.3.IT.CTX.Glut      young     0.002001705
# 17 L2.3.IT.RSP.Glut      old       0.003373636
# 18 L2.3.IT.RSP.Glut      young     0.003614317
# 19 L4.5.IT.CTX.Glut      old       0.012681837
# 20 L4.5.IT.CTX.Glut      young     0.011102780
# 21 L5.ET.CTX.Glut        old       0.003538591
# 22 L5.ET.CTX.Glut        young     0.003329316
# 23 L5.IT.CTX.Glut        old       0.009299651
# 24 L5.IT.CTX.Glut        young     0.008482858
# 25 L5.NP.CTX.Glut        old       0.004811519
# 26 L5.NP.CTX.Glut        young     0.005004157
# 27 L6.CT.CTX.Glut        old       0.002837103
# 28 L6.CT.CTX.Glut        young     0.002783782
# 29 Lamp5.Gaba            old       0.004443786
# 30 Lamp5.Gaba            young     0.004478443
# 31 Microglia.NN          old       0.003905898
# 32 Microglia.NN          young     0.003932173
# 33 OB-in.Frmd7.Gaba      old       0.002796756
# 34 OB-in.Frmd7.Gaba      young     0.002651153
# 35 OB-out.Frmd7.Gaba     old       0.004650600
# 36 OB-out.Frmd7.Gaba     young     0.004494455
# 37 OB.Eomes.Ms4a15.Glut  old       0.004256904
# 38 OB.Eomes.Ms4a15.Glut  young     0.004207211
# 39 OEC.NN                old       0.003938593
# 40 OEC.NN                young     0.003881898
# 41 Oligo.NN              old       0.002613720
# 42 Oligo.NN              young     0.002108788
# 43 OPC.NN                old       0.003692110
# 44 OPC.NN                young     0.003554151
# 45 Pvalb.Gaba            old       0.019424458
# 46 Pvalb.Gaba            young     0.018583383
# 47 Sncg.Gaba             old       0.004251115
# 48 Sncg.Gaba             young     0.004045798
# 49 STR.D1.Gaba           old       0.004400010
# 50 STR.D1.Gaba           young     0.004759916
# 51 STR.D1.Sema5a.Gaba    old       0.005046351
# 52 STR.D1.Sema5a.Gaba    young     0.005733437
# 53 STR.D2.Gaba           old       0.002158934
# 54 STR.D2.Gaba           young     0.002300728

# %%
library(tidyr)

# %%
final_result <- bind_rows(
  result_open %>% mutate(Type = "open"),
  result_close %>% mutate(Type = "close")
) %>%
  pivot_wider(names_from = Age_Group, values_from = Difference) %>% 
  mutate(Old_Young_Diff = old - young) ## %>%  
#   select(Subclass, Old_Young_Diff)

# %%
final_result
# Out:
#    Subclass              Type  old         young       Old_Young_Diff
# 1  ACB-BST-FS.D1.Gaba    open  0.024438896 0.023532397  9.064986e-04
# 2  Astro-TE.NN           open  0.006125225 0.005953991  1.712341e-04
# 3  CA1-ProS.Glut         open  0.014591722 0.012882959  1.708763e-03
# 4  CA3.Glut              open  0.015657925 0.015379125  2.788004e-04
# 5  CLA-EPd-CTX.Car3.Glut open  0.019876131 0.019240119  6.360123e-04
# 6  DG.Glut               open  0.004892522 0.005049983 -1.574607e-04
# 7  IT.AON-TT-DP.Glut     open  0.016279655 0.017201234 -9.215789e-04
# 8  L2.3.IT.CTX.Glut      open  0.016377583 0.015944471  4.331112e-04
# 9  L2.3.IT.RSP.Glut      open  0.013417851 0.013318476  9.937494e-05
# 10 L4.5.IT.CTX.Glut      open  0.014069848 0.013128869  9.409795e-04
# 11 L5.ET.CTX.Glut        open  0.020112199 0.019570783  5.414158e-04
# 12 L5.IT.CTX.Glut        open  0.018289220 0.017683500  6.057209e-04
# 13 L5.NP.CTX.Glut        open  0.020390547 0.019452788  9.377585e-04
# 14 L6.CT.CTX.Glut        open  0.016098713 0.016140356 -4.164267e-05
# 15 Lamp5.Gaba            open  0.013316607 0.013428996 -1.123889e-04
# 16 Microglia.NN          open  0.004552078 0.003609555  9.425231e-04
# 17 OB-in.Frmd7.Gaba      open  0.010305397 0.008804640  1.500757e-03
# 18 OB-out.Frmd7.Gaba     open  0.010105686 0.009151475  9.542116e-04
# 19 OB.Eomes.Ms4a15.Glut  open  0.014920172 0.013884439  1.035733e-03
# 20 OEC.NN                open  0.004839755 0.005007223 -1.674675e-04
# 21 Oligo.NN              open  0.010995959 0.010162669  8.332903e-04
# 22 OPC.NN                open  0.003544611 0.003723576 -1.789647e-04
# 23 Pvalb.Gaba            open  0.024106848 0.024162561 -5.571234e-05
# 24 Sncg.Gaba             open  0.022590424 0.020659419  1.931005e-03
# 25 STR.D1.Gaba           open  0.011896903 0.011724752  1.721513e-04
# 26 STR.D1.Sema5a.Gaba    open  0.015391395 0.014144808  1.246587e-03
# 27 STR.D2.Gaba           open  0.016849438 0.015609149  1.240289e-03
# 28 ACB-BST-FS.D1.Gaba    close 0.003899757 0.004134238 -2.344811e-04
# 29 Astro-TE.NN           close 0.002553543 0.002381452  1.720914e-04
# 30 CA1-ProS.Glut         close 0.002680970 0.002768719 -8.774946e-05
# 31 CA3.Glut              close 0.013082225 0.012443760  6.384649e-04
# 32 CLA-EPd-CTX.Car3.Glut close 0.004237652 0.004215351  2.230029e-05
# 33 DG.Glut               close 0.002919094 0.002531534  3.875605e-04
# 34 IT.AON-TT-DP.Glut     close 0.003936474 0.004755869 -8.193945e-04
# 35 L2.3.IT.CTX.Glut      close 0.001924281 0.002001705 -7.742328e-05
# 36 L2.3.IT.RSP.Glut      close 0.003373636 0.003614317 -2.406813e-04
# 37 L4.5.IT.CTX.Glut      close 0.012681837 0.011102780  1.579057e-03
# 38 L5.ET.CTX.Glut        close 0.003538591 0.003329316  2.092746e-04
# 39 L5.IT.CTX.Glut        close 0.009299651 0.008482858  8.167934e-04
# 40 L5.NP.CTX.Glut        close 0.004811519 0.005004157 -1.926378e-04
# 41 L6.CT.CTX.Glut        close 0.002837103 0.002783782  5.332168e-05
# 42 Lamp5.Gaba            close 0.004443786 0.004478443 -3.465688e-05
# 43 Microglia.NN          close 0.003905898 0.003932173 -2.627561e-05
# 44 OB-in.Frmd7.Gaba      close 0.002796756 0.002651153  1.456032e-04
# 45 OB-out.Frmd7.Gaba     close 0.004650600 0.004494455  1.561458e-04
# 46 OB.Eomes.Ms4a15.Glut  close 0.004256904 0.004207211  4.969280e-05
# 47 OEC.NN                close 0.003938593 0.003881898  5.669536e-05
# 48 Oligo.NN              close 0.002613720 0.002108788  5.049322e-04
# 49 OPC.NN                close 0.003692110 0.003554151  1.379591e-04
# 50 Pvalb.Gaba            close 0.019424458 0.018583383  8.410750e-04
# 51 Sncg.Gaba             close 0.004251115 0.004045798  2.053170e-04
# 52 STR.D1.Gaba           close 0.004400010 0.004759916 -3.599061e-04
# 53 STR.D1.Sema5a.Gaba    close 0.005046351 0.005733437 -6.870852e-04
# 54 STR.D2.Gaba           close 0.002158934 0.002300728 -1.417933e-04

# %%
unique(final_result$Subclass)
# Out:
#  [1] "ACB-BST-FS.D1.Gaba"    "Astro-TE.NN"           "CA1-ProS.Glut"
#  [4] "CA3.Glut"              "CLA-EPd-CTX.Car3.Glut" "DG.Glut"
#  [7] "IT.AON-TT-DP.Glut"     "L2.3.IT.CTX.Glut"      "L2.3.IT.RSP.Glut"
# [10] "L4.5.IT.CTX.Glut"      "L5.ET.CTX.Glut"        "L5.IT.CTX.Glut"
# [13] "L5.NP.CTX.Glut"        "L6.CT.CTX.Glut"        "Lamp5.Gaba"
# [16] "Microglia.NN"          "OB-in.Frmd7.Gaba"      "OB-out.Frmd7.Gaba"
# [19] "OB.Eomes.Ms4a15.Glut"  "OEC.NN"                "Oligo.NN"
# [22] "OPC.NN"                "Pvalb.Gaba"            "Sncg.Gaba"
# [25] "STR.D1.Gaba"           "STR.D1.Sema5a.Gaba"    "STR.D2.Gaba"

# %%
subclass_info
# Out:
#    subclass_v1           subclass_v2
# 1  ACB-BST-FS.D1.Gaba    ACB-BST-FS D1 Gaba
# 2  Astro-TE.NN           Astro-TE NN
# 3  CA1-ProS.Glut         CA1-ProS Glut
# 4  CA3.Glut              CA3 Glut
# 5  CLA-EPd-CTX.Car3.Glut CLA-EPd-CTX Car3 Glut
# 6  DG.Glut               DG Glut
# 7  IT.AON-TT-DP.Glut     IT AON-TT-DP Glut
# 8  L2.3.IT.CTX.Glut      L2/3 IT CTX Glut
# 9  L2.3.IT.RSP.Glut      L2/3 IT RSP Glut
# 10 L4.5.IT.CTX.Glut      L4/5 IT CTX Glut
# 11 L5.ET.CTX.Glut        L5 ET CTX Glut
# 12 L5.IT.CTX.Glut        L5 IT CTX Glut
# 13 L5.NP.CTX.Glut        L5 NP CTX Glut
# 14 L6.CT.CTX.Glut        L6 CT CTX Glut
# 15 Lamp5.Gaba            Lamp5 Gaba
# 16 Microglia.NN          Microglia NN
# 17 OB-in.Frmd7.Gaba      OB-in Frmd7 Gaba
# 18 OB-out.Frmd7.Gaba     OB-out Frmd7 Gaba
# 19 OB.Eomes.Ms4a15.Glut  OB Eomes Ms4a15 Glut
# 20 OEC.NN                OEC NN
# 21 Oligo.NN              Oligo NN
# 22 OPC.NN                OPC NN
# 23 Pvalb.Gaba            Pvalb Gaba
# 24 Sncg.Gaba             Sncg Gaba
# 25 STR.D1.Gaba           STR D1 Gaba
# 26 STR.D1.Sema5a.Gaba    STR D1 Sema5a Gaba
# 27 STR.D2.Gaba           STR D2 Gaba

# %%
final_result$Subclass <- subclass_info$subclass_v2[match(final_result$Subclass,subclass_info$subclass_v1)]

# %%
final_result
# Out:
#    Subclass              Type  old         young       Old_Young_Diff
# 1  ACB-BST-FS D1 Gaba    open  0.024438896 0.023532397  9.064986e-04
# 2  Astro-TE NN           open  0.006125225 0.005953991  1.712341e-04
# 3  CA1-ProS Glut         open  0.014591722 0.012882959  1.708763e-03
# 4  CA3 Glut              open  0.015657925 0.015379125  2.788004e-04
# 5  CLA-EPd-CTX Car3 Glut open  0.019876131 0.019240119  6.360123e-04
# 6  DG Glut               open  0.004892522 0.005049983 -1.574607e-04
# 7  IT AON-TT-DP Glut     open  0.016279655 0.017201234 -9.215789e-04
# 8  L2/3 IT CTX Glut      open  0.016377583 0.015944471  4.331112e-04
# 9  L2/3 IT RSP Glut      open  0.013417851 0.013318476  9.937494e-05
# 10 L4/5 IT CTX Glut      open  0.014069848 0.013128869  9.409795e-04
# 11 L5 ET CTX Glut        open  0.020112199 0.019570783  5.414158e-04
# 12 L5 IT CTX Glut        open  0.018289220 0.017683500  6.057209e-04
# 13 L5 NP CTX Glut        open  0.020390547 0.019452788  9.377585e-04
# 14 L6 CT CTX Glut        open  0.016098713 0.016140356 -4.164267e-05
# 15 Lamp5 Gaba            open  0.013316607 0.013428996 -1.123889e-04
# 16 Microglia NN          open  0.004552078 0.003609555  9.425231e-04
# 17 OB-in Frmd7 Gaba      open  0.010305397 0.008804640  1.500757e-03
# 18 OB-out Frmd7 Gaba     open  0.010105686 0.009151475  9.542116e-04
# 19 OB Eomes Ms4a15 Glut  open  0.014920172 0.013884439  1.035733e-03
# 20 OEC NN                open  0.004839755 0.005007223 -1.674675e-04
# 21 Oligo NN              open  0.010995959 0.010162669  8.332903e-04
# 22 OPC NN                open  0.003544611 0.003723576 -1.789647e-04
# 23 Pvalb Gaba            open  0.024106848 0.024162561 -5.571234e-05
# 24 Sncg Gaba             open  0.022590424 0.020659419  1.931005e-03
# 25 STR D1 Gaba           open  0.011896903 0.011724752  1.721513e-04
# 26 STR D1 Sema5a Gaba    open  0.015391395 0.014144808  1.246587e-03
# 27 STR D2 Gaba           open  0.016849438 0.015609149  1.240289e-03
# 28 ACB-BST-FS D1 Gaba    close 0.003899757 0.004134238 -2.344811e-04
# 29 Astro-TE NN           close 0.002553543 0.002381452  1.720914e-04
# 30 CA1-ProS Glut         close 0.002680970 0.002768719 -8.774946e-05
# 31 CA3 Glut              close 0.013082225 0.012443760  6.384649e-04
# 32 CLA-EPd-CTX Car3 Glut close 0.004237652 0.004215351  2.230029e-05
# 33 DG Glut               close 0.002919094 0.002531534  3.875605e-04
# 34 IT AON-TT-DP Glut     close 0.003936474 0.004755869 -8.193945e-04
# 35 L2/3 IT CTX Glut      close 0.001924281 0.002001705 -7.742328e-05
# 36 L2/3 IT RSP Glut      close 0.003373636 0.003614317 -2.406813e-04
# 37 L4/5 IT CTX Glut      close 0.012681837 0.011102780  1.579057e-03
# 38 L5 ET CTX Glut        close 0.003538591 0.003329316  2.092746e-04
# 39 L5 IT CTX Glut        close 0.009299651 0.008482858  8.167934e-04
# 40 L5 NP CTX Glut        close 0.004811519 0.005004157 -1.926378e-04
# 41 L6 CT CTX Glut        close 0.002837103 0.002783782  5.332168e-05
# 42 Lamp5 Gaba            close 0.004443786 0.004478443 -3.465688e-05
# 43 Microglia NN          close 0.003905898 0.003932173 -2.627561e-05
# 44 OB-in Frmd7 Gaba      close 0.002796756 0.002651153  1.456032e-04
# 45 OB-out Frmd7 Gaba     close 0.004650600 0.004494455  1.561458e-04
# 46 OB Eomes Ms4a15 Glut  close 0.004256904 0.004207211  4.969280e-05
# 47 OEC NN                close 0.003938593 0.003881898  5.669536e-05
# 48 Oligo NN              close 0.002613720 0.002108788  5.049322e-04
# 49 OPC NN                close 0.003692110 0.003554151  1.379591e-04
# 50 Pvalb Gaba            close 0.019424458 0.018583383  8.410750e-04
# 51 Sncg Gaba             close 0.004251115 0.004045798  2.053170e-04
# 52 STR D1 Gaba           close 0.004400010 0.004759916 -3.599061e-04
# 53 STR D1 Sema5a Gaba    close 0.005046351 0.005733437 -6.870852e-04
# 54 STR D2 Gaba           close 0.002158934 0.002300728 -1.417933e-04

# %%
final_result$Subclass <- factor(final_result$Subclass,levels = subclass_order)

# %%
levels(final_result$Subclass)
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"                "Microglia NN"

# %%
final_result$Type <- factor(final_result$Type,levels = c("open","close"))

# %%
levels(final_result$Type)
# Out:
# [1] "open"  "close"

# %%
# options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
# ggplot(final_result, aes(x = Subclass, y = Old_Young_Diff, fill = Type)) +
#   geom_bar(stat = "identity", position = position_dodge()) + 
#   labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5mCH") +
#   theme_minimal(base_size = 18) +
#   theme(
#     panel.grid = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1.2),
#     axis.text = element_text(color = "black"),
#     axis.text.x = element_text(angle = 45, hjust = 1),
#     axis.title = element_text(face = "bold"),
#     plot.title = element_text(hjust = 0.5, face = "bold")
#   ) +
#   scale_fill_manual(values = c("open" = "#D7272A", "close" = "#2077B5"))
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 6, repr.plot.res = 100)
ggplot(final_result, aes(x = Subclass, y = Old_Young_Diff, fill = Type)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5mCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))
# Out:
# plot without title

# %%
p3 <- ggplot(final_result, aes(x = Subclass, y = Old_Young_Diff, fill = Type)) +
  geom_bar(stat = "identity", position = position_dodge()) + 
  labs(x = "Subclass", y = "Mean ratio (old - young)", title = "5mCH") +
  theme_minimal(base_size = 18) +
  theme(
    panel.grid = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1.2),
    axis.text = element_text(color = "black"),
    axis.text.x = element_text(angle = 45, hjust = 1),
    axis.title = element_text(face = "bold"),
    plot.title = element_text(hjust = 0.5, face = "bold")
  ) +
  scale_fill_manual(values = c("open" = "#88A997", "close" = "#BE7767"))

# %%
library(cowplot)
library(gridExtra)
# Out:
# Warning message:
# “package ‘cowplot’ was built under R version 4.3.2”
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
g1 <- arrangeGrob(p1, heights = unit(6, "inches"), widths = unit(15, "inches"))
g2 <- arrangeGrob(p2, heights = unit(6, "inches"), widths = unit(15, "inches"))
g3 <- arrangeGrob(p3, heights = unit(6, "inches"), widths = unit(15, "inches"))

# %%
combined_plot <- arrangeGrob(g1, g2, g3, ncol = 3, nrow = 1)

# %%
ggsave("../../../output/03.Aging_Mouse/06-ATAC/03-ATAC_open_close_peak_CH_methylation_ratio.pdf", combined_plot, width = 45, height = 6)
