# %% [markdown]
# #########    All "our" in the following code refers to Joint Cabernet.

# %%
library(data.table)
library(dplyr)
library(tidyr)
library(GenomicRanges)
# Out:
# Warning message:
# “package ‘data.table’ was built under R version 4.3.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.2”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘GenomicRanges’ was built under R version 4.3.3”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Warning message:
# “package ‘BiocGenerics’ was built under R version 4.3.2”
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Warning message:
# “package ‘S4Vectors’ was built under R version 4.3.3”
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:data.table’:
#
#     first, second
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# “package ‘IRanges’ was built under R version 4.3.3”
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# Loading required package: GenomeInfoDb
#
# Warning message:
# “package ‘GenomeInfoDb’ was built under R version 4.3.2”

# %%
# "indir" is a custom input path, and "outdir" is a custom output path.
# indir=""
# outdir=""

# %%
promoter_file <- "../../../input/reference_genome/PromoterUp2k.mm10.bed"
genebody_file <- "../../../input/reference_genome/Genebody.mm10.bed"

# %%
promoter <- fread(promoter_file, col.names = c("chr", "start", "end", "gene_id", "gene_name", "strand"))
genebody <- fread(genebody_file, col.names = c("chr", "start", "end", "gene_id", "gene_name", "strand"))

# %%
head(promoter);dim(promoter)
head(genebody);dim(genebody)
# Out:
#   chr  start   end     gene_id              gene_name     strand
# 1 chr1 3071253 3073253 ENSMUSG00000102693.1 RP23-271O17.1 +
# 2 chr1 3100016 3102016 ENSMUSG00000064842.1 Gm26206       +
# 3 chr1 3671498 3673498 ENSMUSG00000051951.5 Xkr4          -
# 4 chr1 3250757 3252757 ENSMUSG00000102851.1 RP23-317L18.1 +
# 5 chr1 3368549 3370549 ENSMUSG00000103377.1 RP23-317L18.4 -
# 6 chr1 3377788 3379788 ENSMUSG00000104017.1 RP23-317L18.3 -
# [1] 54142     6
#   chr  start   end     gene_id              gene_name     strand
# 1 chr1 3073253 3074322 ENSMUSG00000102693.1 RP23-271O17.1 +
# 2 chr1 3102016 3102125 ENSMUSG00000064842.1 Gm26206       +
# 3 chr1 3205901 3671498 ENSMUSG00000051951.5 Xkr4          -
# 4 chr1 3252757 3253236 ENSMUSG00000102851.1 RP23-317L18.1 +
# 5 chr1 3365731 3368549 ENSMUSG00000103377.1 RP23-317L18.4 -
# 6 chr1 3375556 3377788 ENSMUSG00000104017.1 RP23-317L18.3 -
# [1] 54146     6

# %%
input_dirs <- c(
 paste0(indir,"/01_hmCG_open_peak/"),
 paste0(indir,"/01_hmCH_open_peak/"),
 paste0(indir,"/01_mCG_open_peak/"),
 paste0(indir,"/01_mCH_open_peak/")
)

input_dirs
# Out:
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_hmCG_open_peak/"
# [2] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_hmCH_open_peak/"
# [3] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCG_open_peak/"
# [4] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak/"

# %%
create_granges <- function(df) {
  GRanges(seqnames = df$chr, ranges = IRanges(start = df$start, end = df$end), gene_id = df$gene_id, gene_name = df$gene_name, strand = df$strand)
}

# %%
promoter_gr <- create_granges(promoter)
genebody_gr <- create_granges(genebody)

promoter_gr;genebody_gr
# Out:
# GRanges object with 54142 ranges and 2 metadata columns:
#           seqnames          ranges strand |              gene_id     gene_name
#              <Rle>       <IRanges>  <Rle> |          <character>   <character>
#       [1]     chr1 3071253-3073253      + | ENSMUSG00000102693.1 RP23-271O17.1
#       [2]     chr1 3100016-3102016      + | ENSMUSG00000064842.1       Gm26206
#       [3]     chr1 3671498-3673498      - | ENSMUSG00000051951.5          Xkr4
#       [4]     chr1 3250757-3252757      + | ENSMUSG00000102851.1 RP23-317L18.1
#       [5]     chr1 3368549-3370549      - | ENSMUSG00000103377.1 RP23-317L18.4
#       ...      ...             ...    ... .                  ...           ...
#   [54138]     chrM     14070-16070      - | ENSMUSG00000064368.1        mt-Nd6
#   [54139]     chrM     14139-16139      - | ENSMUSG00000064369.1         mt-Te
#   [54140]     chrM     12145-14145      + | ENSMUSG00000064370.1       mt-Cytb
#   [54141]     chrM     13289-15289      + | ENSMUSG00000064371.1         mt-Tt
#   [54142]     chrM     15422-17422      - | ENSMUSG00000064372.1         mt-Tp
#   -------
#   seqinfo: 22 sequences from an unspecified genome; no seqlengths
# GRanges object with 54146 ranges and 2 metadata columns:
#           seqnames          ranges strand |              gene_id     gene_name
#              <Rle>       <IRanges>  <Rle> |          <character>   <character>
#       [1]     chr1 3073253-3074322      + | ENSMUSG00000102693.1 RP23-271O17.1
#       [2]     chr1 3102016-3102125      + | ENSMUSG00000064842.1       Gm26206
#       [3]     chr1 3205901-3671498      - | ENSMUSG00000051951.5          Xkr4
#       [4]     chr1 3252757-3253236      + | ENSMUSG00000102851.1 RP23-317L18.1
#       [5]     chr1 3365731-3368549      - | ENSMUSG00000103377.1 RP23-317L18.4
#       ...      ...             ...    ... .                  ...           ...
#   [54142]     chrM     13552-14070      - | ENSMUSG00000064368.1        mt-Nd6
#   [54143]     chrM     14071-14139      - | ENSMUSG00000064369.1         mt-Te
#   [54144]     chrM     14145-15288      + | ENSMUSG00000064370.1       mt-Cytb
#   [54145]     chrM     15289-15355      + | ENSMUSG00000064371.1         mt-Tt
#   [54146]     chrM     15356-15422      - | ENSMUSG00000064372.1         mt-Tp
#   -------
#   seqinfo: 22 sequences from an unspecified genome; no seqlengths

# %%
result_list <- list()

# %%
for (dir in input_dirs) {

  modification <- case_when(
    grepl("hmCG_open_peak", dir) ~ "hmCG",
    grepl("hmCH_open_peak", dir) ~ "hmCH",
    grepl("mCG_open_peak", dir) ~ "mCG",
    grepl("mCH_open_peak", dir) ~ "mCH",
    TRUE ~ "unknown"
  )

  tmp_files <- list.files(dir, pattern = "\\.tmp$", full.names = TRUE)

  old_files <- tmp_files[grepl("_old_", tmp_files)]
  young_files <- tmp_files[grepl("_young_", tmp_files)]

  for (old_file in old_files) {

    print(old_file)
    subclass <- gsub("^(.*)_old_.*", "\\1", basename(old_file))
    print(subclass)
    pattern <- paste0(subclass, "_young_")
    young_file <- young_files[grepl(pattern, young_files)]
    print(young_file)

    if (length(young_file) != 1) next

    old_data <- read.delim(old_file) %>%
      separate(peak, into = c("chr", "range"), sep = ":") %>%
      separate(range, into = c("start", "end"), sep = "-") %>%
      mutate(start = as.numeric(start), end = as.numeric(end))
    print(head(old_data))

    young_data <- read.delim(young_file) %>%
      separate(peak, into = c("chr", "range"), sep = ":") %>%
      separate(range, into = c("start", "end"), sep = "-") %>%
      mutate(start = as.numeric(start), end = as.numeric(end))
    print(head(young_data))

    old_gr <- create_granges(old_data)
    young_gr <- create_granges(young_data)

    overlap_promoter <- findOverlaps(old_gr, promoter_gr)
    overlap_genebody <- findOverlaps(old_gr, genebody_gr)

    promoter_data <- data.frame(old_data[queryHits(overlap_promoter), ],
                                gene_name = mcols(promoter_gr)$gene_name[subjectHits(overlap_promoter)]) %>%
      mutate(element = "promoter")

    genebody_data <- data.frame(old_data[queryHits(overlap_genebody), ],
                                gene_name = mcols(genebody_gr)$gene_name[subjectHits(overlap_genebody)]) %>%
      mutate(element = "genebody")

    combined_old <- bind_rows(promoter_data, genebody_data) %>% distinct()

    print("Combined old data:")
    print(head(combined_old))

    overlap_promoter_young <- findOverlaps(young_gr, promoter_gr)
    overlap_genebody_young <- findOverlaps(young_gr, genebody_gr)

    promoter_data_young <- data.frame(young_data[queryHits(overlap_promoter_young), ],
                                      gene_name = mcols(promoter_gr)$gene_name[subjectHits(overlap_promoter_young)]) %>%
      mutate(element = "promoter")

    genebody_data_young <- data.frame(young_data[queryHits(overlap_genebody_young), ],
                                      gene_name = mcols(genebody_gr)$gene_name[subjectHits(overlap_genebody_young)]) %>%
      mutate(element = "genebody")

    combined_young <- bind_rows(promoter_data_young, genebody_data_young) %>% distinct()

    print("Combined young data:")
    print(head(combined_young))

    merged_data <- inner_join(combined_old, combined_young,
                              by = c("chr", "start", "end", "gene_name", "element"),
                              suffix = c("_old", "_young"))

    if (!"chr" %in% colnames(merged_data)) {
      stop("Error: 'chr' column not found in merged_data!")
    }

    final_data <- merged_data %>%
      mutate(subclass = subclass,
             peak = paste0(chr, ":", start, "-", end),
             old_young_mean_ratio = Mean_ratio_old - Mean_ratio_young,
             modification = modification) %>%
      select(subclass, peak, gene_name, old_young_mean_ratio, modification, element)

    result_list[[length(result_list) + 1]] <- final_data
  }
}
# Out:
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_hmCG_open_peak//ACB-BST-FS.D1.Gaba_old_5hmCG.mm10.tmp"
# [1] "ACB-BST-FS.D1.Gaba"
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_hmCG_open_peak//ACB-BST-FS.D1.Gaba_young_5hmCG.mm10.tmp"
#    chr   start     end Mean_ratio
# 1 chr1 3246935 3252935  0.4592066
# 2 chr1 3289752 3295752  0.4071331
# 3 chr1 3360706 3366706  0.4061809
# 4 chr1 3368714 3374714  0.4537257
# 5 chr1 3385559 3391559  0.4425891
# 6 chr1 3392722 3398722  0.4495155
#    chr   start     end Mean_ratio
# 1 chr1 3246935 3252935  0.4533161
# 2 chr1 3289752 3295752  0.3658487
# 3 chr1 3360706 3366706  0.3716347
# 4 chr1 3368714 3374714  0.4019583
# 5 chr1 3385559 3391559  0.3979654
# 6 chr1 3392722 3398722  0.4367962
# [1] "Combined old data:"
#          chr   start     end Mean_ratio     gene_name  element
# 1...1   chr1 3246935 3252935 0.45920664 RP23-317L18.1 promoter
# 4...2   chr1 3368714 3374714 0.45372574 RP23-317L18.4 promoter
# 8...3   chr1 3463509 3469509 0.44733683  RP23-115I1.1 promoter
# 8.1...4 chr1 3463509 3469509 0.44733683  RP23-115I1.6 promoter
# [1] "Combined old data:"
#         chr   start     end Mean_ratio     gene_name  element
# 12...1 chr1 3245976 3251976 0.01327422 RP23-317L18.1 promoter
# 19...2 chr1 3363543 3369543 0.01118085 RP23-317L18.4 promoter
# 20...3 chr1 3365431 3371431 0.01144625 RP23-317L18.4 promoter
# 21...4 chr1 3366721 3372721 0.01034084 RP23-317L18.4 promoter
# 22...5 chr1 3379747 3385747 0.01226213 RP23-317L18.3 promoter
# 37...6 chr1 3530132 3536132 0.01270690  RP23-115I1.2 promoter
# [1] "Combined young data:"
#         chr   start     end  Mean_ratio     gene_name  element
# 12...1 chr1 3245976 3251976 0.012606340 RP23-317L18.1 promoter
# 19...2 chr1 3363543 3369543 0.008803240 RP23-317L18.4 promoter
# 20...3 chr1 3365431 3371431 0.008778965 RP23-317L18.4 promoter
# 21...4 chr1 3366721 3372721 0.008745425 RP23-317L18.4 promoter
# 22...5 chr1 3379747 3385747 0.011781720 RP23-317L18.3 promoter
# 37...6 chr1 3530132 3536132 0.013267900  RP23-115I1.2 promoter
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//Sncg.Gaba_old_5mCH.mm10.tmp"
# [1] "Sncg.Gaba"
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//Sncg.Gaba_young_5mCH.mm10.tmp"
#    chr   start     end Mean_ratio
# 1 chr1 3091974 3097974 0.02721888
# 2 chr1 3118465 3124465 0.02447851
# 3 chr1 3207395 3213395 0.02487810
# 4 chr1 3289752 3295752 0.02179504
# 5 chr1 3330830 3336830 0.01521043
# 6 chr1 3358097 3364097 0.01969492
#    chr   start     end Mean_ratio
# 1 chr1 3091974 3097974 0.02371247
# 2 chr1 3118465 3124465 0.02202863
# 3 chr1 3207395 3213395 0.02249757
# 4 chr1 3289752 3295752 0.02080992
# 5 chr1 3330830 3336830 0.01542662
# 6 chr1 3358097 3364097 0.02191379
# [1] "Combined old data:"
#           chr   start     end Mean_ratio     gene_name  element
# 7...1    chr1 3365431 3371431 0.02065042 RP23-317L18.4 promoter
# 8...2    chr1 3379747 3385747 0.01664040 RP23-317L18.3 promoter
# 14...3   chr1 3463509 3469509 0.03000668  RP23-115I1.1 promoter
# 14.1...4 chr1 3463509 3469509 0.03000668  RP23-115I1.6 promoter
# 15...5   chr1 3511767 3517767 0.02593884  RP23-115I1.5 promoter
# 16...6   chr1 3512403 3518403 0.02487952  RP23-115I1.5 promoter
# [1] "Combined young data:"
#           chr   start     end Mean_ratio     gene_name  element
# 7...1    chr1 3365431 3371431 0.01932108 RP23-317L18.4 promoter
# 8...2    chr1 3379747 3385747 0.01509128 RP23-317L18.3 promoter
# 14...3   chr1 3463509 3469509 0.02802156  RP23-115I1.1 promoter
# 14.1...4 chr1 3463509 3469509 0.02802156  RP23-115I1.6 promoter
# 15...5   chr1 3511767 3517767 0.02362741  RP23-115I1.5 promoter
# 16...6   chr1 3512403 3518403 0.02301161  RP23-115I1.5 promoter
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D1.Gaba_old_5mCH.mm10.tmp"
# [1] "STR.D1.Gaba"
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D1.Gaba_young_5mCH.mm10.tmp"
#    chr   start     end Mean_ratio
# 1 chr1 3097946 3103946 0.01507366
# 2 chr1 3204202 3210202 0.01739237
# 3 chr1 3216484 3222484 0.02057874
# 4 chr1 3246935 3252935 0.01545532
# 5 chr1 3262347 3268347 0.01578869
# 6 chr1 3289752 3295752 0.01457253
#    chr   start     end  Mean_ratio
# 1 chr1 3097946 3103946 0.008928694
# 2 chr1 3204202 3210202 0.017233182
# 3 chr1 3216484 3222484 0.029700176
# 4 chr1 3246935 3252935 0.012282250
# 5 chr1 3262347 3268347 0.012083120
# 6 chr1 3289752 3295752 0.014035430
# [1] "Combined old data:"
#         chr   start     end Mean_ratio     gene_name  element
# 1...1  chr1 3097946 3103946 0.01507366       Gm26206 promoter
# 4...2  chr1 3246935 3252935 0.01545532 RP23-317L18.1 promoter
# 10...3 chr1 3368714 3374714 0.02853584 RP23-317L18.4 promoter
# 11...4 chr1 3378330 3384330 0.01506482 RP23-317L18.3 promoter
# 12...5 chr1 3378937 3384937 0.01533134 RP23-317L18.3 promoter
# 22...6 chr1 3463509 3469509 0.02489343  RP23-115I1.1 promoter
# [1] "Combined young data:"
#         chr   start     end  Mean_ratio     gene_name  element
# 1...1  chr1 3097946 3103946 0.008928694       Gm26206 promoter
# 4...2  chr1 3246935 3252935 0.012282250 RP23-317L18.1 promoter
# 10...3 chr1 3368714 3374714 0.026677447 RP23-317L18.4 promoter
# 11...4 chr1 3378330 3384330 0.011253975 RP23-317L18.3 promoter
# 12...5 chr1 3378937 3384937 0.013481904 RP23-317L18.3 promoter
# 22...6 chr1 3463509 3469509 0.027609045  RP23-115I1.1 promoter
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D1.Sema5a.Gaba_old_5mCH.mm10.tmp"
# [1] "STR.D1.Sema5a.Gaba"
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D1.Sema5a.Gaba_young_5mCH.mm10.tmp"
#    chr   start     end Mean_ratio
# 1 chr1 3091974 3097974 0.01820576
# 2 chr1 3246935 3252935 0.01966435
# 3 chr1 3262347 3268347 0.02532016
# 4 chr1 3286601 3292601 0.02640723
# 5 chr1 3290706 3296706 0.02554801
# 6 chr1 3378330 3384330 0.01921437
#    chr   start     end Mean_ratio
# 1 chr1 3091974 3097974 0.01693075
# 2 chr1 3246935 3252935 0.01930004
# 3 chr1 3262347 3268347 0.01558345
# 4 chr1 3286601 3292601 0.02052631
# 5 chr1 3290706 3296706 0.02029215
# 6 chr1 3378330 3384330 0.01070960
# [1] "Combined old data:"
#           chr   start     end  Mean_ratio     gene_name  element
# 2...1    chr1 3246935 3252935 0.019664350 RP23-317L18.1 promoter
# 6...2    chr1 3378330 3384330 0.019214370 RP23-317L18.3 promoter
# 14...3   chr1 3463509 3469509 0.013733849  RP23-115I1.1 promoter
# 14.1...4 chr1 3463509 3469509 0.013733849  RP23-115I1.6 promoter
# 18...5   chr1 3668024 3674024 0.008413924          Xkr4 promoter
# 19...6   chr1 3668778 3674778 0.011041081          Xkr4 promoter
# [1] "Combined young data:"
#           chr   start     end  Mean_ratio     gene_name  element
# 2...1    chr1 3246935 3252935 0.019300045 RP23-317L18.1 promoter
# 6...2    chr1 3378330 3384330 0.010709595 RP23-317L18.3 promoter
# 14...3   chr1 3463509 3469509 0.010705819  RP23-115I1.1 promoter
# 14.1...4 chr1 3463509 3469509 0.010705819  RP23-115I1.6 promoter
# 18...5   chr1 3668024 3674024 0.008242074          Xkr4 promoter
# 19...6   chr1 3668778 3674778 0.012129265          Xkr4 promoter
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D2.Gaba_old_5mCH.mm10.tmp"
# [1] "STR.D2.Gaba"
# [1] "/share/analysisdata/Methyl/public/TSO/yangfa/analysis/old_young/ATAC_DNA_DEG_20250216/output/01_mCH_open_peak//STR.D2.Gaba_young_5mCH.mm10.tmp"
#    chr   start     end Mean_ratio
# 1 chr1 3009729 3015729 0.01678885
# 2 chr1 3091974 3097974 0.01780705
# 3 chr1 3097946 3103946 0.01838723
# 4 chr1 3164635 3170635 0.01949703
# 5 chr1 3204202 3210202 0.01608034
# 6 chr1 3216484 3222484 0.01999974
#    chr   start     end Mean_ratio
# 1 chr1 3009729 3015729 0.01541733
# 2 chr1 3091974 3097974 0.01648002
# 3 chr1 3097946 3103946 0.01784238
# 4 chr1 3164635 3170635 0.01838184
# 5 chr1 3204202 3210202 0.01572810
# 6 chr1 3216484 3222484 0.01843783
# [1] "Combined old data:"
#         chr   start     end Mean_ratio     gene_name  element
# 3...1  chr1 3097946 3103946 0.01838723       Gm26206 promoter
# 7...2  chr1 3246935 3252935 0.01677355 RP23-317L18.1 promoter
# 17...3 chr1 3368714 3374714 0.02036969 RP23-317L18.4 promoter
# 18...4 chr1 3378330 3384330 0.01693978 RP23-317L18.3 promoter
# 19...5 chr1 3378937 3384937 0.01719218 RP23-317L18.3 promoter
# 31...6 chr1 3463509 3469509 0.01417282  RP23-115I1.1 promoter
# [1] "Combined young data:"
#         chr   start     end Mean_ratio     gene_name  element
# 3...1  chr1 3097946 3103946 0.01784238       Gm26206 promoter
# 7...2  chr1 3246935 3252935 0.01591482 RP23-317L18.1 promoter
# 17...3 chr1 3368714 3374714 0.01859561 RP23-317L18.4 promoter
# 18...4 chr1 3378330 3384330 0.01536200 RP23-317L18.3 promoter
# 19...5 chr1 3378937 3384937 0.01546202 RP23-317L18.3 promoter
# 31...6 chr1 3463509 3469509 0.01309536  RP23-115I1.1 promoter

# %%
final_result <- bind_rows(result_list)

# %%
head(final_result);dim(final_result)
# Out:
#   subclass           peak                 gene_name     old_young_mean_ratio
# 1 ACB-BST-FS.D1.Gaba chr1:3246935-3252935 RP23-317L18.1  0.005890571
# 2 ACB-BST-FS.D1.Gaba chr1:3368714-3374714 RP23-317L18.4  0.051767391
# 3 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.1  -0.010710417
# 4 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.6  -0.010710417
# 5 ACB-BST-FS.D1.Gaba chr1:3668024-3674024 Xkr4           0.003502728
# 6 ACB-BST-FS.D1.Gaba chr1:3668778-3674778 Xkr4           0.002226372
#   modification element
# 1 hmCG         promoter
# 2 hmCG         promoter
# 3 hmCG         promoter
# 4 hmCG         promoter
# 5 hmCG         promoter
# 6 hmCG         promoter
# [1] 17781216        6

# %%
final_result
# Out:
#          subclass           peak                     gene_name
# 1        ACB-BST-FS.D1.Gaba chr1:3246935-3252935     RP23-317L18.1
# 2        ACB-BST-FS.D1.Gaba chr1:3368714-3374714     RP23-317L18.4
# 3        ACB-BST-FS.D1.Gaba chr1:3463509-3469509     RP23-115I1.1
# 4        ACB-BST-FS.D1.Gaba chr1:3463509-3469509     RP23-115I1.6
# 5        ACB-BST-FS.D1.Gaba chr1:3668024-3674024     Xkr4
# 6        ACB-BST-FS.D1.Gaba chr1:3668778-3674778     Xkr4
# 7        ACB-BST-FS.D1.Gaba chr1:3669297-3675297     Xkr4
# 17781204 STR.D2.Gaba        chrY:1111228-1117228     Uty
# 17781205 STR.D2.Gaba        chrY:1166826-1172826     Uty
# 17781206 STR.D2.Gaba        chrY:1193327-1199327     Uty
# 17781207 STR.D2.Gaba        chrY:1242778-1248778     Uty
# 17781208 STR.D2.Gaba        chrY:1283621-1289621     Ddx3y
# 17781209 STR.D2.Gaba        chrY:90758472-90764472   RP24-500I4.1
# 17781210 STR.D2.Gaba        chrY:90795329-90801329   Gm47283
# 17781211 STR.D2.Gaba        chrY:90796364-90802364   Gm47283
# 17781212 STR.D2.Gaba        chrY:90797781-90803781   Gm47283
# 17781213 STR.D2.Gaba        chrY:90800638-90806638   Gm47283
# 17781214 STR.D2.Gaba        chrY:90802097-90808097   Gm47283
# 17781215 STR.D2.Gaba        chrY:90804746-90810746   Gm47283
# 17781216 STR.D2.Gaba        chrY:90805837-90811837   Gm47283
#          old_young_mean_ratio modification element
# 1         0.005890571         hmCG         promoter
# 2         0.051767391         hmCG         promoter
# 3        -0.010710417         hmCG         promoter
# 4        -0.010710417         hmCG         promoter
# 5         0.003502728         hmCG         promoter
# 6         0.002226372         hmCG         promoter
# 7         0.005009716         hmCG         promoter
# 8         0.007653755         hmCG         promoter
# 9         0.003684746         hmCG         promoter
# 10        0.026024400         hmCG         promoter
# 11        0.026024400         hmCG         promoter
# 12        0.003769086         hmCG         promoter
# 13        0.008381000         hmCG         promoter
# 14        0.042530241         hmCG         promoter
# 15        0.042530241         hmCG         promoter
# 16       -0.020296860         hmCG         promoter
# 17        0.005954175         hmCG         promoter
# 18        0.009877577         hmCG         promoter
# 19        0.000891040         hmCG         promoter
# 20        0.025320492         hmCG         promoter
# 21        0.025320492         hmCG         promoter
# 22        0.032139377         hmCG         promoter
# 23       -0.010075667         hmCG         promoter
# 24       -0.016106333         hmCG         promoter
# 25        0.003751259         hmCG         promoter
# 26        0.019512056         hmCG         promoter
# 27        0.010186000         hmCG         promoter
# 28        0.029093452         hmCG         promoter
# 29        0.029093452         hmCG         promoter
# 30        0.002311648         hmCG         promoter
# ⋮        ⋮                    ⋮            ⋮
# 17781187 -0.0005437432        mCH          genebody
# 17781188 -0.0005437432        mCH          genebody
# 17781189 -0.0005437432        mCH          genebody
# 17781190  0.0000452929        mCH          genebody
# 17781191 -0.0005378365        mCH          genebody
# 17781192  0.0019314051        mCH          genebody
# 17781193  0.0018032210        mCH          genebody
# 17781194  0.0017884444        mCH          genebody
# 17781195  0.0007687700        mCH          genebody
# 17781196  0.0007687700        mCH          genebody
# 17781197  0.0014776000        mCH          genebody
# 17781198  0.0019906900        mCH          genebody
# 17781199  0.0015361750        mCH          genebody
# 17781200  0.0008763500        mCH          genebody
# 17781201 -0.0001066200        mCH          genebody
# 17781202  0.0012488650        mCH          genebody
# 17781203  0.0012652100        mCH          genebody
# 17781204  0.0012382800        mCH          genebody
# 17781205  0.0007896550        mCH          genebody
# 17781206  0.0003164450        mCH          genebody
# 17781207 -0.0003385150        mCH          genebody
# 17781208  0.0007517850        mCH          genebody
# 17781209  0.0090682083        mCH          genebody
# 17781210 -0.0039454055        mCH          genebody
# 17781211 -0.0012916341        mCH          genebody
# 17781212  0.0001833250        mCH          genebody
# 17781213  0.0000719200        mCH          genebody
# 17781214  0.0000172850        mCH          genebody
# 17781215 -0.0003734000        mCH          genebody
# 17781216 -0.0002815450        mCH          genebody

# %%
library(Seurat)
# Out:
# Warning message:
# “package ‘Seurat’ was built under R version 4.3.3”
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.3.3”
# Loading required package: sp
#
# Warning message:
# “package ‘sp’ was built under R version 4.3.2”
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t

# %%
final_result <- readRDS(paste0(indir,"/02-openPeak2Gene_old_young_methylation_element.rds"))

# %%
head(final_result);dim(final_result)
# Out:
#   subclass           peak                 gene_name     old_young_mean_ratio
# 1 ACB-BST-FS.D1.Gaba chr1:3246935-3252935 RP23-317L18.1  0.005890571
# 2 ACB-BST-FS.D1.Gaba chr1:3368714-3374714 RP23-317L18.4  0.051767391
# 3 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.1  -0.010710417
# 4 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.6  -0.010710417
# 5 ACB-BST-FS.D1.Gaba chr1:3668024-3674024 Xkr4           0.003502728
# 6 ACB-BST-FS.D1.Gaba chr1:3668778-3674778 Xkr4           0.002226372
#   modification element
# 1 hmCG         promoter
# 2 hmCG         promoter
# 3 hmCG         promoter
# 4 hmCG         promoter
# 5 hmCG         promoter
# 6 hmCG         promoter
# [1] 17781216        6

# %%
old_young_gene <- read.csv(paste0(indir,"/Deseq_total_result_k15_filter_genes_corrected.csv"))

# %%
head(old_young_gene);dim(old_young_gene)
# Out:
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 2 ENSMUSG00000100832 0.8017553 -1.176904      0.1732320 -6.793805 1.092142e-11
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
#   padj         class
# 1 4.082558e-15 L2/3 IT CTX Glut
# 2 1.684808e-10 L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut
# [1] 10267     8

# %%
unique(old_young_gene$class)
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"

# %%
table(final_result$gene_name %in% genebody$gene_name)
# Out:
#     TRUE
# 17781216

# %%
final_result$gene_id <- genebody$gene_id[match(final_result$gene_name,genebody$gene_name)]

# %%
head(final_result);dim(final_result)
# Out:
#   subclass           peak                 gene_name     old_young_mean_ratio
# 1 ACB-BST-FS.D1.Gaba chr1:3246935-3252935 RP23-317L18.1  0.005890571
# 2 ACB-BST-FS.D1.Gaba chr1:3368714-3374714 RP23-317L18.4  0.051767391
# 3 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.1  -0.010710417
# 4 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.6  -0.010710417
# 5 ACB-BST-FS.D1.Gaba chr1:3668024-3674024 Xkr4           0.003502728
# 6 ACB-BST-FS.D1.Gaba chr1:3668778-3674778 Xkr4           0.002226372
#   modification element  gene_id
# 1 hmCG         promoter ENSMUSG00000102851.1
# 2 hmCG         promoter ENSMUSG00000103377.1
# 3 hmCG         promoter ENSMUSG00000089699.1
# 4 hmCG         promoter ENSMUSG00000103025.1
# 5 hmCG         promoter ENSMUSG00000051951.5
# 6 hmCG         promoter ENSMUSG00000051951.5
# [1] 17781216        7

# %%
final_result <- final_result %>%
  mutate(gene_id = gsub("\\..*", "", gene_id))

# %%
head(final_result);dim(final_result)
# Out:
#   subclass           peak                 gene_name     old_young_mean_ratio
# 1 ACB-BST-FS.D1.Gaba chr1:3246935-3252935 RP23-317L18.1  0.005890571
# 2 ACB-BST-FS.D1.Gaba chr1:3368714-3374714 RP23-317L18.4  0.051767391
# 3 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.1  -0.010710417
# 4 ACB-BST-FS.D1.Gaba chr1:3463509-3469509 RP23-115I1.6  -0.010710417
# 5 ACB-BST-FS.D1.Gaba chr1:3668024-3674024 Xkr4           0.003502728
# 6 ACB-BST-FS.D1.Gaba chr1:3668778-3674778 Xkr4           0.002226372
#   modification element  gene_id
# 1 hmCG         promoter ENSMUSG00000102851
# 2 hmCG         promoter ENSMUSG00000103377
# 3 hmCG         promoter ENSMUSG00000089699
# 4 hmCG         promoter ENSMUSG00000103025
# 5 hmCG         promoter ENSMUSG00000051951
# 6 hmCG         promoter ENSMUSG00000051951
# [1] 17781216        7

# %%
table(final_result$gene_id %in% old_young_gene$genename)
table(old_young_gene$genename %in% final_result$gene_id)
# Out:
#    FALSE     TRUE
# 13003088  4778128
# FALSE  TRUE
#   190 10077

# %%
final_result_filter <- final_result[final_result$gene_id %in% old_young_gene$genename,]
old_young_gene_filter <- old_young_gene[old_young_gene$genename %in% final_result$gene_id,]

# %%
head(final_result_filter);dim(final_result_filter)
# Out:
#    subclass           peak                 gene_name old_young_mean_ratio
# 9  ACB-BST-FS.D1.Gaba chr1:4782746-4788746 Mrpl15     0.003684746
# 15 ACB-BST-FS.D1.Gaba chr1:5067371-5073371 Rgs20      0.042530241
# 23 ACB-BST-FS.D1.Gaba chr1:6480546-6486546 St18      -0.010075667
# 24 ACB-BST-FS.D1.Gaba chr1:6481206-6487206 St18      -0.016106333
# 35 ACB-BST-FS.D1.Gaba chr1:9542291-9548291 Adhfe1     0.005449012
# 39 ACB-BST-FS.D1.Gaba chr1:9697508-9703508 Mybl1      0.002015116
#    modification element  gene_id
# 9  hmCG         promoter ENSMUSG00000033845
# 15 hmCG         promoter ENSMUSG00000002459
# 23 hmCG         promoter ENSMUSG00000033740
# 24 hmCG         promoter ENSMUSG00000033740
# 35 hmCG         promoter ENSMUSG00000025911
# 39 hmCG         promoter ENSMUSG00000025912
# [1] 4778128       7

# %%
unique(final_result_filter$modification)
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
unique(final_result_filter$subclass)
# Out:
#  [1] "ACB-BST-FS.D1.Gaba"    "Astro-TE.NN"           "CA1-ProS.Glut"
#  [4] "CA3.Glut"              "CLA-EPd-CTX.Car3.Glut" "DG.Glut"
#  [7] "IT.AON-TT-DP.Glut"     "L2.3.IT.CTX.Glut"      "L2.3.IT.RSP.Glut"
# [10] "L4.5.IT.CTX.Glut"      "L5.ET.CTX.Glut"        "L5.IT.CTX.Glut"
# [13] "L5.NP.CTX.Glut"        "L6.CT.CTX.Glut"        "Lamp5.Gaba"
# [16] "Microglia.NN"          "OB-in.Frmd7.Gaba"      "OB-out.Frmd7.Gaba"
# [19] "OB.Eomes.Ms4a15.Glut"  "OEC.NN"                "Oligo.NN"
# [22] "OPC.NN"                "Pvalb.Gaba"            "Sncg.Gaba"
# [25] "STR.D1.Gaba"           "STR.D1.Sema5a.Gaba"    "STR.D2.Gaba"

# %%
subclass_info <- data.frame(subclass_v1=unique(final_result_filter$subclass),
                           subclass_v2=c('ACB-BST-FS D1 Gaba','Astro-TE NN','CA1-ProS Glut','CA3 Glut','CLA-EPd-CTX Car3 Glut','DG Glut','IT AON-TT-DP Glut','L2/3 IT CTX Glut',
 'L2/3 IT RSP Glut','L4/5 IT CTX Glut','L5 ET CTX Glut','L5 IT CTX Glut','L5 NP CTX Glut','L6 CT CTX Glut','Lamp5 Gaba','Microglia NN',
 'OB-in Frmd7 Gaba','OB-out Frmd7 Gaba','OB Eomes Ms4a15 Glut','OEC NN','Oligo NN','OPC NN','Pvalb Gaba',
 'Sncg Gaba','STR D1 Gaba','STR D1 Sema5a Gaba','STR D2 Gaba'))

# %%
subclass_info
# Out:
#    subclass_v1           subclass_v2
# 1  ACB-BST-FS.D1.Gaba    ACB-BST-FS D1 Gaba
# 2  Astro-TE.NN           Astro-TE NN
# 3  CA1-ProS.Glut         CA1-ProS Glut
# 4  CA3.Glut              CA3 Glut
# 5  CLA-EPd-CTX.Car3.Glut CLA-EPd-CTX Car3 Glut
# 6  DG.Glut               DG Glut
# 7  IT.AON-TT-DP.Glut     IT AON-TT-DP Glut
# 8  L2.3.IT.CTX.Glut      L2/3 IT CTX Glut
# 9  L2.3.IT.RSP.Glut      L2/3 IT RSP Glut
# 10 L4.5.IT.CTX.Glut      L4/5 IT CTX Glut
# 11 L5.ET.CTX.Glut        L5 ET CTX Glut
# 12 L5.IT.CTX.Glut        L5 IT CTX Glut
# 13 L5.NP.CTX.Glut        L5 NP CTX Glut
# 14 L6.CT.CTX.Glut        L6 CT CTX Glut
# 15 Lamp5.Gaba            Lamp5 Gaba
# 16 Microglia.NN          Microglia NN
# 17 OB-in.Frmd7.Gaba      OB-in Frmd7 Gaba
# 18 OB-out.Frmd7.Gaba     OB-out Frmd7 Gaba
# 19 OB.Eomes.Ms4a15.Glut  OB Eomes Ms4a15 Glut
# 20 OEC.NN                OEC NN
# 21 Oligo.NN              Oligo NN
# 22 OPC.NN                OPC NN
# 23 Pvalb.Gaba            Pvalb Gaba
# 24 Sncg.Gaba             Sncg Gaba
# 25 STR.D1.Gaba           STR D1 Gaba
# 26 STR.D1.Sema5a.Gaba    STR D1 Sema5a Gaba
# 27 STR.D2.Gaba           STR D2 Gaba

# %%
final_result_filter$subclass <- subclass_info$subclass_v2[match(final_result_filter$subclass,subclass_info$subclass_v1)]

# %%
head(final_result_filter);dim(final_result_filter)
# Out:
#    subclass           peak                 gene_name old_young_mean_ratio
# 9  ACB-BST-FS D1 Gaba chr1:4782746-4788746 Mrpl15     0.003684746
# 15 ACB-BST-FS D1 Gaba chr1:5067371-5073371 Rgs20      0.042530241
# 23 ACB-BST-FS D1 Gaba chr1:6480546-6486546 St18      -0.010075667
# 24 ACB-BST-FS D1 Gaba chr1:6481206-6487206 St18      -0.016106333
# 35 ACB-BST-FS D1 Gaba chr1:9542291-9548291 Adhfe1     0.005449012
# 39 ACB-BST-FS D1 Gaba chr1:9697508-9703508 Mybl1      0.002015116
#    modification element  gene_id
# 9  hmCG         promoter ENSMUSG00000033845
# 15 hmCG         promoter ENSMUSG00000002459
# 23 hmCG         promoter ENSMUSG00000033740
# 24 hmCG         promoter ENSMUSG00000033740
# 35 hmCG         promoter ENSMUSG00000025911
# 39 hmCG         promoter ENSMUSG00000025912
# [1] 4778128       7

# %%
head(old_young_gene_filter);dim(old_young_gene_filter)
# Out:
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 2 ENSMUSG00000100832 0.8017553 -1.176904      0.1732320 -6.793805 1.092142e-11
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
#   padj         class
# 1 4.082558e-15 L2/3 IT CTX Glut
# 2 1.684808e-10 L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut
# [1] 10077     8

# %%
length(unique(final_result_filter$gene_id))
# Out:
# [1] 6740

# %%
length(unique(old_young_gene_filter$genename))
# Out:
# [1] 6740

# %%
final_result_filter_genebody <- final_result_filter[final_result_filter$element == "genebody",]
final_result_filter_promoter <- final_result_filter[final_result_filter$element == "promoter",]

# %%
head(final_result_filter_genebody);dim(final_result_filter_genebody)
# Out:
#       subclass           peak                 gene_name old_young_mean_ratio
# 26776 ACB-BST-FS D1 Gaba chr1:4782746-4788746 Mrpl15    0.003684746
# 26783 ACB-BST-FS D1 Gaba chr1:4923512-4929512 Rgs20     0.008381000
# 26785 ACB-BST-FS D1 Gaba chr1:4932056-4938056 Rgs20     0.012931617
# 26786 ACB-BST-FS D1 Gaba chr1:4993396-4999396 Rgs20     0.008544030
# 26787 ACB-BST-FS D1 Gaba chr1:5004509-5010509 Rgs20     0.014063258
# 26788 ACB-BST-FS D1 Gaba chr1:5016450-5022450 Rgs20     0.020335745
#       modification element  gene_id
# 26776 hmCG         genebody ENSMUSG00000033845
# 26783 hmCG         genebody ENSMUSG00000002459
# 26785 hmCG         genebody ENSMUSG00000002459
# 26786 hmCG         genebody ENSMUSG00000002459
# 26787 hmCG         genebody ENSMUSG00000002459
# 26788 hmCG         genebody ENSMUSG00000002459
# [1] 3817992       7

# %%
head(final_result_filter_promoter);dim(final_result_filter_promoter)
# Out:
#    subclass           peak                 gene_name old_young_mean_ratio
# 9  ACB-BST-FS D1 Gaba chr1:4782746-4788746 Mrpl15     0.003684746
# 15 ACB-BST-FS D1 Gaba chr1:5067371-5073371 Rgs20      0.042530241
# 23 ACB-BST-FS D1 Gaba chr1:6480546-6486546 St18      -0.010075667
# 24 ACB-BST-FS D1 Gaba chr1:6481206-6487206 St18      -0.016106333
# 35 ACB-BST-FS D1 Gaba chr1:9542291-9548291 Adhfe1     0.005449012
# 39 ACB-BST-FS D1 Gaba chr1:9697508-9703508 Mybl1      0.002015116
#    modification element  gene_id
# 9  hmCG         promoter ENSMUSG00000033845
# 15 hmCG         promoter ENSMUSG00000002459
# 23 hmCG         promoter ENSMUSG00000033740
# 24 hmCG         promoter ENSMUSG00000033740
# 35 hmCG         promoter ENSMUSG00000025911
# 39 hmCG         promoter ENSMUSG00000025912
# [1] 960136      7

# %%
old_young_gene_filter$label <- paste0(old_young_gene_filter$genename,"_",old_young_gene_filter$class)

# %%
head(old_young_gene_filter);dim(old_young_gene_filter)
# Out:
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 2 ENSMUSG00000100832 0.8017553 -1.176904      0.1732320 -6.793805 1.092142e-11
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
#   padj         class            label
# 1 4.082558e-15 L2/3 IT CTX Glut ENSMUSG00000087131_L2/3 IT CTX Glut
# 2 1.684808e-10 L2/3 IT CTX Glut ENSMUSG00000100832_L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut ENSMUSG00000101741_L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut ENSMUSG00000038242_L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut ENSMUSG00000026031_L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut ENSMUSG00000025946_L2/3 IT CTX Glut
# [1] 10077     9

# %%
final_result_filter_genebody$label <- paste0(final_result_filter_genebody$gene_id,"_",final_result_filter_genebody$subclass)
final_result_filter_promoter$label <- paste0(final_result_filter_promoter$gene_id,"_",final_result_filter_promoter$subclass)

# %%
head(final_result_filter_genebody);dim(final_result_filter_genebody)
# Out:
#       subclass           peak                 gene_name old_young_mean_ratio
# 26776 ACB-BST-FS D1 Gaba chr1:4782746-4788746 Mrpl15    0.003684746
# 26783 ACB-BST-FS D1 Gaba chr1:4923512-4929512 Rgs20     0.008381000
# 26785 ACB-BST-FS D1 Gaba chr1:4932056-4938056 Rgs20     0.012931617
# 26786 ACB-BST-FS D1 Gaba chr1:4993396-4999396 Rgs20     0.008544030
# 26787 ACB-BST-FS D1 Gaba chr1:5004509-5010509 Rgs20     0.014063258
# 26788 ACB-BST-FS D1 Gaba chr1:5016450-5022450 Rgs20     0.020335745
#       modification element  gene_id
# 26776 hmCG         genebody ENSMUSG00000033845
# 26783 hmCG         genebody ENSMUSG00000002459
# 26785 hmCG         genebody ENSMUSG00000002459
# 26786 hmCG         genebody ENSMUSG00000002459
# 26787 hmCG         genebody ENSMUSG00000002459
# 26788 hmCG         genebody ENSMUSG00000002459
#       label
# 26776 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 26783 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# 26785 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# 26786 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# 26787 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# 26788 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# [1] 3817992       8

# %%
head(final_result_filter_promoter);dim(final_result_filter_promoter)
# Out:
#    subclass           peak                 gene_name old_young_mean_ratio
# 9  ACB-BST-FS D1 Gaba chr1:4782746-4788746 Mrpl15     0.003684746
# 15 ACB-BST-FS D1 Gaba chr1:5067371-5073371 Rgs20      0.042530241
# 23 ACB-BST-FS D1 Gaba chr1:6480546-6486546 St18      -0.010075667
# 24 ACB-BST-FS D1 Gaba chr1:6481206-6487206 St18      -0.016106333
# 35 ACB-BST-FS D1 Gaba chr1:9542291-9548291 Adhfe1     0.005449012
# 39 ACB-BST-FS D1 Gaba chr1:9697508-9703508 Mybl1      0.002015116
#    modification element  gene_id
# 9  hmCG         promoter ENSMUSG00000033845
# 15 hmCG         promoter ENSMUSG00000002459
# 23 hmCG         promoter ENSMUSG00000033740
# 24 hmCG         promoter ENSMUSG00000033740
# 35 hmCG         promoter ENSMUSG00000025911
# 39 hmCG         promoter ENSMUSG00000025912
#    label
# 9  ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 15 ENSMUSG00000002459_ACB-BST-FS D1 Gaba
# 23 ENSMUSG00000033740_ACB-BST-FS D1 Gaba
# 24 ENSMUSG00000033740_ACB-BST-FS D1 Gaba
# 35 ENSMUSG00000025911_ACB-BST-FS D1 Gaba
# 39 ENSMUSG00000025912_ACB-BST-FS D1 Gaba
# [1] 960136      8

# %%
table(final_result_filter_genebody$label %in% old_young_gene_filter$label)
table(old_young_gene_filter$label %in% final_result_filter_genebody$label)

table(final_result_filter_promoter$label %in% old_young_gene_filter$label)
table(old_young_gene_filter$label %in% final_result_filter_promoter$label)
# Out:
#   FALSE    TRUE
# 3601008  216984
# FALSE  TRUE
#  1031  9046
#  FALSE   TRUE
# 908100  52036
# FALSE  TRUE
#  3020  7057

# %%
final_result_filter_genebody2 <- final_result_filter_genebody[final_result_filter_genebody$label %in% old_young_gene_filter$label,]
old_young_gene_filter_genebody <- old_young_gene_filter[old_young_gene_filter$label %in% final_result_filter_genebody$label,]

# %%
final_result_filter_promoter2 <- final_result_filter_promoter[final_result_filter_promoter$label %in% old_young_gene_filter$label,]
old_young_gene_filter_promoter <- old_young_gene_filter[old_young_gene_filter$label %in% final_result_filter_promoter$label,]

# %%
head(final_result_filter_genebody2);dim(final_result_filter_genebody2)
head(old_young_gene_filter_genebody);dim(old_young_gene_filter_genebody)

table(final_result_filter_genebody2$label %in% old_young_gene_filter_genebody$label)
table(old_young_gene_filter_genebody$label %in% final_result_filter_genebody2$label)
# Out:
#       subclass           peak                   gene_name
# 26776 ACB-BST-FS D1 Gaba chr1:4782746-4788746   Mrpl15
# 27471 ACB-BST-FS D1 Gaba chr1:44144942-44150942 Ercc5
# 27596 ACB-BST-FS D1 Gaba chr1:54247708-54253708 Ccdc150
# 28156 ACB-BST-FS D1 Gaba chr1:78901019-78907019 RP23-421G18.1
# 28157 ACB-BST-FS D1 Gaba chr1:78916927-78922927 RP23-421G18.1
# 28158 ACB-BST-FS D1 Gaba chr1:78959258-78965258 RP23-421G18.1
#       old_young_mean_ratio modification element  gene_id
# 26776 0.003684746          hmCG         genebody ENSMUSG00000033845
# 27471 0.020144535          hmCG         genebody ENSMUSG00000026048
# 27596 0.007896894          hmCG         genebody ENSMUSG00000025983
# 28156 0.042006600          hmCG         genebody ENSMUSG00000099706
# 28157 0.046517310          hmCG         genebody ENSMUSG00000099706
# 28158 0.048720250          hmCG         genebody ENSMUSG00000099706
#       label
# 26776 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 27471 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 27596 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 28156 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28157 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28158 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# [1] 216984      8
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 2 ENSMUSG00000100832 0.8017553 -1.176904      0.1732320 -6.793805 1.092142e-11
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
#   padj         class            label
# 1 4.082558e-15 L2/3 IT CTX Glut ENSMUSG00000087131_L2/3 IT CTX Glut
# 2 1.684808e-10 L2/3 IT CTX Glut ENSMUSG00000100832_L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut ENSMUSG00000101741_L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut ENSMUSG00000038242_L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut ENSMUSG00000026031_L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut ENSMUSG00000025946_L2/3 IT CTX Glut
# [1] 9046    9
#   TRUE
# 216984
# TRUE
# 9046

# %%
head(final_result_filter_promoter2);dim(final_result_filter_promoter2)
head(old_young_gene_filter_promoter);dim(old_young_gene_filter_promoter)

table(final_result_filter_promoter2$label %in% old_young_gene_filter_promoter$label)
table(old_young_gene_filter_promoter$label %in% final_result_filter_promoter2$label)
# Out:
#     subclass           peak                     gene_name
# 9   ACB-BST-FS D1 Gaba chr1:4782746-4788746     Mrpl15
# 363 ACB-BST-FS D1 Gaba chr1:44144942-44150942   Ercc5
# 420 ACB-BST-FS D1 Gaba chr1:54247708-54253708   Ccdc150
# 700 ACB-BST-FS D1 Gaba chr1:79224865-79230865   RP23-421G18.1
# 818 ACB-BST-FS D1 Gaba chr1:90600378-90606378   Cops8
# 954 ACB-BST-FS D1 Gaba chr1:119050679-119056679 Gli2
#     old_young_mean_ratio modification element  gene_id
# 9    0.0036847460        hmCG         promoter ENSMUSG00000033845
# 363  0.0201445352        hmCG         promoter ENSMUSG00000026048
# 420  0.0078968939        hmCG         promoter ENSMUSG00000025983
# 700 -0.0160831515        hmCG         promoter ENSMUSG00000099706
# 818  0.0009646452        hmCG         promoter ENSMUSG00000034432
# 954 -0.0035424182        hmCG         promoter ENSMUSG00000048402
#     label
# 9   ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 363 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 420 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 700 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 818 ENSMUSG00000034432_ACB-BST-FS D1 Gaba
# 954 ENSMUSG00000048402_ACB-BST-FS D1 Gaba
# [1] 52036     8
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
# 7 ENSMUSG00000055322 0.7313522  1.293637      0.1331039  9.719003 2.502199e-22
#   padj         class            label
# 1 4.082558e-15 L2/3 IT CTX Glut ENSMUSG00000087131_L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut ENSMUSG00000101741_L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut ENSMUSG00000038242_L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut ENSMUSG00000026031_L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut ENSMUSG00000025946_L2/3 IT CTX Glut
# 7 1.092627e-20 L2/3 IT CTX Glut ENSMUSG00000055322_L2/3 IT CTX Glut
# [1] 7057    9
#  TRUE
# 52036
# TRUE
# 7057

# %%
length(old_young_gene_filter_promoter$label);length(unique(old_young_gene_filter_promoter$label))
# Out:
# [1] 7057
# [1] 7057

# %%
length(final_result_filter_promoter2$label);length(unique(final_result_filter_promoter2$label))
# Out:
# [1] 52036
# [1] 7057

# %%
length(old_young_gene_filter_promoter$genename);length(unique(old_young_gene_filter_promoter$genename)) ## 不同celltype会有一样的基因
# Out:
# [1] 7057
# [1] 5045

# %%
final_result_filter_genebody3 <- final_result_filter_genebody2 %>% dplyr::select(-peak)
final_result_filter_promoter3 <- final_result_filter_promoter2 %>% dplyr::select(-peak)

# %%
head(final_result_filter_genebody3);dim(final_result_filter_genebody3)
head(final_result_filter_promoter3);dim(final_result_filter_promoter3)
# Out:
#       subclass           gene_name     old_young_mean_ratio modification
# 26776 ACB-BST-FS D1 Gaba Mrpl15        0.003684746          hmCG
# 27471 ACB-BST-FS D1 Gaba Ercc5         0.020144535          hmCG
# 27596 ACB-BST-FS D1 Gaba Ccdc150       0.007896894          hmCG
# 28156 ACB-BST-FS D1 Gaba RP23-421G18.1 0.042006600          hmCG
# 28157 ACB-BST-FS D1 Gaba RP23-421G18.1 0.046517310          hmCG
# 28158 ACB-BST-FS D1 Gaba RP23-421G18.1 0.048720250          hmCG
#       element  gene_id            label
# 26776 genebody ENSMUSG00000033845 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 27471 genebody ENSMUSG00000026048 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 27596 genebody ENSMUSG00000025983 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 28156 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28157 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28158 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# [1] 216984      7
#     subclass           gene_name     old_young_mean_ratio modification element
# 9   ACB-BST-FS D1 Gaba Mrpl15         0.0036847460        hmCG         promoter
# 363 ACB-BST-FS D1 Gaba Ercc5          0.0201445352        hmCG         promoter
# 420 ACB-BST-FS D1 Gaba Ccdc150        0.0078968939        hmCG         promoter
# 700 ACB-BST-FS D1 Gaba RP23-421G18.1 -0.0160831515        hmCG         promoter
# 818 ACB-BST-FS D1 Gaba Cops8          0.0009646452        hmCG         promoter
# 954 ACB-BST-FS D1 Gaba Gli2          -0.0035424182        hmCG         promoter
#     gene_id            label
# 9   ENSMUSG00000033845 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 363 ENSMUSG00000026048 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 420 ENSMUSG00000025983 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 700 ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 818 ENSMUSG00000034432 ENSMUSG00000034432_ACB-BST-FS D1 Gaba
# 954 ENSMUSG00000048402 ENSMUSG00000048402_ACB-BST-FS D1 Gaba
# [1] 52036     7

# %%
unique(final_result_filter_genebody3$modification)
unique(final_result_filter_promoter3$modification)
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
final_result_filter_promoter3$label2 <- paste0(final_result_filter_promoter3$modification,"_",final_result_filter_promoter3$label)

# %%
final_result_filter_genebody3$label2 <- paste0(final_result_filter_genebody3$modification,"_",final_result_filter_genebody3$label)

# %%
head(final_result_filter_genebody3);dim(final_result_filter_genebody3)
head(final_result_filter_promoter3);dim(final_result_filter_promoter3)
# Out:
#       subclass           gene_name     old_young_mean_ratio modification
# 26776 ACB-BST-FS D1 Gaba Mrpl15        0.003684746          hmCG
# 27471 ACB-BST-FS D1 Gaba Ercc5         0.020144535          hmCG
# 27596 ACB-BST-FS D1 Gaba Ccdc150       0.007896894          hmCG
# 28156 ACB-BST-FS D1 Gaba RP23-421G18.1 0.042006600          hmCG
# 28157 ACB-BST-FS D1 Gaba RP23-421G18.1 0.046517310          hmCG
# 28158 ACB-BST-FS D1 Gaba RP23-421G18.1 0.048720250          hmCG
#       element  gene_id            label
# 26776 genebody ENSMUSG00000033845 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 27471 genebody ENSMUSG00000026048 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 27596 genebody ENSMUSG00000025983 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 28156 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28157 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28158 genebody ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
#       label2
# 26776 hmCG_ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 27471 hmCG_ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 27596 hmCG_ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 28156 hmCG_ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28157 hmCG_ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 28158 hmCG_ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# [1] 216984      8
#     subclass           gene_name     old_young_mean_ratio modification element
# 9   ACB-BST-FS D1 Gaba Mrpl15         0.0036847460        hmCG         promoter
# 363 ACB-BST-FS D1 Gaba Ercc5          0.0201445352        hmCG         promoter
# 420 ACB-BST-FS D1 Gaba Ccdc150        0.0078968939        hmCG         promoter
# 700 ACB-BST-FS D1 Gaba RP23-421G18.1 -0.0160831515        hmCG         promoter
# 818 ACB-BST-FS D1 Gaba Cops8          0.0009646452        hmCG         promoter
# 954 ACB-BST-FS D1 Gaba Gli2          -0.0035424182        hmCG         promoter
#     gene_id            label
# 9   ENSMUSG00000033845 ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 363 ENSMUSG00000026048 ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 420 ENSMUSG00000025983 ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 700 ENSMUSG00000099706 ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 818 ENSMUSG00000034432 ENSMUSG00000034432_ACB-BST-FS D1 Gaba
# 954 ENSMUSG00000048402 ENSMUSG00000048402_ACB-BST-FS D1 Gaba
#     label2
# 9   hmCG_ENSMUSG00000033845_ACB-BST-FS D1 Gaba
# 363 hmCG_ENSMUSG00000026048_ACB-BST-FS D1 Gaba
# 420 hmCG_ENSMUSG00000025983_ACB-BST-FS D1 Gaba
# 700 hmCG_ENSMUSG00000099706_ACB-BST-FS D1 Gaba
# 818 hmCG_ENSMUSG00000034432_ACB-BST-FS D1 Gaba
# 954 hmCG_ENSMUSG00000048402_ACB-BST-FS D1 Gaba
# [1] 52036     8

# %%
length(final_result_filter_genebody3$label2);length(unique(final_result_filter_genebody3$label2))
length(final_result_filter_promoter3$label2);length(unique(final_result_filter_promoter3$label2))
# Out:
# [1] 216984
# [1] 36184
# [1] 52036
# [1] 28228

# %%
final_result_filter_genebody3_summary <- final_result_filter_genebody3 %>%
  group_by(label2) %>%
  summarise(
    subclass = dplyr::first(subclass),
    gene_name = dplyr::first(gene_name),
    old_young_mean_ratio = mean(old_young_mean_ratio, na.rm = TRUE),
    modification = dplyr::first(modification),
    element = dplyr::first(element),
    gene_id = dplyr::first(gene_id),
    label =  dplyr::first(label)
  )

# %%
head(final_result_filter_genebody3_summary);dim(final_result_filter_genebody3_summary)
# Out:
#   label2                                    subclass          gene_name
# 1 hmCG_ENSMUSG00000000001_OPC NN            OPC NN            Gnai3
# 2 hmCG_ENSMUSG00000000028_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Cdc45
# 3 hmCG_ENSMUSG00000000037_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Scml2
# 4 hmCG_ENSMUSG00000000049_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Apoh
# 5 hmCG_ENSMUSG00000000142_IT AON-TT-DP Glut IT AON-TT-DP Glut Axin2
# 6 hmCG_ENSMUSG00000000159_DG Glut           DG Glut           Igsf5
#   old_young_mean_ratio modification element  gene_id
# 1 0.01298853           hmCG         genebody ENSMUSG00000000001
# 2 0.01438932           hmCG         genebody ENSMUSG00000000028
# 3 0.05920417           hmCG         genebody ENSMUSG00000000037
# 4 0.03126209           hmCG         genebody ENSMUSG00000000049
# 5 0.03012396           hmCG         genebody ENSMUSG00000000142
# 6 0.02911288           hmCG         genebody ENSMUSG00000000159
#   label
# 1 ENSMUSG00000000001_OPC NN
# 2 ENSMUSG00000000028_OB-in Frmd7 Gaba
# 3 ENSMUSG00000000037_OB-in Frmd7 Gaba
# 4 ENSMUSG00000000049_OB-in Frmd7 Gaba
# 5 ENSMUSG00000000142_IT AON-TT-DP Glut
# 6 ENSMUSG00000000159_DG Glut
# [1] 36184     8

# %%
length(final_result_filter_genebody3_summary$label);length(unique(final_result_filter_genebody3_summary$label))
length(final_result_filter_genebody3_summary$label2);length(unique(final_result_filter_genebody3_summary$label2))
# Out:
# [1] 36184
# [1] 9046
# [1] 36184
# [1] 36184

# %%
head(final_result_filter_genebody3_summary);dim(final_result_filter_genebody3_summary)
# Out:
#   label2                                    subclass          gene_name
# 1 hmCG_ENSMUSG00000000001_OPC NN            OPC NN            Gnai3
# 2 hmCG_ENSMUSG00000000028_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Cdc45
# 3 hmCG_ENSMUSG00000000037_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Scml2
# 4 hmCG_ENSMUSG00000000049_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Apoh
# 5 hmCG_ENSMUSG00000000142_IT AON-TT-DP Glut IT AON-TT-DP Glut Axin2
# 6 hmCG_ENSMUSG00000000159_DG Glut           DG Glut           Igsf5
#   old_young_mean_ratio modification element  gene_id
# 1 0.01298853           hmCG         genebody ENSMUSG00000000001
# 2 0.01438932           hmCG         genebody ENSMUSG00000000028
# 3 0.05920417           hmCG         genebody ENSMUSG00000000037
# 4 0.03126209           hmCG         genebody ENSMUSG00000000049
# 5 0.03012396           hmCG         genebody ENSMUSG00000000142
# 6 0.02911288           hmCG         genebody ENSMUSG00000000159
#   label
# 1 ENSMUSG00000000001_OPC NN
# 2 ENSMUSG00000000028_OB-in Frmd7 Gaba
# 3 ENSMUSG00000000037_OB-in Frmd7 Gaba
# 4 ENSMUSG00000000049_OB-in Frmd7 Gaba
# 5 ENSMUSG00000000142_IT AON-TT-DP Glut
# 6 ENSMUSG00000000159_DG Glut
# [1] 36184     8

# %%
head(old_young_gene_filter_genebody);dim(old_young_gene_filter_genebody)
# Out:
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 2 ENSMUSG00000100832 0.8017553 -1.176904      0.1732320 -6.793805 1.092142e-11
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
#   padj         class            label
# 1 4.082558e-15 L2/3 IT CTX Glut ENSMUSG00000087131_L2/3 IT CTX Glut
# 2 1.684808e-10 L2/3 IT CTX Glut ENSMUSG00000100832_L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut ENSMUSG00000101741_L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut ENSMUSG00000038242_L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut ENSMUSG00000026031_L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut ENSMUSG00000025946_L2/3 IT CTX Glut
# [1] 9046    9

# %%
final_result_filter_promoter3_summary <- final_result_filter_promoter3 %>%
  group_by(label2) %>%
  summarise(
    subclass = dplyr::first(subclass),
    gene_name = dplyr::first(gene_name),
    old_young_mean_ratio = mean(old_young_mean_ratio, na.rm = TRUE),
    modification = dplyr::first(modification),
    element = dplyr::first(element),
    gene_id = dplyr::first(gene_id),
    label = dplyr::first(label)
  )

# %%
length(final_result_filter_promoter3_summary$label);length(unique(final_result_filter_promoter3_summary$label))
length(final_result_filter_promoter3_summary$label2);length(unique(final_result_filter_promoter3_summary$label2))
# Out:
# [1] 28228
# [1] 7057
# [1] 28228
# [1] 28228

# %%
head(final_result_filter_promoter3_summary);dim(final_result_filter_promoter3_summary)
# Out:
#   label2                                    subclass          gene_name
# 1 hmCG_ENSMUSG00000000001_OPC NN            OPC NN            Gnai3
# 2 hmCG_ENSMUSG00000000028_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Cdc45
# 3 hmCG_ENSMUSG00000000037_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Scml2
# 4 hmCG_ENSMUSG00000000049_OB-in Frmd7 Gaba  OB-in Frmd7 Gaba  Apoh
# 5 hmCG_ENSMUSG00000000142_IT AON-TT-DP Glut IT AON-TT-DP Glut Axin2
# 6 hmCG_ENSMUSG00000000159_DG Glut           DG Glut           Igsf5
#   old_young_mean_ratio modification element  gene_id
# 1 0.01298853           hmCG         promoter ENSMUSG00000000001
# 2 0.01438932           hmCG         promoter ENSMUSG00000000028
# 3 0.08060862           hmCG         promoter ENSMUSG00000000037
# 4 0.02615487           hmCG         promoter ENSMUSG00000000049
# 5 0.01883503           hmCG         promoter ENSMUSG00000000142
# 6 0.04501394           hmCG         promoter ENSMUSG00000000159
#   label
# 1 ENSMUSG00000000001_OPC NN
# 2 ENSMUSG00000000028_OB-in Frmd7 Gaba
# 3 ENSMUSG00000000037_OB-in Frmd7 Gaba
# 4 ENSMUSG00000000049_OB-in Frmd7 Gaba
# 5 ENSMUSG00000000142_IT AON-TT-DP Glut
# 6 ENSMUSG00000000159_DG Glut
# [1] 28228     8

# %%
head(old_young_gene_filter_promoter);dim(old_young_gene_filter_promoter)
# Out:
#   genename           baseMean  log2FoldChange lfcSE     stat      pvalue
# 1 ENSMUSG00000087131 0.6199420  1.311331      0.1589748  8.248671 1.601654e-16
# 3 ENSMUSG00000101741 0.6772680 -1.113995      0.1766283 -6.307002 2.844913e-10
# 4 ENSMUSG00000038242 0.8710774 -1.300506      0.1954070 -6.655371 2.825859e-11
# 5 ENSMUSG00000026031 1.0232254  1.209210      0.1556598  7.768288 7.955426e-15
# 6 ENSMUSG00000025946 2.5994752 -1.086840      0.1333550 -8.149978 3.639893e-16
# 7 ENSMUSG00000055322 0.7313522  1.293637      0.1331039  9.719003 2.502199e-22
#   padj         class            label
# 1 4.082558e-15 L2/3 IT CTX Glut ENSMUSG00000087131_L2/3 IT CTX Glut
# 3 3.711624e-09 L2/3 IT CTX Glut ENSMUSG00000101741_L2/3 IT CTX Glut
# 4 4.181748e-10 L2/3 IT CTX Glut ENSMUSG00000038242_L2/3 IT CTX Glut
# 5 1.729845e-13 L2/3 IT CTX Glut ENSMUSG00000026031_L2/3 IT CTX Glut
# 6 8.922205e-15 L2/3 IT CTX Glut ENSMUSG00000025946_L2/3 IT CTX Glut
# 7 1.092627e-20 L2/3 IT CTX Glut ENSMUSG00000055322_L2/3 IT CTX Glut
# [1] 7057    9

# %%
unique(final_result_filter_promoter3_summary$modification)
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
unique(final_result_filter_genebody3_summary$modification)
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
unique(final_result_filter_genebody3_summary$subclass)
# Out:
#  [1] "OPC NN"                "OB-in Frmd7 Gaba"      "IT AON-TT-DP Glut"
#  [4] "DG Glut"               "STR D2 Gaba"           "OB-out Frmd7 Gaba"
#  [7] "STR D1 Sema5a Gaba"    "Astro-TE NN"           "L2/3 IT RSP Glut"
# [10] "L6 CT CTX Glut"        "Oligo NN"              "CLA-EPd-CTX Car3 Glut"
# [13] "ACB-BST-FS D1 Gaba"    "L4/5 IT CTX Glut"      "CA1-ProS Glut"
# [16] "L5 ET CTX Glut"        "CA3 Glut"              "Lamp5 Gaba"
# [19] "L2/3 IT CTX Glut"      "Pvalb Gaba"            "OB Eomes Ms4a15 Glut"
# [22] "L5 IT CTX Glut"        "Sncg Gaba"             "OEC NN"
# [25] "L5 NP CTX Glut"        "STR D1 Gaba"

# %%
levels(final_result_filter_genebody3_summary$subclass)
# Out:
# NULL

# %%
subclass_order <- unlist(strsplit("L2/3 IT CTX Glut
L4/5 IT CTX Glut
L5 IT CTX Glut
IT AON-TT-DP Glut
L2/3 IT RSP Glut
L5 ET CTX Glut
CA1-ProS Glut
CA3 Glut
CLA-EPd-CTX Car3 Glut
L5 NP CTX Glut
L6 CT CTX Glut
DG Glut
OB Eomes Ms4a15 Glut
OB-in Frmd7 Gaba
OB-out Frmd7 Gaba
Sncg Gaba
Lamp5 Gaba
Pvalb Gaba
STR D1 Gaba
STR D2 Gaba
STR D1 Sema5a Gaba
ACB-BST-FS D1 Gaba
Astro-TE NN
Oligo NN
OPC NN
OEC NN","\n"))

subclass_order
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"

# %%
final_result_filter_genebody3_summary$subclass <- factor(final_result_filter_genebody3_summary$subclass,levels = subclass_order)

# %%
levels(final_result_filter_genebody3_summary$subclass)
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"

# %%
unique(final_result_filter_promoter3_summary$subclass)
# Out:
#  [1] "OPC NN"                "OB-in Frmd7 Gaba"      "IT AON-TT-DP Glut"
#  [4] "DG Glut"               "STR D2 Gaba"           "STR D1 Sema5a Gaba"
#  [7] "Astro-TE NN"           "L6 CT CTX Glut"        "Oligo NN"
# [10] "CLA-EPd-CTX Car3 Glut" "ACB-BST-FS D1 Gaba"    "L4/5 IT CTX Glut"
# [13] "L2/3 IT RSP Glut"      "L5 ET CTX Glut"        "CA1-ProS Glut"
# [16] "CA3 Glut"              "Lamp5 Gaba"            "L2/3 IT CTX Glut"
# [19] "OB-out Frmd7 Gaba"     "Pvalb Gaba"            "OB Eomes Ms4a15 Glut"
# [22] "L5 IT CTX Glut"        "Sncg Gaba"             "OEC NN"
# [25] "L5 NP CTX Glut"        "STR D1 Gaba"

# %%
levels(final_result_filter_promoter3_summary$subclass)
# Out:
# NULL

# %%
final_result_filter_promoter3_summary$subclass <- factor(final_result_filter_promoter3_summary$subclass,levels = subclass_order)

# %%
levels(final_result_filter_promoter3_summary$subclass)
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "IT AON-TT-DP Glut"     "L2/3 IT RSP Glut"      "L5 ET CTX Glut"
#  [7] "CA1-ProS Glut"         "CA3 Glut"              "CLA-EPd-CTX Car3 Glut"
# [10] "L5 NP CTX Glut"        "L6 CT CTX Glut"        "DG Glut"
# [13] "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"      "OB-out Frmd7 Gaba"
# [16] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [19] "STR D1 Gaba"           "STR D2 Gaba"           "STR D1 Sema5a Gaba"
# [22] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [25] "OPC NN"                "OEC NN"

# %%
split_data_promoter <- split(final_result_filter_promoter3_summary, final_result_filter_promoter3_summary$modification)

# %%
split_data_promoter
# Out:
# $hmCG
# # A tibble: 7,057 × 8
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 mCH_ENS… OPC NN   Gnai3                0.0000467 mCH          promot… ENSMUS…
#  2 mCH_ENS… OB-in F… Cdc45               -0.000804  mCH          promot… ENSMUS…
#  3 mCH_ENS… OB-in F… Scml2                0.00179   mCH          promot… ENSMUS…
#  4 mCH_ENS… OB-in F… Apoh                -0.000106  mCH          promot… ENSMUS…
#  5 mCH_ENS… IT AON-… Axin2                0.000552  mCH          promot… ENSMUS…
#  6 mCH_ENS… DG Glut  Igsf5                0.000979  mCH          promot… ENSMUS…
#  7 mCH_ENS… STR D2 … Igsf5                0.00141   mCH          promot… ENSMUS…
#  8 mCH_ENS… DG Glut  Sdhd                -0.000249  mCH          promot… ENSMUS…
#  9 mCH_ENS… STR D1 … Nalcn               -0.00428   mCH          promot… ENSMUS…
# 10 mCH_ENS… OB-in F… Clec2g              -0.0000763 mCH          promot… ENSMUS…
# # ℹ 7,047 more rows
# # ℹ 1 more variable: label <chr>

# %%
plots_promoter <- list()

# %%
modifications <- unique(final_result_filter_promoter3_summary$modification)
modifications
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
library(ggplot2)
library(patchwork)
# Out:
# Warning message:
# “package ‘patchwork’ was built under R version 4.3.2”

# %%
split_data_genebody <- split(final_result_filter_genebody3_summary, final_result_filter_genebody3_summary$modification)

# %%
split_data_genebody
# Out:
# $hmCG
# # A tibble: 9,046 × 8
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 hmCG_EN… OPC NN   Gnai3                  0.0130  hmCG         genebo… ENSMUS…
#  2 hmCG_EN… OB-in F… Cdc45                  0.0144  hmCG         genebo… ENSMUS…
#  3 hmCG_EN… OB-in F… Scml2                  0.0592  hmCG         genebo… ENSMUS…
#  4 hmCG_EN… OB-in F… Apoh                   0.0313  hmCG         genebo… ENSMUS…
#  5 hmCG_EN… IT AON-… Axin2                  0.0301  hmCG         genebo… ENSMUS…
#  6 hmCG_EN… DG Glut  Igsf5                  0.0291  hmCG         genebo… ENSMUS…
#  7 hmCG_EN… OB-in F… Igsf5                  0.0331  hmCG         genebo… ENSMUS…
#  8 hmCG_EN… STR D2 … Igsf5                  0.0148  hmCG         genebo… ENSMUS…
#  9 hmCG_EN… DG Glut  Sdhd                   0.0253  hmCG         genebo… ENSMUS…
# 10 hmCG_EN… OB-out … Ccnd2                  0.00437 hmCG         genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 1 more variable: label <chr>
#
# $hmCH
# # A tibble: 9,046 × 8
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 hmCH_EN… OPC NN   Gnai3               -0.0000540 hmCH         genebo… ENSMUS…
#  2 hmCH_EN… OB-in F… Cdc45               -0.00115   hmCH         genebo… ENSMUS…
#  3 hmCH_EN… OB-in F… Scml2                0.000435  hmCH         genebo… ENSMUS…
#  4 hmCH_EN… OB-in F… Apoh                 0.000285  hmCH         genebo… ENSMUS…
#  5 hmCH_EN… IT AON-… Axin2               -0.000544  hmCH         genebo… ENSMUS…
#  6 hmCH_EN… DG Glut  Igsf5               -0.000242  hmCH         genebo… ENSMUS…
#  7 hmCH_EN… OB-in F… Igsf5               -0.0000479 hmCH         genebo… ENSMUS…
#  8 hmCH_EN… STR D2 … Igsf5               -0.000259  hmCH         genebo… ENSMUS…
#  9 hmCH_EN… DG Glut  Sdhd                 0.000146  hmCH         genebo… ENSMUS…
# 10 hmCH_EN… OB-out … Ccnd2               -0.00195   hmCH         genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 1 more variable: label <chr>
#
# $mCG
# # A tibble: 9,046 × 8
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 mCG_ENS… OPC NN   Gnai3                 -0.0165  mCG          genebo… ENSMUS…
#  2 mCG_ENS… OB-in F… Cdc45                  0.00193 mCG          genebo… ENSMUS…
#  3 mCG_ENS… OB-in F… Scml2                  0.00599 mCG          genebo… ENSMUS…
#  4 mCG_ENS… OB-in F… Apoh                   0.00182 mCG          genebo… ENSMUS…
#  5 mCG_ENS… IT AON-… Axin2                 -0.0138  mCG          genebo… ENSMUS…
#  6 mCG_ENS… DG Glut  Igsf5                 -0.00575 mCG          genebo… ENSMUS…
#  7 mCG_ENS… OB-in F… Igsf5                 -0.00690 mCG          genebo… ENSMUS…
#  8 mCG_ENS… STR D2 … Igsf5                  0.0110  mCG          genebo… ENSMUS…
#  9 mCG_ENS… DG Glut  Sdhd                   0.00487 mCG          genebo… ENSMUS…
# 10 mCG_ENS… OB-out … Ccnd2                  0.0163  mCG          genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 1 more variable: label <chr>
#
# $mCH
# # A tibble: 9,046 × 8
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 mCH_ENS… OPC NN   Gnai3                0.0000467 mCH          genebo… ENSMUS…
#  2 mCH_ENS… OB-in F… Cdc45               -0.000804  mCH          genebo… ENSMUS…
#  3 mCH_ENS… OB-in F… Scml2                0.00130   mCH          genebo… ENSMUS…
#  4 mCH_ENS… OB-in F… Apoh                 0.00110   mCH          genebo… ENSMUS…
#  5 mCH_ENS… IT AON-… Axin2               -0.000850  mCH          genebo… ENSMUS…
#  6 mCH_ENS… DG Glut  Igsf5               -0.000495  mCH          genebo… ENSMUS…
#  7 mCH_ENS… OB-in F… Igsf5                0.000686  mCH          genebo… ENSMUS…
#  8 mCH_ENS… STR D2 … Igsf5                0.000646  mCH          genebo… ENSMUS…
#  9 mCH_ENS… DG Glut  Sdhd                -0.000249  mCH          genebo… ENSMUS…
# 10 mCH_ENS… OB-out … Ccnd2                0.00499   mCH          genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 1 more variable: label <chr>

# %%
split_data_genebody[["hmCG"]][split_data_genebody[["hmCG"]]$subclass == "STR D1 Gaba",]
# Out:
#   label2                              subclass    gene_name
# 1 hmCG_ENSMUSG00000036469_STR D1 Gaba STR D1 Gaba March1
#   old_young_mean_ratio modification element  gene_id
# 1 0.04180724           hmCG         genebody ENSMUSG00000036469
#   label
# 1 ENSMUSG00000036469_STR D1 Gaba

# %%
split_data_genebody[["hmCG"]][split_data_genebody[["hmCG"]]$subclass == "STR D2 Gaba",]
# Out:
#     label2                              subclass    gene_name
# 1   hmCG_ENSMUSG00000000159_STR D2 Gaba STR D2 Gaba Igsf5
# 2   hmCG_ENSMUSG00000000290_STR D2 Gaba STR D2 Gaba Itgb2
# 3   hmCG_ENSMUSG00000000440_STR D2 Gaba STR D2 Gaba Pparg
# 4   hmCG_ENSMUSG00000000901_STR D2 Gaba STR D2 Gaba Mmp11
# 5   hmCG_ENSMUSG00000001027_STR D2 Gaba STR D2 Gaba Scn4a
# 6   hmCG_ENSMUSG00000001741_STR D2 Gaba STR D2 Gaba Il16
# 7   hmCG_ENSMUSG00000001870_STR D2 Gaba STR D2 Gaba Ltbp1
# 8   hmCG_ENSMUSG00000001995_STR D2 Gaba STR D2 Gaba Sipa1l2
# 9   hmCG_ENSMUSG00000002486_STR D2 Gaba STR D2 Gaba Tchp
# 10  hmCG_ENSMUSG00000003545_STR D2 Gaba STR D2 Gaba Fosb
# 11  hmCG_ENSMUSG00000004341_STR D2 Gaba STR D2 Gaba Gpx6
# 12  hmCG_ENSMUSG00000004415_STR D2 Gaba STR D2 Gaba Col26a1
# 13  hmCG_ENSMUSG00000004668_STR D2 Gaba STR D2 Gaba Abca13
# 14  hmCG_ENSMUSG00000005087_STR D2 Gaba STR D2 Gaba Cd44
# 15  hmCG_ENSMUSG00000005107_STR D2 Gaba STR D2 Gaba Slc2a9
# 16  hmCG_ENSMUSG00000005220_STR D2 Gaba STR D2 Gaba Corin
# 17  hmCG_ENSMUSG00000005483_STR D2 Gaba STR D2 Gaba Dnajb1
# 18  hmCG_ENSMUSG00000006019_STR D2 Gaba STR D2 Gaba Dhx34
# 19  hmCG_ENSMUSG00000006204_STR D2 Gaba STR D2 Gaba AC110885.1
# 20  hmCG_ENSMUSG00000006386_STR D2 Gaba STR D2 Gaba Tek
# 21  hmCG_ENSMUSG00000006800_STR D2 Gaba STR D2 Gaba Sulf2
# 22  hmCG_ENSMUSG00000006850_STR D2 Gaba STR D2 Gaba Tmco6
# 23  hmCG_ENSMUSG00000007030_STR D2 Gaba STR D2 Gaba Vwa7
# 24  hmCG_ENSMUSG00000007646_STR D2 Gaba STR D2 Gaba Rad51c
# 25  hmCG_ENSMUSG00000007721_STR D2 Gaba STR D2 Gaba Ccdc124
# 26  hmCG_ENSMUSG00000007892_STR D2 Gaba STR D2 Gaba Rplp1
# 27  hmCG_ENSMUSG00000008999_STR D2 Gaba STR D2 Gaba Bmp7
# 28  hmCG_ENSMUSG00000009376_STR D2 Gaba STR D2 Gaba Met
# 29  hmCG_ENSMUSG00000009734_STR D2 Gaba STR D2 Gaba Pou6f2
# 30  hmCG_ENSMUSG00000010342_STR D2 Gaba STR D2 Gaba Tex14
# ⋮   ⋮                                   ⋮           ⋮
# 523 hmCG_ENSMUSG00000113134_STR D2 Gaba STR D2 Gaba RP23-183C14.3
# 524 hmCG_ENSMUSG00000113224_STR D2 Gaba STR D2 Gaba RP24-392F16.2
# 525 hmCG_ENSMUSG00000113370_STR D2 Gaba STR D2 Gaba RP23-53J21.2
# 526 hmCG_ENSMUSG00000113634_STR D2 Gaba STR D2 Gaba RP24-212D8.1
# 527 hmCG_ENSMUSG00000113669_STR D2 Gaba STR D2 Gaba RP23-49E21.2
# 528 hmCG_ENSMUSG00000113772_STR D2 Gaba STR D2 Gaba RP23-285H4.2
# 529 hmCG_ENSMUSG00000113836_STR D2 Gaba STR D2 Gaba RP24-231B8.5
# 530 hmCG_ENSMUSG00000114028_STR D2 Gaba STR D2 Gaba RP23-311G21.3
# 531 hmCG_ENSMUSG00000114038_STR D2 Gaba STR D2 Gaba RP24-207J5.1
# 532 hmCG_ENSMUSG00000114534_STR D2 Gaba STR D2 Gaba RP23-157D19.2
# 533 hmCG_ENSMUSG00000114564_STR D2 Gaba STR D2 Gaba RP24-573L8.1
# 534 hmCG_ENSMUSG00000114695_STR D2 Gaba STR D2 Gaba RP23-344L21.5
# 535 hmCG_ENSMUSG00000114715_STR D2 Gaba STR D2 Gaba RP24-189B1.3
# 536 hmCG_ENSMUSG00000114767_STR D2 Gaba STR D2 Gaba RP23-31C10.4
# 537 hmCG_ENSMUSG00000114794_STR D2 Gaba STR D2 Gaba RP23-203C5.2
# 538 hmCG_ENSMUSG00000115289_STR D2 Gaba STR D2 Gaba RP24-120I12.2
# 539 hmCG_ENSMUSG00000115432_STR D2 Gaba STR D2 Gaba RP24-535H19.1
# 540 hmCG_ENSMUSG00000115520_STR D2 Gaba STR D2 Gaba RP24-559L16.3
# 541 hmCG_ENSMUSG00000115623_STR D2 Gaba STR D2 Gaba RP23-134C5.1
# 542 hmCG_ENSMUSG00000115852_STR D2 Gaba STR D2 Gaba RP23-425F12.1
# 543 hmCG_ENSMUSG00000115970_STR D2 Gaba STR D2 Gaba RP24-544N15.3
# 544 hmCG_ENSMUSG00000116029_STR D2 Gaba STR D2 Gaba RP23-453I1.1
# 545 hmCG_ENSMUSG00000116031_STR D2 Gaba STR D2 Gaba RP24-90M17.1
# 546 hmCG_ENSMUSG00000116068_STR D2 Gaba STR D2 Gaba RP23-134E16.1
# 547 hmCG_ENSMUSG00000116520_STR D2 Gaba STR D2 Gaba RP23-125E11.1
# 548 hmCG_ENSMUSG00000116654_STR D2 Gaba STR D2 Gaba RP24-468B14.1
# 549 hmCG_ENSMUSG00000116689_STR D2 Gaba STR D2 Gaba RP24-480I8.2
# 550 hmCG_ENSMUSG00000116720_STR D2 Gaba STR D2 Gaba RP23-431I7.2
# 551 hmCG_ENSMUSG00000116920_STR D2 Gaba STR D2 Gaba RP24-485J1.1
# 552 hmCG_ENSMUSG00000116976_STR D2 Gaba STR D2 Gaba RP24-133J7.1
#     old_young_mean_ratio modification element  gene_id
# 1   0.014807826          hmCG         genebody ENSMUSG00000000159
# 2   0.024890144          hmCG         genebody ENSMUSG00000000290
# 3   0.031801286          hmCG         genebody ENSMUSG00000000440
# 4   0.009297615          hmCG         genebody ENSMUSG00000000901
# 5   0.022127499          hmCG         genebody ENSMUSG00000001027
# 548 0.02183965           hmCG         genebody ENSMUSG00000116654
# 549 0.02741222           hmCG         genebody ENSMUSG00000116689
# 550 0.01681004           hmCG         genebody ENSMUSG00000116720
# 551 0.02550543           hmCG         genebody ENSMUSG00000116920
# 552 0.02091644           hmCG         genebody ENSMUSG00000116976
#     label
# 1   ENSMUSG00000000159_STR D2 Gaba
# 2   ENSMUSG00000000290_STR D2 Gaba
# 3   ENSMUSG00000000440_STR D2 Gaba
# 4   ENSMUSG00000000901_STR D2 Gaba
# 5   ENSMUSG00000001027_STR D2 Gaba
# 6   ENSMUSG00000001741_STR D2 Gaba
# 7   ENSMUSG00000001870_STR D2 Gaba
# 8   ENSMUSG00000001995_STR D2 Gaba
# 9   ENSMUSG00000002486_STR D2 Gaba
# 10  ENSMUSG00000003545_STR D2 Gaba
# 11  ENSMUSG00000004341_STR D2 Gaba
# 12  ENSMUSG00000004415_STR D2 Gaba
# 13  ENSMUSG00000004668_STR D2 Gaba
# 14  ENSMUSG00000005087_STR D2 Gaba
# 15  ENSMUSG00000005107_STR D2 Gaba
# 16  ENSMUSG00000005220_STR D2 Gaba
# 17  ENSMUSG00000005483_STR D2 Gaba
# 18  ENSMUSG00000006019_STR D2 Gaba
# 19  ENSMUSG00000006204_STR D2 Gaba
# 20  ENSMUSG00000006386_STR D2 Gaba
# 21  ENSMUSG00000006800_STR D2 Gaba
# 22  ENSMUSG00000006850_STR D2 Gaba
# 23  ENSMUSG00000007030_STR D2 Gaba
# 24  ENSMUSG00000007646_STR D2 Gaba
# 25  ENSMUSG00000007721_STR D2 Gaba
# 26  ENSMUSG00000007892_STR D2 Gaba
# 27  ENSMUSG00000008999_STR D2 Gaba
# 28  ENSMUSG00000009376_STR D2 Gaba
# 29  ENSMUSG00000009734_STR D2 Gaba
# 30  ENSMUSG00000010342_STR D2 Gaba
# ⋮   ⋮
# 523 ENSMUSG00000113134_STR D2 Gaba
# 524 ENSMUSG00000113224_STR D2 Gaba
# 525 ENSMUSG00000113370_STR D2 Gaba
# 526 ENSMUSG00000113634_STR D2 Gaba
# 527 ENSMUSG00000113669_STR D2 Gaba
# 528 ENSMUSG00000113772_STR D2 Gaba
# 529 ENSMUSG00000113836_STR D2 Gaba
# 530 ENSMUSG00000114028_STR D2 Gaba
# 531 ENSMUSG00000114038_STR D2 Gaba
# 532 ENSMUSG00000114534_STR D2 Gaba
# 533 ENSMUSG00000114564_STR D2 Gaba
# 534 ENSMUSG00000114695_STR D2 Gaba
# 535 ENSMUSG00000114715_STR D2 Gaba
# 536 ENSMUSG00000114767_STR D2 Gaba
# 537 ENSMUSG00000114794_STR D2 Gaba
# 538 ENSMUSG00000115289_STR D2 Gaba
# 539 ENSMUSG00000115432_STR D2 Gaba
# 540 ENSMUSG00000115520_STR D2 Gaba
# 541 ENSMUSG00000115623_STR D2 Gaba
# 542 ENSMUSG00000115852_STR D2 Gaba
# 543 ENSMUSG00000115970_STR D2 Gaba
# 544 ENSMUSG00000116029_STR D2 Gaba
# 545 ENSMUSG00000116031_STR D2 Gaba
# 546 ENSMUSG00000116068_STR D2 Gaba
# 547 ENSMUSG00000116520_STR D2 Gaba
# 548 ENSMUSG00000116654_STR D2 Gaba
# 549 ENSMUSG00000116689_STR D2 Gaba
# 550 ENSMUSG00000116720_STR D2 Gaba
# 551 ENSMUSG00000116920_STR D2 Gaba
# 552 ENSMUSG00000116976_STR D2 Gaba

# %%
split_data_genebody[["mCG"]][split_data_genebody[["mCG"]]$subclass == "STR D1 Gaba",]
# Out:
#   label2                             subclass    gene_name old_young_mean_ratio
# 1 mCG_ENSMUSG00000036469_STR D1 Gaba STR D1 Gaba March1    0.005189348
#   modification element  gene_id            label
# 1 mCG          genebody ENSMUSG00000036469 ENSMUSG00000036469_STR D1 Gaba

# %%
split_data_genebody[["mCG"]][split_data_genebody[["mCG"]]$subclass == "STR D2 Gaba",]
# Out:
#     label2                             subclass    gene_name
# 1   mCG_ENSMUSG00000000159_STR D2 Gaba STR D2 Gaba Igsf5
# 2   mCG_ENSMUSG00000000290_STR D2 Gaba STR D2 Gaba Itgb2
# 3   mCG_ENSMUSG00000000440_STR D2 Gaba STR D2 Gaba Pparg
# 4   mCG_ENSMUSG00000000901_STR D2 Gaba STR D2 Gaba Mmp11
# 5   mCG_ENSMUSG00000001027_STR D2 Gaba STR D2 Gaba Scn4a
# 6   mCG_ENSMUSG00000001741_STR D2 Gaba STR D2 Gaba Il16
# 7   mCG_ENSMUSG00000001870_STR D2 Gaba STR D2 Gaba Ltbp1
# 8   mCG_ENSMUSG00000001995_STR D2 Gaba STR D2 Gaba Sipa1l2
# 9   mCG_ENSMUSG00000002486_STR D2 Gaba STR D2 Gaba Tchp
# 10  mCG_ENSMUSG00000003545_STR D2 Gaba STR D2 Gaba Fosb
# 11  mCG_ENSMUSG00000004341_STR D2 Gaba STR D2 Gaba Gpx6
# 12  mCG_ENSMUSG00000004415_STR D2 Gaba STR D2 Gaba Col26a1
# 13  mCG_ENSMUSG00000004668_STR D2 Gaba STR D2 Gaba Abca13
# 14  mCG_ENSMUSG00000005087_STR D2 Gaba STR D2 Gaba Cd44
# 15  mCG_ENSMUSG00000005107_STR D2 Gaba STR D2 Gaba Slc2a9
# 16  mCG_ENSMUSG00000005220_STR D2 Gaba STR D2 Gaba Corin
# 17  mCG_ENSMUSG00000005483_STR D2 Gaba STR D2 Gaba Dnajb1
# 18  mCG_ENSMUSG00000006019_STR D2 Gaba STR D2 Gaba Dhx34
# 19  mCG_ENSMUSG00000006204_STR D2 Gaba STR D2 Gaba AC110885.1
# 20  mCG_ENSMUSG00000006386_STR D2 Gaba STR D2 Gaba Tek
# 21  mCG_ENSMUSG00000006800_STR D2 Gaba STR D2 Gaba Sulf2
# 22  mCG_ENSMUSG00000006850_STR D2 Gaba STR D2 Gaba Tmco6
# 23  mCG_ENSMUSG00000007030_STR D2 Gaba STR D2 Gaba Vwa7
# 24  mCG_ENSMUSG00000007646_STR D2 Gaba STR D2 Gaba Rad51c
# 25  mCG_ENSMUSG00000007721_STR D2 Gaba STR D2 Gaba Ccdc124
# 26  mCG_ENSMUSG00000007892_STR D2 Gaba STR D2 Gaba Rplp1
# 27  mCG_ENSMUSG00000008999_STR D2 Gaba STR D2 Gaba Bmp7
# 28  mCG_ENSMUSG00000009376_STR D2 Gaba STR D2 Gaba Met
# 29  mCG_ENSMUSG00000009734_STR D2 Gaba STR D2 Gaba Pou6f2
# 30  mCG_ENSMUSG00000010342_STR D2 Gaba STR D2 Gaba Tex14
# ⋮   ⋮                                  ⋮           ⋮
# 523 mCG_ENSMUSG00000113134_STR D2 Gaba STR D2 Gaba RP23-183C14.3
# 524 mCG_ENSMUSG00000113224_STR D2 Gaba STR D2 Gaba RP24-392F16.2
# 525 mCG_ENSMUSG00000113370_STR D2 Gaba STR D2 Gaba RP23-53J21.2
# 526 mCG_ENSMUSG00000113634_STR D2 Gaba STR D2 Gaba RP24-212D8.1
# 527 mCG_ENSMUSG00000113669_STR D2 Gaba STR D2 Gaba RP23-49E21.2
# 528 mCG_ENSMUSG00000113772_STR D2 Gaba STR D2 Gaba RP23-285H4.2
# 529 mCG_ENSMUSG00000113836_STR D2 Gaba STR D2 Gaba RP24-231B8.5
# 530 mCG_ENSMUSG00000114028_STR D2 Gaba STR D2 Gaba RP23-311G21.3
# 531 mCG_ENSMUSG00000114038_STR D2 Gaba STR D2 Gaba RP24-207J5.1
# 532 mCG_ENSMUSG00000114534_STR D2 Gaba STR D2 Gaba RP23-157D19.2
# 533 mCG_ENSMUSG00000114564_STR D2 Gaba STR D2 Gaba RP24-573L8.1
# 534 mCG_ENSMUSG00000114695_STR D2 Gaba STR D2 Gaba RP23-344L21.5
# 535 mCG_ENSMUSG00000114715_STR D2 Gaba STR D2 Gaba RP24-189B1.3
# 536 mCG_ENSMUSG00000114767_STR D2 Gaba STR D2 Gaba RP23-31C10.4
# 537 mCG_ENSMUSG00000114794_STR D2 Gaba STR D2 Gaba RP23-203C5.2
# 538 mCG_ENSMUSG00000115289_STR D2 Gaba STR D2 Gaba RP24-120I12.2
# 539 mCG_ENSMUSG00000115432_STR D2 Gaba STR D2 Gaba RP24-535H19.1
# 540 mCG_ENSMUSG00000115520_STR D2 Gaba STR D2 Gaba RP24-559L16.3
# 541 mCG_ENSMUSG00000115623_STR D2 Gaba STR D2 Gaba RP23-134C5.1
# 542 mCG_ENSMUSG00000115852_STR D2 Gaba STR D2 Gaba RP23-425F12.1
# 543 mCG_ENSMUSG00000115970_STR D2 Gaba STR D2 Gaba RP24-544N15.3
# 544 mCG_ENSMUSG00000116029_STR D2 Gaba STR D2 Gaba RP23-453I1.1
# 545 mCG_ENSMUSG00000116031_STR D2 Gaba STR D2 Gaba RP24-90M17.1
# 546 mCG_ENSMUSG00000116068_STR D2 Gaba STR D2 Gaba RP23-134E16.1
# 547 mCG_ENSMUSG00000116520_STR D2 Gaba STR D2 Gaba RP23-125E11.1
# 548 mCG_ENSMUSG00000116654_STR D2 Gaba STR D2 Gaba RP24-468B14.1
# 549 mCG_ENSMUSG00000116689_STR D2 Gaba STR D2 Gaba RP24-480I8.2
# 535 ENSMUSG00000114715_STR D2 Gaba
# 536 ENSMUSG00000114767_STR D2 Gaba
# 537 ENSMUSG00000114794_STR D2 Gaba
# 538 ENSMUSG00000115289_STR D2 Gaba
# 539 ENSMUSG00000115432_STR D2 Gaba
# 540 ENSMUSG00000115520_STR D2 Gaba
# 541 ENSMUSG00000115623_STR D2 Gaba
# 542 ENSMUSG00000115852_STR D2 Gaba
# 543 ENSMUSG00000115970_STR D2 Gaba
# 544 ENSMUSG00000116029_STR D2 Gaba
# 545 ENSMUSG00000116031_STR D2 Gaba
# 546 ENSMUSG00000116068_STR D2 Gaba
# 547 ENSMUSG00000116520_STR D2 Gaba
# 548 ENSMUSG00000116654_STR D2 Gaba
# 549 ENSMUSG00000116689_STR D2 Gaba
# 550 ENSMUSG00000116720_STR D2 Gaba
# 551 ENSMUSG00000116920_STR D2 Gaba
# 552 ENSMUSG00000116976_STR D2 Gaba

# %%
old_young_gene_filter_genebody[old_young_gene_filter_genebody$class == "STR D1 Gaba",]
# Out:
#      genename           baseMean log2FoldChange lfcSE     stat     pvalue
# 8088 ENSMUSG00000036469 100.0116 1.412845       0.2925477 4.829451 1.369099e-06
#      padj        class       label
# 8088 0.006412859 STR D1 Gaba ENSMUSG00000036469_STR D1 Gaba

# %%
boxplots_genebody <- list()

# %%
for (mod in modifications) {
  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>% 
    inner_join(old_young_gene_filter_genebody, by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {
    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    pvalues <- merged_data %>%
      group_by(subclass) %>%
      summarise(
        positive_count = sum(log2_sign == "Positive"),
        negative_count = sum(log2_sign == "Negative"),
        p_value = ifelse(positive_count > 1 & negative_count > 1,
                         t.test(old_young_mean_ratio[log2_sign == "Positive"],
                                old_young_mean_ratio[log2_sign == "Negative"])$p.value,
                         NA_real_),
        .groups = "drop"
      ) %>%
      mutate(label = ifelse(p_value < 0.001, "***",
                            ifelse(p_value < 0.01, "**",
                                   ifelse(p_value < 0.05, "*", "ns"))))

    y_min <- min(merged_data$old_young_mean_ratio, na.rm = TRUE) - 0.05
    y_max <- max(merged_data$old_young_mean_ratio, na.rm = TRUE) + 0.2

    p <- ggplot(merged_data, aes(x = subclass, y = old_young_mean_ratio, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, position = position_dodge(width = 0.8)) +
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      geom_hline(yintercept = 0, linetype = "dashed", color = "grey50", size = 0.8) +
      geom_text(data = pvalues, aes(x = subclass, y = y_max + 0.05, label = label),
                inherit.aes = FALSE, vjust = 0, size = 3) +
      labs(
        title = paste("Boxplot for", mod),
        x = "Subclass",
        y = "Old-Young Mean Ratio",
        fill = "Log2 Fold Change"
      ) +
      scale_y_continuous(
        limits = c(y_min, y_max),
        breaks = seq(-0.05, y_max, by = 0.05)
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 45, hjust = 1, color = "black"),
        axis.text.y = element_text(color = "black"),
        axis.line = element_line(color = "black", size = 0.8), 
        panel.grid = element_blank()
      )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
## 这段也行
for (mod in modifications) {
  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>% 
    inner_join(old_young_gene_filter_genebody, by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {
    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    pvalues <- merged_data %>%
      group_by(subclass) %>%
      summarise(
        positive_count = sum(log2_sign == "Positive"),
        negative_count = sum(log2_sign == "Negative"),
        p_value = ifelse(positive_count > 1 & negative_count > 1,
                         t.test(old_young_mean_ratio[log2_sign == "Positive"],
                                old_young_mean_ratio[log2_sign == "Negative"])$p.value,
                         NA_real_),
        .groups = "drop"
      ) %>%
      mutate(label = ifelse(p_value < 0.001, "***",
                            ifelse(p_value < 0.01, "**",
                                   ifelse(p_value < 0.05, "*", "ns"))))

    print(pvalues)
    print(head(merged_data))

    p <- ggplot(merged_data, aes(x = subclass, y = old_young_mean_ratio, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, position = position_dodge(width = 0.8)) +
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      geom_hline(yintercept = 0, linetype = "dashed", color = "grey50", size = 0.8) +
      geom_text(data = pvalues, aes(x = subclass, y = max(merged_data$old_young_mean_ratio, na.rm = TRUE) + 0.2, label = label),
                inherit.aes = FALSE, vjust = 0, size = 3) +
      labs(
        title = paste("Boxplot for", mod),
        x = "Subclass",
        y = "Old-Young Mean Ratio",
        fill = "Log2 Fold Change"
      ) +
#       scale_y_continuous(
#           limits = c(-0.05,0.15),
#           breaks = seq(-0.05,0.15,
#                        by = 0.05)
#       ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 45, hjust = 1, color = "black"),
        axis.text.y = element_text(color = "black"),
        axis.line = element_line(color = "black", size = 0.8), 
        panel.grid = element_blank()
      )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}
# Out:
# # A tibble: 26 × 5
#    subclass              positive_count negative_count  p_value label
#    <fct>                          <int>          <int>    <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.0311   *
#  2 L4/5 IT CTX Glut                 207            250 0.0838   ns
#  3 L5 IT CTX Glut                   155             55 0.423    ns
#  4 IT AON-TT-DP Glut                353             71 0.442    ns
#  5 L2/3 IT RSP Glut                 177            158 0.992    ns
#  6 L5 ET CTX Glut                   160            121 0.836    ns
#  7 CA1-ProS Glut                    294            132 0.0214   *
#  8 CA3 Glut                         134             95 0.0612   ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.000338 ***
# 10 L5 NP CTX Glut                     2              7 0.745    ns
# # ℹ 16 more rows
# # A tibble: 6 × 16
#   label2    subclass gene_name old_young_mean_ratio modification element gene_id
#   <chr>     <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
# 1 hmCG_ENS… OPC NN   Gnai3                   0.0130 hmCG         genebo… ENSMUS…
# 2 hmCG_ENS… OB-in F… Cdc45                   0.0144 hmCG         genebo… ENSMUS…
# 3 hmCG_ENS… OB-in F… Scml2                   0.0592 hmCG         genebo… ENSMUS…
# 4 hmCG_ENS… OB-in F… Apoh                    0.0313 hmCG         genebo… ENSMUS…
# 5 hmCG_ENS… IT AON-… Axin2                   0.0301 hmCG         genebo… ENSMUS…
# 6 hmCG_ENS… DG Glut  Igsf5                   0.0291 hmCG         genebo… ENSMUS…
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>
# # A tibble: 26 × 5
#    subclass              positive_count negative_count p_value label
#    <fct>                          <int>          <int>   <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52  0.0409 *
#  2 L4/5 IT CTX Glut                 207            250  0.126  ns
#  3 L5 IT CTX Glut                   155             55  0.303  ns
#  4 IT AON-TT-DP Glut                353             71  0.791  ns
#  5 L2/3 IT RSP Glut                 177            158  0.753  ns
#  6 L5 ET CTX Glut                   160            121  0.703  ns
#  7 CA1-ProS Glut                    294            132  0.108  ns
#  8 CA3 Glut                         134             95  0.0679 ns
#  9 CLA-EPd-CTX Car3 Glut            155             97  0.778  ns
# 10 L5 NP CTX Glut                     2              7  0.912  ns
# # ℹ 16 more rows
# # A tibble: 6 × 16
#   label2    subclass gene_name old_young_mean_ratio modification element gene_id
#   <chr>     <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
# 1 hmCH_ENS… OPC NN   Gnai3               -0.0000540 hmCH         genebo… ENSMUS…
# 2 hmCH_ENS… OB-in F… Cdc45               -0.00115   hmCH         genebo… ENSMUS…
# 3 hmCH_ENS… OB-in F… Scml2                0.000435  hmCH         genebo… ENSMUS…
# 4 hmCH_ENS… OB-in F… Apoh                 0.000285  hmCH         genebo… ENSMUS…
# 5 hmCH_ENS… IT AON-… Axin2               -0.000544  hmCH         genebo… ENSMUS…
# 6 hmCH_ENS… DG Glut  Igsf5               -0.000242  hmCH         genebo… ENSMUS…
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>
# # A tibble: 26 × 5
#    subclass              positive_count negative_count      p_value label
#    <fct>                          <int>          <int>        <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.00000161   ***
#  2 L4/5 IT CTX Glut                 207            250 0.00408      **
#  3 L5 IT CTX Glut                   155             55 0.000343     ***
#  4 IT AON-TT-DP Glut                353             71 0.000358     ***
#  5 L2/3 IT RSP Glut                 177            158 0.000326     ***
#  6 L5 ET CTX Glut                   160            121 0.00249      **
#  7 CA1-ProS Glut                    294            132 0.0000000477 ***
#  8 CA3 Glut                         134             95 0.0756       ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.180        ns
# 10 L5 NP CTX Glut                     2              7 0.401        ns
# # ℹ 16 more rows
# # A tibble: 6 × 16
#   label2    subclass gene_name old_young_mean_ratio modification element gene_id
#   <chr>     <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
# 1 mCG_ENSM… OPC NN   Gnai3                 -0.0165  mCG          genebo… ENSMUS…
# 2 mCG_ENSM… OB-in F… Cdc45                  0.00193 mCG          genebo… ENSMUS…
# 3 mCG_ENSM… OB-in F… Scml2                  0.00599 mCG          genebo… ENSMUS…
# 4 mCG_ENSM… OB-in F… Apoh                   0.00182 mCG          genebo… ENSMUS…
# 5 mCG_ENSM… IT AON-… Axin2                 -0.0138  mCG          genebo… ENSMUS…
# 6 mCG_ENSM… DG Glut  Igsf5                 -0.00575 mCG          genebo… ENSMUS…
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>
# # A tibble: 26 × 5
#    subclass              positive_count negative_count  p_value label
#    <fct>                          <int>          <int>    <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.000930 ***
#  2 L4/5 IT CTX Glut                 207            250 0.493    ns
#  3 L5 IT CTX Glut                   155             55 0.00804  **
#  4 IT AON-TT-DP Glut                353             71 0.00389  **
#  5 L2/3 IT RSP Glut                 177            158 0.0128   *
#  6 L5 ET CTX Glut                   160            121 0.00564  **
#  7 CA1-ProS Glut                    294            132 0.619    ns
#  8 CA3 Glut                         134             95 0.734    ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.143    ns
# 10 L5 NP CTX Glut                     2              7 0.764    ns
# # ℹ 16 more rows
# # A tibble: 6 × 16
#   label2    subclass gene_name old_young_mean_ratio modification element gene_id
#   <chr>     <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
# 1 mCH_ENSM… OPC NN   Gnai3                0.0000467 mCH          genebo… ENSMUS…
# 2 mCH_ENSM… OB-in F… Cdc45               -0.000804  mCH          genebo… ENSMUS…
# 3 mCH_ENSM… OB-in F… Scml2                0.00130   mCH          genebo… ENSMUS…
# 4 mCH_ENSM… OB-in F… Apoh                 0.00110   mCH          genebo… ENSMUS…
# 5 mCH_ENSM… IT AON-… Axin2               -0.000850  mCH          genebo… ENSMUS…
# 6 mCH_ENSM… DG Glut  Igsf5               -0.000495  mCH          genebo… ENSMUS…
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>

# %%
for (mod in modifications) {
  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>% 
    inner_join(old_young_gene_filter_genebody, by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {
    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    mean_ratios <- merged_data %>%
      group_by(subclass, log2_sign) %>%
      summarise(mean_ratio = mean(old_young_mean_ratio, na.rm = TRUE), .groups = "drop")

    ratio_df <- mean_ratios %>%
      spread(key = log2_sign, value = mean_ratio) %>%
      mutate(ratio = Positive / Negative) %>%
      select(subclass, ratio)

    pvalues <- merged_data %>%
      group_by(subclass) %>%
      summarise(
        positive_count = sum(log2_sign == "Positive"),
        negative_count = sum(log2_sign == "Negative"),
        p_value = ifelse(positive_count > 1 & negative_count > 1,
                         t.test(old_young_mean_ratio[log2_sign == "Positive"],
                                old_young_mean_ratio[log2_sign == "Negative"])$p.value,
                         NA_real_),
        .groups = "drop"
      ) %>%
      mutate(label = ifelse(p_value < 0.001, "***",
                            ifelse(p_value < 0.01, "**",
                                   ifelse(p_value < 0.05, "*", "ns"))))

    result <- list(
      pvalues = pvalues,
      merged_data = merged_data,
      ratio_df = ratio_df
    )

    print(result)
    return(result)
  } else {
    message(paste("No matching data for modification:", mod))
  }
}
# Out:
# $pvalues
# # A tibble: 26 × 5
#    subclass              positive_count negative_count  p_value label
#    <fct>                          <int>          <int>    <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.0311   *
#  2 L4/5 IT CTX Glut                 207            250 0.0838   ns
#  3 L5 IT CTX Glut                   155             55 0.423    ns
#  4 IT AON-TT-DP Glut                353             71 0.442    ns
#  5 L2/3 IT RSP Glut                 177            158 0.992    ns
#  6 L5 ET CTX Glut                   160            121 0.836    ns
#  7 CA1-ProS Glut                    294            132 0.0214   *
#  8 CA3 Glut                         134             95 0.0612   ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.000338 ***
# 10 L5 NP CTX Glut                     2              7 0.745    ns
# # ℹ 16 more rows
#
# $merged_data
# # A tibble: 9,046 × 16
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 hmCG_EN… OPC NN   Gnai3                  0.0130  hmCG         genebo… ENSMUS…
#  2 hmCG_EN… OB-in F… Cdc45                  0.0144  hmCG         genebo… ENSMUS…
#  3 hmCG_EN… OB-in F… Scml2                  0.0592  hmCG         genebo… ENSMUS…
#  4 hmCG_EN… OB-in F… Apoh                   0.0313  hmCG         genebo… ENSMUS…
#  5 hmCG_EN… IT AON-… Axin2                  0.0301  hmCG         genebo… ENSMUS…
#  6 hmCG_EN… DG Glut  Igsf5                  0.0291  hmCG         genebo… ENSMUS…
#  7 hmCG_EN… OB-in F… Igsf5                  0.0331  hmCG         genebo… ENSMUS…
#  8 hmCG_EN… STR D2 … Igsf5                  0.0148  hmCG         genebo… ENSMUS…
#  9 hmCG_EN… DG Glut  Sdhd                   0.0253  hmCG         genebo… ENSMUS…
# 10 hmCG_EN… OB-out … Ccnd2                  0.00437 hmCG         genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>
#
# $ratio_df
# # A tibble: 26 × 2
#    subclass              ratio
#    <fct>                 <dbl>
#  1 L2/3 IT CTX Glut      1.13
#  2 L4/5 IT CTX Glut      1.07
#  3 L5 IT CTX Glut        1.06
#  4 IT AON-TT-DP Glut     1.06
#  5 L2/3 IT RSP Glut      0.999
#  6 L5 ET CTX Glut        0.985
#  7 CA1-ProS Glut         1.10
#  8 CA3 Glut              1.13
#  9 CLA-EPd-CTX Car3 Glut 0.740
# 10 L5 NP CTX Glut        1.74
# # ℹ 16 more rows

# %%
result
# Out:
# $pvalues
# # A tibble: 26 × 5
#    subclass              positive_count negative_count  p_value label
#    <fct>                          <int>          <int>    <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.0311   *
#  2 L4/5 IT CTX Glut                 207            250 0.0838   ns
#  3 L5 IT CTX Glut                   155             55 0.423    ns
#  4 IT AON-TT-DP Glut                353             71 0.442    ns
#  5 L2/3 IT RSP Glut                 177            158 0.992    ns
#  6 L5 ET CTX Glut                   160            121 0.836    ns
#  7 CA1-ProS Glut                    294            132 0.0214   *
#  8 CA3 Glut                         134             95 0.0612   ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.000338 ***
# 10 L5 NP CTX Glut                     2              7 0.745    ns
# # ℹ 16 more rows
#
# $merged_data
# # A tibble: 9,046 × 16
#    label2   subclass gene_name old_young_mean_ratio modification element gene_id
#    <chr>    <fct>    <chr>                    <dbl> <chr>        <chr>   <chr>
#  1 hmCG_EN… OPC NN   Gnai3                  0.0130  hmCG         genebo… ENSMUS…
#  2 hmCG_EN… OB-in F… Cdc45                  0.0144  hmCG         genebo… ENSMUS…
#  3 hmCG_EN… OB-in F… Scml2                  0.0592  hmCG         genebo… ENSMUS…
#  4 hmCG_EN… OB-in F… Apoh                   0.0313  hmCG         genebo… ENSMUS…
#  5 hmCG_EN… IT AON-… Axin2                  0.0301  hmCG         genebo… ENSMUS…
#  6 hmCG_EN… DG Glut  Igsf5                  0.0291  hmCG         genebo… ENSMUS…
#  7 hmCG_EN… OB-in F… Igsf5                  0.0331  hmCG         genebo… ENSMUS…
#  8 hmCG_EN… STR D2 … Igsf5                  0.0148  hmCG         genebo… ENSMUS…
#  9 hmCG_EN… DG Glut  Sdhd                   0.0253  hmCG         genebo… ENSMUS…
# 10 hmCG_EN… OB-out … Ccnd2                  0.00437 hmCG         genebo… ENSMUS…
# # ℹ 9,036 more rows
# # ℹ 9 more variables: label.x <chr>, baseMean <dbl>, log2FoldChange <dbl>,
# #   lfcSE <dbl>, stat <dbl>, pvalue <dbl>, padj <dbl>, label.y <chr>,
# #   log2_sign <chr>
#
# $ratio_df
# # A tibble: 26 × 2
#    subclass              ratio
#    <fct>                 <dbl>
#  1 L2/3 IT CTX Glut      1.13
#  2 L4/5 IT CTX Glut      1.07
#  3 L5 IT CTX Glut        1.06
#  4 IT AON-TT-DP Glut     1.06
#  5 L2/3 IT RSP Glut      0.999
#  6 L5 ET CTX Glut        0.985
#  7 CA1-ProS Glut         1.10
#  8 CA3 Glut              1.13
#  9 CLA-EPd-CTX Car3 Glut 0.740
# 10 L5 NP CTX Glut        1.74
# # ℹ 16 more rows

# %%
result$ratio_df
# Out:
#    subclass              ratio
# 1  L2/3 IT CTX Glut      1.1291798
# 2  L4/5 IT CTX Glut      1.0724888
# 3  L5 IT CTX Glut        1.0575275
# 4  IT AON-TT-DP Glut     1.0614057
# 5  L2/3 IT RSP Glut      0.9994625
# 6  L5 ET CTX Glut        0.9849707
# 7  CA1-ProS Glut         1.1025872
# 8  CA3 Glut              1.1265610
# 9  CLA-EPd-CTX Car3 Glut 0.7396374
# 10 L5 NP CTX Glut        1.7399622
# 11 L6 CT CTX Glut        1.0940080
# 12 DG Glut               1.1622505
# 13 OB Eomes Ms4a15 Glut  1.2158557
# 14 OB-in Frmd7 Gaba      1.2517679
# 15 OB-out Frmd7 Gaba     1.0214842
# 16 Sncg Gaba             1.2829482
# 17 Lamp5 Gaba            1.0292306
# 18 Pvalb Gaba            1.3888378
# 19 STR D1 Gaba                  NA
# 20 STR D2 Gaba           1.1825956
# 21 STR D1 Sema5a Gaba    3.3566029
# 22 ACB-BST-FS D1 Gaba    1.1661247
# 23 Astro-TE NN           1.0782639
# 24 Oligo NN              1.0444700
# 25 OPC NN                1.1686514
# 26 OEC NN                2.2805836

# %%
write.csv(result$ratio_df,paste0(outdir,"/02-hmCG_subclass_Positive_vs_Negative_ratio.csv"),row.names=F)

# %%
options(repr.plot.width = 10, repr.plot.height = 12, repr.plot.res = 100)
boxplots_genebody
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# plot without title
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# plot without title
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# $hmCG
#
# $hmCH
#
# $mCG
#
# $mCH
# plot without title
# plot without title

# %%
pdf("../../../output/03-aging/06-ATAC/02-Genebody_boxplots_including_sig_5hmCG_total5mCG_update_t_test.pdf", width = 20, height = 10)
wrap_plots(boxplots_genebody[modifications], ncol = 2) %>%
  print()
dev.off()
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# png
#   2

# %%
boxplots_genebody <- list()

# %%
for (mod in modifications) {
  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>% 
    inner_join(old_young_gene_filter_genebody, by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {
    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    pvalues <- merged_data %>%
      group_by(subclass) %>%
      summarise(
        positive_count = sum(log2_sign == "Positive"),
        negative_count = sum(log2_sign == "Negative"),
        p_value = ifelse(positive_count > 1 & negative_count > 1,
                         wilcox.test(old_young_mean_ratio[log2_sign == "Positive"],
                                     old_young_mean_ratio[log2_sign == "Negative"])$p.value,
                         NA_real_),
        .groups = "drop"
      ) %>%
      mutate(label = ifelse(p_value < 0.001, "***",
                            ifelse(p_value < 0.01, "**",
                                   ifelse(p_value < 0.05, "*", "ns"))))

    y_min <- min(merged_data$old_young_mean_ratio, na.rm = TRUE) - 0.05
    y_max <- max(merged_data$old_young_mean_ratio, na.rm = TRUE) + 0.2

    p <- ggplot(merged_data, aes(x = subclass, y = old_young_mean_ratio, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, position = position_dodge(width = 0.8)) +
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      geom_hline(yintercept = 0, linetype = "dashed", color = "grey50", size = 0.8) +
      geom_text(data = pvalues, aes(x = subclass, y = y_max + 0.05, label = label),
                inherit.aes = FALSE, vjust = 0, size = 3) +
      labs(
        title = paste("Boxplot for", mod),
        x = "Subclass",
        y = "Old-Young Mean Ratio",
        fill = "Log2 Fold Change"
      ) +
      scale_y_continuous(
        limits = c(y_min, y_max),
        breaks = seq(-0.05, y_max, by = 0.05)
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 45, hjust = 1, color = "black"),
        axis.text.y = element_text(color = "black"),
        axis.line = element_line(color = "black", size = 0.8), 
        panel.grid = element_blank()
      )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
## 也可以
for (mod in modifications) {
  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>% 
    inner_join(old_young_gene_filter_genebody, by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {
    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    pvalues <- merged_data %>%
      group_by(subclass) %>%
      summarise(
        positive_count = sum(log2_sign == "Positive"),
        negative_count = sum(log2_sign == "Negative"),
        p_value = ifelse(positive_count > 1 & negative_count > 1,
                         wilcox.test(old_young_mean_ratio[log2_sign == "Positive"],
                                old_young_mean_ratio[log2_sign == "Negative"])$p.value,
                         NA_real_),
        .groups = "drop"
      ) %>%
      mutate(label = ifelse(p_value < 0.001, "***",
                            ifelse(p_value < 0.01, "**",
                                   ifelse(p_value < 0.05, "*", "ns"))))

    print(pvalues)

    p <- ggplot(merged_data, aes(x = subclass, y = old_young_mean_ratio, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, position = position_dodge(width = 0.8)) +
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      geom_hline(yintercept = 0, linetype = "dashed", color = "grey50", size = 0.8) +
      geom_text(data = pvalues, aes(x = subclass, y = max(merged_data$old_young_mean_ratio, na.rm = TRUE) + 0.2, label = label),
                inherit.aes = FALSE, vjust = 0, size = 3) +
      labs(
        title = paste("Boxplot for", mod),
        x = "Subclass",
        y = "Old-Young Mean Ratio",
        fill = "Log2 Fold Change"
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 45, hjust = 1, color = "black"),
        axis.text.y = element_text(color = "black"),
        axis.line = element_line(color = "black", size = 0.8), 
        panel.grid = element_blank()
      )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}
# Out:
# # A tibble: 26 × 5
#    subclass              positive_count negative_count   p_value label
#    <fct>                          <int>          <int>     <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.0348    *
#  2 L4/5 IT CTX Glut                 207            250 0.219     ns
#  3 L5 IT CTX Glut                   155             55 0.492     ns
#  4 IT AON-TT-DP Glut                353             71 0.425     ns
#  5 L2/3 IT RSP Glut                 177            158 0.521     ns
#  6 L5 ET CTX Glut                   160            121 0.508     ns
#  7 CA1-ProS Glut                    294            132 0.0287    *
#  8 CA3 Glut                         134             95 0.0163    *
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.0000226 ***
# 10 L5 NP CTX Glut                     2              7 0.889     ns
# # ℹ 16 more rows
# # A tibble: 26 × 5
#    subclass              positive_count negative_count p_value label
#    <fct>                          <int>          <int>   <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52  0.0516 ns
#  2 L4/5 IT CTX Glut                 207            250  0.314  ns
#  3 L5 IT CTX Glut                   155             55  0.131  ns
#  4 IT AON-TT-DP Glut                353             71  0.697  ns
#  5 L2/3 IT RSP Glut                 177            158  0.973  ns
#  6 L5 ET CTX Glut                   160            121  0.487  ns
#  7 CA1-ProS Glut                    294            132  0.0421 *
#  8 CA3 Glut                         134             95  0.0334 *
#  9 CLA-EPd-CTX Car3 Glut            155             97  0.946  ns
# 10 L5 NP CTX Glut                     2              7  0.667  ns
# # ℹ 16 more rows
# # A tibble: 26 × 5
#    subclass              positive_count negative_count       p_value label
#    <fct>                          <int>          <int>         <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.00000000693 ***
#  2 L4/5 IT CTX Glut                 207            250 0.00528       **
#  3 L5 IT CTX Glut                   155             55 0.00000355    ***
#  4 IT AON-TT-DP Glut                353             71 0.000495      ***
#  5 L2/3 IT RSP Glut                 177            158 0.00185       **
#  6 L5 ET CTX Glut                   160            121 0.00945       **
#  7 CA1-ProS Glut                    294            132 0.0000000222  ***
#  8 CA3 Glut                         134             95 0.0141        *
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.214         ns
# 10 L5 NP CTX Glut                     2              7 0.889         ns
# # ℹ 16 more rows
# # A tibble: 26 × 5
#    subclass              positive_count negative_count p_value label
#    <fct>                          <int>          <int>   <dbl> <chr>
#  1 L2/3 IT CTX Glut                 200             52 0.00155 **
#  2 L4/5 IT CTX Glut                 207            250 0.685   ns
#  3 L5 IT CTX Glut                   155             55 0.0121  *
#  4 IT AON-TT-DP Glut                353             71 0.00294 **
#  5 L2/3 IT RSP Glut                 177            158 0.00176 **
#  6 L5 ET CTX Glut                   160            121 0.0106  *
#  7 CA1-ProS Glut                    294            132 0.832   ns
#  8 CA3 Glut                         134             95 0.230   ns
#  9 CLA-EPd-CTX Car3 Glut            155             97 0.201   ns
# 10 L5 NP CTX Glut                     2              7 0.5     ns
# # ℹ 16 more rows

# %%
options(repr.plot.width = 10, repr.plot.height = 12, repr.plot.res = 100)
boxplots_genebody
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# plot without title
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# plot without title
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# $hmCG
#
# $hmCH
#
# $mCG
#
# $mCH
# plot without title
# plot without title

# %%
pdf("../../../output/03-aging/06-ATAC/02-Genebody_boxplots_including_sig_5hmCG_total5mCG_update_wilcox_test.pdf", width = 20, height = 10)
wrap_plots(boxplots_genebody[modifications], ncol = 2) %>%
  print()
dev.off()
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_text()`).”
# Warning message:
# “Removed 26 rows containing missing values or values outside the scale range (`geom_text()`).”
# png
#   2

# %%
## 后面不运行

# %%
lineplots_genebody <- list()

# %%
for (mod in modifications) {

  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>%
    inner_join(old_young_gene_filter_genebody, 
               by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {

    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    mean_data <- merged_data %>%
      group_by(subclass, log2_sign) %>%
      summarise(
        mean_value = mean(old_young_mean_ratio, na.rm = TRUE),
        .groups = "drop"
      )

    p <- ggplot(mean_data, aes(x = subclass, y = mean_value, color = log2_sign, group = log2_sign)) +
      geom_line(size = 1.2) +
      geom_point(size = 3) +
      scale_color_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      labs(
        title = paste("Mean Old-Young Ratio for Positive and Negative Across Subclasses -", mod),
        x = "Subclass",
        y = "Mean Old-Young Mean Ratio",
        color = "Log2 Fold Change"
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 45, hjust = 1, color = "black"),
        axis.text.y = element_text(color = "black"),
        axis.line = element_line(color = "black", size = 0.8), 
        panel.grid = element_blank()
      )

    lineplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
options(repr.plot.width = 10, repr.plot.height = 12, repr.plot.res = 100)
lineplots_genebody
# Out:
# plot without title
# plot without title
# $hmCG
#
# $hmCH
#
# $mCG
#
# $mCH
# plot without title
# plot without title

# %%
pdf("../../../output/03-aging/06-ATAC/02-Genebody_lineplots_5hmCG_total5mCG.pdf", width = 20, height = 10)
wrap_plots(lineplots_genebody[modifications], ncol = 2) %>%
  print()
dev.off()
# Out:
# png
#   2

# %%
library(ggpubr)
# Out:
# Warning message:
# “package ‘ggpubr’ was built under R version 4.3.3”

# %%
boxplots_genebody <- list()

# %%
for (mod in modifications) {

  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>%
    inner_join(old_young_gene_filter_genebody, 
               by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {

    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    mean_data <- merged_data %>%
      group_by(subclass, log2_sign) %>%
      summarise(
        mean_value = mean(old_young_mean_ratio, na.rm = TRUE),
        .groups = "drop"
      )

    p <- ggplot(mean_data, aes(x = log2_sign, y = mean_value, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, alpha = 0.7) + 
      geom_jitter(width = 0.2, size = 1.5, alpha = 0.8) + 
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      labs(
        title = paste("Boxplot of Mean Old-Young Ratio by Log2 Sign -", mod),
        x = "Log2 Fold Change Sign",
        y = "Mean Old-Young Ratio"
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 0, hjust = 0.5, color = "black"),
        axis.text.y = element_text(color = "black"),
        legend.position = "none"
      )

    p <- p + stat_compare_means(
      method = "t.test",
      label = "p.signif",
      comparisons = list(c("Positive", "Negative"))
    )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
print(boxplots_genebody[[1]])
# Out:
# plot without title

# %%
print(boxplots_genebody[[2]])
# Out:
# plot without title

# %%
modifications
# Out:
# [1] "hmCG" "hmCH" "mCG"  "mCH"

# %%
print(boxplots_genebody[[3]])
# Out:
# plot without title

# %%
print(boxplots_genebody[[4]])
# Out:
# plot without title

# %%
boxplots_genebody <- list()

# %%
for (mod in modifications) {

  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>%
    inner_join(old_young_gene_filter_genebody, 
               by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {

    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    mean_data <- merged_data %>%
      group_by(subclass, log2_sign) %>%
      summarise(
        mean_value = mean(old_young_mean_ratio, na.rm = TRUE),
        .groups = "drop"
      )

    p <- ggplot(mean_data, aes(x = log2_sign, y = mean_value, fill = log2_sign)) +
      geom_boxplot(outlier.shape = NA, alpha = 0.7) +
      geom_jitter(width = 0.2, size = 1.5, alpha = 0.8) +
      scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
      labs(
        title = paste("Boxplot of Mean Old-Young Ratio by Log2 Sign -", mod),
        x = "Log2 Fold Change Sign",
        y = "Mean Old-Young Ratio"
      ) +
      theme_minimal() +
      theme(
        plot.title = element_text(hjust = 0.5),
        axis.title = element_text(size = 14),
        axis.text.x = element_text(angle = 0, hjust = 0.5, color = "black"),
        axis.text.y = element_text(color = "black"),
        legend.position = "none"
      )

    p <- p + stat_compare_means(
      method = "wilcox.test",
      label = "p.signif",
      comparisons = list(c("Positive", "Negative"))
    )

    boxplots_genebody[[mod]] <- p
  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
print(boxplots_genebody[[1]])
# Out:
# plot without title

# %%
print(boxplots_genebody[[2]])
# Out:
# plot without title

# %%
print(boxplots_genebody[[3]])
# Out:
# plot without title

# %%
print(boxplots_genebody[[4]])
# Out:
# plot without title

# %%
all_mean_data <- data.frame()

# %%
for (mod in modifications) {

  current_data <- split_data_genebody[[mod]]

  merged_data <- current_data %>%
    inner_join(old_young_gene_filter_genebody, 
               by = c("subclass" = "class", "gene_id" = "genename"))
  
  if (nrow(merged_data) > 0) {

    merged_data <- merged_data %>%
      mutate(
        log2_sign = ifelse(log2FoldChange > 0, "Positive", "Negative"),
        subclass = factor(subclass, levels = subclass_order)
      )

    mean_data <- merged_data %>%
      group_by(subclass, log2_sign) %>%
      summarise(
        mean_value = mean(old_young_mean_ratio, na.rm = TRUE),
        .groups = "drop"
      ) %>%
      mutate(modification = mod)

    all_mean_data <- bind_rows(all_mean_data, mean_data)

  } else {
    message(paste("No matching data for modification:", mod))
  }
}

# %%
options(repr.plot.width = 18, repr.plot.height = 5, repr.plot.res = 100)
if (nrow(all_mean_data) > 0) {
  p <- ggplot(all_mean_data, aes(x = log2_sign, y = mean_value, fill = log2_sign)) +
    geom_boxplot(outlier.shape = NA, alpha = 0.7) + 
    geom_jitter(width = 0.2, size = 1.5, alpha = 0.8) + 
    scale_fill_manual(values = c("Positive" = "tomato", "Negative" = "steelblue")) +
    facet_wrap(~ modification, scales = "free_y", ncol = 4) +
    labs(
      title = "",
      x = "Log2 Fold Change",
      y = "Mean Old-Young Ratio"
    ) +
    theme_minimal() +
    theme(
      plot.title = element_text(hjust = 0.5),
      axis.title = element_text(size = 14),
      axis.text.x = element_text(angle = 0, hjust = 0.5, color = "black"),
      axis.text.y = element_text(color = "black"),
      legend.position = "none",
      panel.border = element_rect(color = "black", size = 0.5, fill = NA),
      strip.background = element_rect(color = "black", fill = "white"),
      strip.text = element_text(size = 12, face = "bold")
    ) +
    stat_compare_means(
      method = "wilcox.test",
      label = "p.signif",
      comparisons = list(c("Positive", "Negative"))
    )
  
  print(p)
} else {
  message("No data available for plotting.")
}
# Out:
# plot without title

# %%
options(repr.plot.width = 18, repr.plot.height = 5, repr.plot.res = 100)
p
# Out:
# plot without title

# %%
pdf("../../../output/03-aging/06-ATAC/02-Genebody_boxplot_5hmC_total5mC_mean.pdf", width = 18, height = 5)
p
dev.off()
# Out:
# png
#   2
