# %%
library(dplyr)
library(tidyr)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.2”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
data <- read.csv("../output/05-5hmC_CG_chrom100k_subclass_mean_dat_final_with_compartment.csv", stringsAsFactors = FALSE,check.names = F)
head(data);dim(data)
# Out:
#   chrom100k L2/3 IT CTX Glut L4/5 IT CTX Glut L5 IT CTX Glut L6 IT CTX Glut
# 1 chr1_0    NA               NA               NA             NA
# 2 chr1_1    NA               NA               NA             NA
# 3 chr1_2    NA               NA               NA             NA
# 4 chr1_3    NA               NA               NA             NA
# 5 chr1_4    NA               NA               NA             NA
# 6 chr1_5    NA               NA               NA             NA
#   IT AON-TT-DP Glut LA-BLA-BMA-PA Glut L2/3 IT RSP Glut L4 RSP-ACA Glut
# 1 NA                NA                 NA               NA
# 2 NA                NA                 NA               NA
# 3 NA                NA                 NA               NA
# 4 NA                NA                 NA               NA
# 5 NA                NA                 NA               NA
# 6 NA                NA                 NA               NA
#   L5 ET CTX Glut ⋯ Lamp5 Gaba_compartment Pvalb Gaba_compartment
# 1 NA             ⋯
# 2 NA             ⋯
# 3 NA             ⋯
# 4 NA             ⋯
# 5 NA             ⋯
# 6 NA             ⋯
#   Sst Gaba_compartment STR D1 Gaba_compartment STR D2 Gaba_compartment
# 1
# 2
# 3
# 4
# 5
# 6
#   ACB-BST-FS D1 Gaba_compartment Astro-TE NN_compartment Oligo NN_compartment
# 1
# 2
# 3
# 4
# 5
# 6
#   OPC NN_compartment Microglia NN_compartment
# 1
# 2
# 3
# 4
# 5
# 6
# [1] 24639    62

# %%
table(data$`L2/3 IT CTX Glut_compartment`)
# Out:
#           A     B
#  1501 12032 11106

# %%
label_columns <- grep("_compartment$", names(data), value = TRUE)
label_columns
# Out:
#  [1] "L2/3 IT CTX Glut_compartment"      "L4/5 IT CTX Glut_compartment"
#  [3] "L5 IT CTX Glut_compartment"        "L6 IT CTX Glut_compartment"
#  [5] "IT AON-TT-DP Glut_compartment"     "LA-BLA-BMA-PA Glut_compartment"
#  [7] "L2/3 IT RSP Glut_compartment"      "L4 RSP-ACA Glut_compartment"
#  [9] "L5 ET CTX Glut_compartment"        "SUB-ProS Glut_compartment"
# [11] "CA1-ProS Glut_compartment"         "CA3 Glut_compartment"
# [13] "CLA-EPd-CTX Car3 Glut_compartment" "L5 NP CTX Glut_compartment"
# [15] "L6 CT CTX Glut_compartment"        "DG Glut_compartment"
# [17] "OB Eomes Ms4a15 Glut_compartment"  "OB-in Frmd7 Gaba_compartment"
# [19] "OB-out Frmd7 Gaba_compartment"     "Sncg Gaba_compartment"
# [21] "Lamp5 Gaba_compartment"            "Pvalb Gaba_compartment"
# [23] "Sst Gaba_compartment"              "STR D1 Gaba_compartment"
# [25] "STR D2 Gaba_compartment"           "ACB-BST-FS D1 Gaba_compartment"
# [27] "Astro-TE NN_compartment"           "Oligo NN_compartment"
# [29] "OPC NN_compartment"                "Microglia NN_compartment"

# %%
length(label_columns)
# Out:
# [1] 30

# %%
mean_results <- data.frame()

# %%
mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

for (label_col in label_columns) {

  main_col <- sub("_compartment$", "", label_col)

  if (main_col %in% names(data)) {

    mean_values <- data %>%
      filter(!is.na(.data[[label_col]])) %>%
      group_by(.data[[label_col]]) %>%
      summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
      pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

    A_mean <- mean_values[[paste0(main_col, "_A")]]
    B_mean <- mean_values[[paste0(main_col, "_B")]]

    subclass_results <- data.frame(
      Subclass = main_col,
      A_mean = A_mean,
      B_mean = B_mean,
      stringsAsFactors = FALSE
    )

    mean_results <- rbind(mean_results, subclass_results)
  } else {
    warning(paste("Main column not found for label column:", label_col))
  }
}
# Out:
# Warning message:
# “Use of .data in tidyselect expressions was deprecated in tidyselect 1.2.0.
# ℹ Please use `all_of(var)` (or `any_of(var)`) instead of `.data[[var]]`”

# %%
mean_results
# Out:
#    Subclass              A_mean     B_mean
# 1  L2/3 IT CTX Glut      0.25070752 0.24625194
# 2  L4/5 IT CTX Glut      0.25580284 0.23932260
# 3  L5 IT CTX Glut        0.28005857 0.25286792
# 4  L6 IT CTX Glut        0.27472511 0.23979805
# 5  IT AON-TT-DP Glut     0.27101129 0.25985911
# 6  LA-BLA-BMA-PA Glut    0.28180913 0.26936572
# 7  L2/3 IT RSP Glut      0.28809481 0.26075705
# 8  L4 RSP-ACA Glut       0.31134568 0.28760136
# 9  L5 ET CTX Glut        0.29359466 0.28768492
# 10 SUB-ProS Glut         0.25736366 0.24002498
# 11 CA1-ProS Glut         0.24535677 0.23344301
# 12 CA3 Glut              0.24728972 0.23043071
# 13 CLA-EPd-CTX Car3 Glut 0.26121840 0.24902849
# 14 L5 NP CTX Glut        0.29540169 0.25113156
# 15 L6 CT CTX Glut        0.24330857 0.23553908
# 16 DG Glut               0.18049581 0.17241296
# 17 OB Eomes Ms4a15 Glut  0.19934339 0.19231236
# 18 OB-in Frmd7 Gaba      0.15667899 0.16186643
# 19 OB-out Frmd7 Gaba     0.15701156 0.14857761
# 20 Sncg Gaba             0.22811751 0.23580781
# 21 Lamp5 Gaba            0.26640006 0.26187914
# 22 Pvalb Gaba            0.30983717 0.28083985
# 23 Sst Gaba              0.30734440 0.29457504
# 24 STR D1 Gaba           0.21603046 0.22250406
# 25 STR D2 Gaba           0.16108265 0.15698367
# 26 ACB-BST-FS D1 Gaba    0.26358125 0.26788138
# 27 Astro-TE NN           0.13583646 0.10839879
# 28 Oligo NN              0.10790145 0.10458517
# 29 OPC NN                0.07791230 0.06130722
# 30 Microglia NN          0.04126392 0.04280018

# %%
mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )

mean_results
# Out:
#    Subclass              A_mean     B_mean     logFC
# 1  L2/3 IT CTX Glut      0.25070752 0.24625194  0.02587019
# 2  L4/5 IT CTX Glut      0.25580284 0.23932260  0.09607563
# 3  L5 IT CTX Glut        0.28005857 0.25286792  0.14734452
# 4  L6 IT CTX Glut        0.27472511 0.23979805  0.19616884
# 5  IT AON-TT-DP Glut     0.27101129 0.25985911  0.06062331
# 6  LA-BLA-BMA-PA Glut    0.28180913 0.26936572  0.06515207
# 7  L2/3 IT RSP Glut      0.28809481 0.26075705  0.14383741
# 8  L4 RSP-ACA Glut       0.31134568 0.28760136  0.11444675
# 9  L5 ET CTX Glut        0.29359466 0.28768492  0.02933613
# 10 SUB-ProS Glut         0.25736366 0.24002498  0.10062376
# 11 CA1-ProS Glut         0.24535677 0.23344301  0.07181071
# 12 CA3 Glut              0.24728972 0.23043071  0.10186928
# 13 CLA-EPd-CTX Car3 Glut 0.26121840 0.24902849  0.06894573
# 14 L5 NP CTX Glut        0.29540169 0.25113156  0.23423471
# 15 L6 CT CTX Glut        0.24330857 0.23553908  0.04682070
# 16 DG Glut               0.18049581 0.17241296  0.06609717
# 17 OB Eomes Ms4a15 Glut  0.19934339 0.19231236  0.05180430
# 18 OB-in Frmd7 Gaba      0.15667899 0.16186643 -0.04699207
# 19 OB-out Frmd7 Gaba     0.15701156 0.14857761  0.07965401
# 20 Sncg Gaba             0.22811751 0.23580781 -0.04783430
# 21 Lamp5 Gaba            0.26640006 0.26187914  0.02469330
# 22 Pvalb Gaba            0.30983717 0.28083985  0.14176258
# 23 Sst Gaba              0.30734440 0.29457504  0.06122101
# 24 STR D1 Gaba           0.21603046 0.22250406 -0.04259695
# 25 STR D2 Gaba           0.16108265 0.15698367  0.03718664
# 26 ACB-BST-FS D1 Gaba    0.26358125 0.26788138 -0.02334660
# 27 Astro-TE NN           0.13583646 0.10839879  0.32552211
# 28 Oligo NN              0.10790145 0.10458517  0.04503596
# 29 OPC NN                0.07791230 0.06130722  0.34579412
# 30 Microglia NN          0.04126392 0.04280018 -0.05273583

# %%
# mean_results$diff <- mean_results$A_mean - mean_results$B_mean
# mean_results

# %%
subclass <- c('L2/3 IT CTX Glut','L4/5 IT CTX Glut','L5 IT CTX Glut','L6 IT CTX Glut','IT AON-TT-DP Glut','LA-BLA-BMA-PA Glut',
              'L2/3 IT RSP Glut','L4 RSP-ACA Glut','L5 ET CTX Glut','SUB-ProS Glut','CA1-ProS Glut','CA3 Glut','CLA-EPd-CTX Car3 Glut',
              'L5 NP CTX Glut','L6 CT CTX Glut','DG Glut','OB Eomes Ms4a15 Glut','OB-in Frmd7 Gaba','OB-out Frmd7 Gaba','Sncg Gaba',
              'Lamp5 Gaba','Pvalb Gaba','Sst Gaba','STR D1 Gaba','STR D2 Gaba','ACB-BST-FS D1 Gaba','Astro-TE NN','Oligo NN','OPC NN',
              'Microglia NN')

subclass
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "L6 IT CTX Glut"        "IT AON-TT-DP Glut"     "LA-BLA-BMA-PA Glut"
#  [7] "L2/3 IT RSP Glut"      "L4 RSP-ACA Glut"       "L5 ET CTX Glut"
# [10] "SUB-ProS Glut"         "CA1-ProS Glut"         "CA3 Glut"
# [13] "CLA-EPd-CTX Car3 Glut" "L5 NP CTX Glut"        "L6 CT CTX Glut"
# [16] "DG Glut"               "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"
# [19] "OB-out Frmd7 Gaba"     "Sncg Gaba"             "Lamp5 Gaba"
# [22] "Pvalb Gaba"            "Sst Gaba"              "STR D1 Gaba"
# [25] "STR D2 Gaba"           "ACB-BST-FS D1 Gaba"    "Astro-TE NN"
# [28] "Oligo NN"              "OPC NN"                "Microglia NN"

# %%
mean_results$Subclass <- factor(mean_results$Subclass, levels = subclass)

# %%
mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")

# %%
mean_results
# Out:
#    Subclass              A_mean     B_mean     logFC       color_flag
# 1  L2/3 IT CTX Glut      0.25070752 0.24625194  0.02587019 positive
# 2  L4/5 IT CTX Glut      0.25580284 0.23932260  0.09607563 positive
# 3  L5 IT CTX Glut        0.28005857 0.25286792  0.14734452 positive
# 4  L6 IT CTX Glut        0.27472511 0.23979805  0.19616884 positive
# 5  IT AON-TT-DP Glut     0.27101129 0.25985911  0.06062331 positive
# 6  LA-BLA-BMA-PA Glut    0.28180913 0.26936572  0.06515207 positive
# 7  L2/3 IT RSP Glut      0.28809481 0.26075705  0.14383741 positive
# 8  L4 RSP-ACA Glut       0.31134568 0.28760136  0.11444675 positive
# 9  L5 ET CTX Glut        0.29359466 0.28768492  0.02933613 positive
# 10 SUB-ProS Glut         0.25736366 0.24002498  0.10062376 positive
# 11 CA1-ProS Glut         0.24535677 0.23344301  0.07181071 positive
# 12 CA3 Glut              0.24728972 0.23043071  0.10186928 positive
# 13 CLA-EPd-CTX Car3 Glut 0.26121840 0.24902849  0.06894573 positive
# 14 L5 NP CTX Glut        0.29540169 0.25113156  0.23423471 positive
# 15 L6 CT CTX Glut        0.24330857 0.23553908  0.04682070 positive
# 16 DG Glut               0.18049581 0.17241296  0.06609717 positive
# 17 OB Eomes Ms4a15 Glut  0.19934339 0.19231236  0.05180430 positive
# 18 OB-in Frmd7 Gaba      0.15667899 0.16186643 -0.04699207 negative
# 19 OB-out Frmd7 Gaba     0.15701156 0.14857761  0.07965401 positive
# 20 Sncg Gaba             0.22811751 0.23580781 -0.04783430 negative
# 21 Lamp5 Gaba            0.26640006 0.26187914  0.02469330 positive
# 22 Pvalb Gaba            0.30983717 0.28083985  0.14176258 positive
# 23 Sst Gaba              0.30734440 0.29457504  0.06122101 positive
# 24 STR D1 Gaba           0.21603046 0.22250406 -0.04259695 negative
# 25 STR D2 Gaba           0.16108265 0.15698367  0.03718664 positive
# 26 ACB-BST-FS D1 Gaba    0.26358125 0.26788138 -0.02334660 negative
# 27 Astro-TE NN           0.13583646 0.10839879  0.32552211 positive
# 28 Oligo NN              0.10790145 0.10458517  0.04503596 positive
# 29 OPC NN                0.07791230 0.06130722  0.34579412 positive
# 30 Microglia NN          0.04126392 0.04280018 -0.05273583 negative

# %%
library(ggplot2)
library(scales)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.3.3”
# Warning message:
# “package ‘scales’ was built under R version 4.3.2”

# %%
options(repr.plot.width = 9, repr.plot.height = 5, repr.plot.res = 100)
ggplot(mean_results, aes(x = Subclass, y = logFC, fill = logFC > 0)) +
  geom_col() +
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
  theme_minimal(base_size = 15) +
  theme(
    panel.background = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5)
  ) +
  labs(x = "Subclass", y = "log2(A_mean / B_mean)", title = "5hmCG")
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 9, repr.plot.res = 100)
ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1, 
                                linetype = "solid"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = "5hmCG")
# Out:
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 9, repr.plot.res = 100)
ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = "5hmCG") + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))
# Out:
# Warning message:
# “The `size` argument of `element_line()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_col()`).”
# plot without title

# %%
plot_AB_diff1 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("../output/05-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",group), stringsAsFactors = FALSE, check.names = FALSE)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  

  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.1, 0.1),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_hmCG <- plot_AB_diff1("5hmC_CG","5hmCG")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_hmCG
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_col()`).”
# plot without title

# %%
plot_AB_diff2 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("../output/05-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",group), stringsAsFactors = FALSE, check.names = FALSE)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  

  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.01, 0.01),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_hmCH <- plot_AB_diff2("5hmC_CH","5hmCH")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_hmCH
# Out:
# plot without title

# %%
P_mCG <- plot_AB_diff1("5mC_CG","5mCG+5hmCG")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_mCG
# Out:
# plot without title

# %%
P_mCH <- plot_AB_diff2("5mC_CH","5mCH+5hmCH")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_mCH
# Out:
# plot without title

# %%
plot_AB_diff3 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("../output/05-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",group), stringsAsFactors = FALSE, check.names = FALSE)
  
  check_and_fix_first_column_name <- function(data) {
      if (is.na(names(data)[1]) || names(data)[1] == "") {
          names(data)[1] <- "chrom100k"
          print("第一列的列名为空，已更改为 'chrom100k'")
      } else {
          print("第一列的列名为: ", names(data)[1])
      }
      return(data)
  }
  
  data <- check_and_fix_first_column_name(data)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  
  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.1, 0.1),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_true5mC_CG <- plot_AB_diff3("true5mC_CG","5mCG")
# Out:
# [1] "第一列的列名为空，已更改为 'chrom100k'"

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_true5mC_CG
# Out:
# plot without title

# %%
plot_AB_diff4 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("../output/05-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",group), stringsAsFactors = FALSE, check.names = FALSE)
  
  check_and_fix_first_column_name <- function(data) {
      if (is.na(names(data)[1]) || names(data)[1] == "") {
          names(data)[1] <- "chrom100k"
          print("第一列的列名为空，已更改为 'chrom100k'")
      } else {
          print("第一列的列名为: ", names(data)[1])
      }
      return(data)
  }
  
  data <- check_and_fix_first_column_name(data)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  
  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.01, 0.01),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_true5mC_CH <- plot_AB_diff4("true5mC_CH","5mCH")
# Out:
# [1] "第一列的列名为空，已更改为 'chrom100k'"

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_true5mC_CH
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_col()`).”
# plot without title

# %%
library(gridExtra)
library(ggplot2)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
g1 <- arrangeGrob(P_hmCG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g2 <- arrangeGrob(P_true5mC_CG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g3 <- arrangeGrob(P_mCG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g4 <- arrangeGrob(P_hmCH, heights = unit(8, "inches"), widths = unit(7, "inches"))
g5 <- arrangeGrob(P_true5mC_CH, heights = unit(8, "inches"), widths = unit(7, "inches"))
g6 <- arrangeGrob(P_mCH, heights = unit(8, "inches"), widths = unit(7, "inches"))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_col()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_col()`).”

# %%
combined_plot <- arrangeGrob(g3, g1, g2, g6, g4, g5, ncol = 6, nrow = 1)

# %%
ggsave("../output/06-Subclass_AB_compartment_DNA_methyl_log2FC.pdf", combined_plot, width = 42, height = 8)
