# %%
library(dplyr)
library(tidyr)
# Out:
# Warning message:
# “程辑包‘dplyr’是用R版本4.3.2 来建造的”
#
# 载入程辑包：‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# "indir" is a custom input path, and "outdir" is a custom output path.
# indir=""
# outdir=""

# %%
data <- read.csv(paste0(indir,"/03-5hmC_CG_chrom100k_subclass_mean_dat_final_with_compartment.csv"), stringsAsFactors = FALSE,check.names = F)
head(data);dim(data)
# Out:
#   chrom100k L2/3 IT CTX Glut L4/5 IT CTX Glut L5 IT CTX Glut L2/3 IT RSP Glut
# 1 chr1_0    NA               NA               NA             NA
# 2 chr1_1    NA               NA               NA             NA
# 3 chr1_2    NA               NA               NA             NA
# 4 chr1_3    NA               NA               NA             NA
# 5 chr1_4    NA               NA               NA             NA
# 6 chr1_5    NA               NA               NA             NA
#   L4 RSP-ACA Glut L5 ET CTX Glut SUB-ProS Glut CA1-ProS Glut CA3 Glut ⋯
# 1 NA              NA             NA            NA            NA       ⋯
# 2 NA              NA             NA            NA            NA       ⋯
# 3 NA              NA             NA            NA            NA       ⋯
# 4 NA              NA             NA            NA            NA       ⋯
# 5 NA              NA             NA            NA            NA       ⋯
# 6 NA              NA             NA            NA            NA       ⋯
#   Lamp5 Gaba_compartment Pvalb Gaba_compartment Sst Gaba_compartment
# 1
# 2
# 3
# 4
# 5
# 6
#   STR D1 Gaba_compartment STR D2 Gaba_compartment
# 1
# 2
# 3
# 4
# 5
# 6
#   ACB-BST-FS D1 Gaba_compartment Astro-TE NN_compartment Oligo NN_compartment
# 1
# 2
# 3
# 4
# 5
# 6
#   OPC NN_compartment Microglia NN_compartment
# 1
# 2
# 3
# 4
# 5
# 6
# [1] 24639    60

# %%
table(data$`L2/3 IT CTX Glut_compartment`)
# Out:
#           A     B
#  1501 12032 11106

# %%
label_columns <- grep("_compartment$", names(data), value = TRUE)
label_columns
# Out:
#  [1] "L2/3 IT CTX Glut_compartment"      "L4/5 IT CTX Glut_compartment"
#  [3] "L5 IT CTX Glut_compartment"        "L2/3 IT RSP Glut_compartment"
#  [5] "L4 RSP-ACA Glut_compartment"       "L5 ET CTX Glut_compartment"
#  [7] "SUB-ProS Glut_compartment"         "CA1-ProS Glut_compartment"
#  [9] "CA3 Glut_compartment"              "CLA-EPd-CTX Car3 Glut_compartment"
# [11] "L5 NP CTX Glut_compartment"        "L6 CT CTX Glut_compartment"
# [13] "DG Glut_compartment"               "OB Eomes Ms4a15 Glut_compartment"
# [15] "OB-in Frmd7 Gaba_compartment"      "OB-out Frmd7 Gaba_compartment"
# [17] "OB Dopa-Gaba_compartment"          "OB-STR-CTX Inh IMN_compartment"
# [19] "Sncg Gaba_compartment"             "Lamp5 Gaba_compartment"
# [21] "Pvalb Gaba_compartment"            "Sst Gaba_compartment"
# [23] "STR D1 Gaba_compartment"           "STR D2 Gaba_compartment"
# [25] "ACB-BST-FS D1 Gaba_compartment"    "Astro-TE NN_compartment"
# [27] "Oligo NN_compartment"              "OPC NN_compartment"
# [29] "Microglia NN_compartment"

# %%
length(label_columns)
# Out:
# [1] 29

# %%
mean_results <- data.frame()

# %%
mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

for (label_col in label_columns) {

  main_col <- sub("_compartment$", "", label_col)

  if (main_col %in% names(data)) {

    mean_values <- data %>%
      filter(!is.na(.data[[label_col]])) %>%
      group_by(.data[[label_col]]) %>%
      summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
      pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

    A_mean <- mean_values[[paste0(main_col, "_A")]]
    B_mean <- mean_values[[paste0(main_col, "_B")]]

    subclass_results <- data.frame(
      Subclass = main_col,
      A_mean = A_mean,
      B_mean = B_mean,
      stringsAsFactors = FALSE
    )

    mean_results <- rbind(mean_results, subclass_results)
  } else {
    warning(paste("Main column not found for label column:", label_col))
  }
}
# Out:
# Warning message:
# “Use of .data in tidyselect expressions was deprecated in tidyselect 1.2.0.
# ℹ Please use `all_of(var)` (or `any_of(var)`) instead of `.data[[var]]`”

# %%
mean_results
# Out:
#    Subclass              A_mean     B_mean
# 1  L2/3 IT CTX Glut      0.25583359 0.25101428
# 2  L4/5 IT CTX Glut      0.25418486 0.23761872
# 3  L5 IT CTX Glut        0.27981829 0.25258462
# 4  L2/3 IT RSP Glut      0.28369207 0.25610792
# 5  L4 RSP-ACA Glut       0.30476724 0.28112498
# 6  L5 ET CTX Glut        0.29060479 0.28464085
# 7  SUB-ProS Glut         0.27000429 0.25170588
# 8  CA1-ProS Glut         0.23956269 0.22802431
# 9  CA3 Glut              0.24748933 0.23050754
# 10 CLA-EPd-CTX Car3 Glut 0.26072658 0.24859504
# 11 L5 NP CTX Glut        0.30671055 0.25963881
# 12 L6 CT CTX Glut        0.24334140 0.23556704
# 13 DG Glut               0.18226939 0.17415761
# 14 OB Eomes Ms4a15 Glut  0.21754107 0.20937217
# 15 OB-in Frmd7 Gaba      0.15648110 0.16165327
# 16 OB-out Frmd7 Gaba     0.13747772 0.12906540
# 17 OB Dopa-Gaba          0.18696525 0.16748345
# 18 OB-STR-CTX Inh IMN    0.15126130 0.15980359
# 19 Sncg Gaba             0.26735649 0.27673262
# 20 Lamp5 Gaba            0.26624830 0.26169930
# 21 Pvalb Gaba            0.31146295 0.28224373
# 22 Sst Gaba              0.30999772 0.29730669
# 23 STR D1 Gaba           0.21587360 0.22235737
# 24 STR D2 Gaba           0.15961397 0.15495790
# 25 ACB-BST-FS D1 Gaba    0.26576453 0.26991762
# 26 Astro-TE NN           0.13358874 0.10599385
# 27 Oligo NN              0.10437521 0.10104059
# 28 OPC NN                0.07576049 0.05922033
# 29 Microglia NN          0.04217300 0.04372975

# %%
mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )

mean_results
# Out:
#    Subclass              A_mean     B_mean     logFC
# 1  L2/3 IT CTX Glut      0.25583359 0.25101428  0.02743624
# 2  L4/5 IT CTX Glut      0.25418486 0.23761872  0.09722956
# 3  L5 IT CTX Glut        0.27981829 0.25258462  0.14772349
# 4  L2/3 IT RSP Glut      0.28369207 0.25610792  0.14757394
# 5  L4 RSP-ACA Glut       0.30476724 0.28112498  0.11649619
# 6  L5 ET CTX Glut        0.29060479 0.28464085  0.02991574
# 7  SUB-ProS Glut         0.27000429 0.25170588  0.10124343
# 8  CA1-ProS Glut         0.23956269 0.22802431  0.07121561
# 9  CA3 Glut              0.24748933 0.23050754  0.10255233
# 10 CLA-EPd-CTX Car3 Glut 0.26072658 0.24859504  0.06874014
# 11 L5 NP CTX Glut        0.30671055 0.25963881  0.24037178
# 12 L6 CT CTX Glut        0.24334140 0.23556704  0.04684406
# 13 DG Glut               0.18226939 0.17415761  0.06567876
# 14 OB Eomes Ms4a15 Glut  0.21754107 0.20937217  0.05521806
# 15 OB-in Frmd7 Gaba      0.15648110 0.16165327 -0.04691426
# 16 OB-out Frmd7 Gaba     0.13747772 0.12906540  0.09109552
# 17 OB Dopa-Gaba          0.18696525 0.16748345  0.15875162
# 18 OB-STR-CTX Inh IMN    0.15126130 0.15980359 -0.07925694
# 19 Sncg Gaba             0.26735649 0.27673262 -0.04972799
# 20 Lamp5 Gaba            0.26624830 0.26169930  0.02486228
# 21 Pvalb Gaba            0.31146295 0.28224373  0.14211899
# 22 Sst Gaba              0.30999772 0.29730669  0.06030568
# 23 STR D1 Gaba           0.21587360 0.22235737 -0.04269337
# 24 STR D2 Gaba           0.15961397 0.15495790  0.04271062
# 25 ACB-BST-FS D1 Gaba    0.26576453 0.26991762 -0.02237062
# 26 Astro-TE NN           0.13358874 0.10599385  0.33381789
# 27 Oligo NN              0.10437521 0.10104059  0.04684411
# 28 OPC NN                0.07576049 0.05922033  0.35535322
# 29 Microglia NN          0.04217300 0.04372975 -0.05229525

# %%
# mean_results$diff <- mean_results$A_mean - mean_results$B_mean
# mean_results

# %%
subclass <- c('L2/3 IT CTX Glut','L4/5 IT CTX Glut','L5 IT CTX Glut','L2/3 IT RSP Glut','L4 RSP-ACA Glut','L5 ET CTX Glut','SUB-ProS Glut','CA1-ProS Glut','CA3 Glut',
           'CLA-EPd-CTX Car3 Glut','L5 NP CTX Glut','L6 CT CTX Glut','DG Glut','OB Eomes Ms4a15 Glut','OB-in Frmd7 Gaba','OB-out Frmd7 Gaba','OB Dopa-Gaba',
           'OB-STR-CTX Inh IMN','Sncg Gaba','Lamp5 Gaba','Pvalb Gaba','Sst Gaba','STR D1 Gaba','STR D2 Gaba','ACB-BST-FS D1 Gaba','Astro-TE NN','Oligo NN',
           'OPC NN','Microglia NN')

subclass
# Out:
#  [1] "L2/3 IT CTX Glut"      "L4/5 IT CTX Glut"      "L5 IT CTX Glut"
#  [4] "L2/3 IT RSP Glut"      "L4 RSP-ACA Glut"       "L5 ET CTX Glut"
#  [7] "SUB-ProS Glut"         "CA1-ProS Glut"         "CA3 Glut"
# [10] "CLA-EPd-CTX Car3 Glut" "L5 NP CTX Glut"        "L6 CT CTX Glut"
# [13] "DG Glut"               "OB Eomes Ms4a15 Glut"  "OB-in Frmd7 Gaba"
# [16] "OB-out Frmd7 Gaba"     "OB Dopa-Gaba"          "OB-STR-CTX Inh IMN"
# [19] "Sncg Gaba"             "Lamp5 Gaba"            "Pvalb Gaba"
# [22] "Sst Gaba"              "STR D1 Gaba"           "STR D2 Gaba"
# [25] "ACB-BST-FS D1 Gaba"    "Astro-TE NN"           "Oligo NN"
# [28] "OPC NN"                "Microglia NN"

# %%
mean_results$Subclass <- factor(mean_results$Subclass, levels = subclass)

# %%
mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")

# %%
mean_results
# Out:
#    Subclass              A_mean     B_mean     logFC       color_flag
# 1  L2/3 IT CTX Glut      0.25583359 0.25101428  0.02743624 positive
# 2  L4/5 IT CTX Glut      0.25418486 0.23761872  0.09722956 positive
# 3  L5 IT CTX Glut        0.27981829 0.25258462  0.14772349 positive
# 4  L2/3 IT RSP Glut      0.28369207 0.25610792  0.14757394 positive
# 5  L4 RSP-ACA Glut       0.30476724 0.28112498  0.11649619 positive
# 6  L5 ET CTX Glut        0.29060479 0.28464085  0.02991574 positive
# 7  SUB-ProS Glut         0.27000429 0.25170588  0.10124343 positive
# 8  CA1-ProS Glut         0.23956269 0.22802431  0.07121561 positive
# 9  CA3 Glut              0.24748933 0.23050754  0.10255233 positive
# 10 CLA-EPd-CTX Car3 Glut 0.26072658 0.24859504  0.06874014 positive
# 11 L5 NP CTX Glut        0.30671055 0.25963881  0.24037178 positive
# 12 L6 CT CTX Glut        0.24334140 0.23556704  0.04684406 positive
# 13 DG Glut               0.18226939 0.17415761  0.06567876 positive
# 14 OB Eomes Ms4a15 Glut  0.21754107 0.20937217  0.05521806 positive
# 15 OB-in Frmd7 Gaba      0.15648110 0.16165327 -0.04691426 negative
# 16 OB-out Frmd7 Gaba     0.13747772 0.12906540  0.09109552 positive
# 17 OB Dopa-Gaba          0.18696525 0.16748345  0.15875162 positive
# 18 OB-STR-CTX Inh IMN    0.15126130 0.15980359 -0.07925694 negative
# 19 Sncg Gaba             0.26735649 0.27673262 -0.04972799 negative
# 20 Lamp5 Gaba            0.26624830 0.26169930  0.02486228 positive
# 21 Pvalb Gaba            0.31146295 0.28224373  0.14211899 positive
# 22 Sst Gaba              0.30999772 0.29730669  0.06030568 positive
# 23 STR D1 Gaba           0.21587360 0.22235737 -0.04269337 negative
# 24 STR D2 Gaba           0.15961397 0.15495790  0.04271062 positive
# 25 ACB-BST-FS D1 Gaba    0.26576453 0.26991762 -0.02237062 negative
# 26 Astro-TE NN           0.13358874 0.10599385  0.33381789 positive
# 27 Oligo NN              0.10437521 0.10104059  0.04684411 positive
# 28 OPC NN                0.07576049 0.05922033  0.35535322 positive
# 29 Microglia NN          0.04217300 0.04372975 -0.05229525 negative

# %%
library(ggplot2)
library(scales)
# Out:
# Warning message:
# “程辑包‘scales’是用R版本4.3.2 来建造的”

# %%
options(repr.plot.width = 9, repr.plot.height = 5, repr.plot.res = 100)
ggplot(mean_results, aes(x = Subclass, y = logFC, fill = logFC > 0)) +
  geom_col() +
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
  theme_minimal(base_size = 15) +
  theme(
    panel.background = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5)
  ) +
  labs(x = "Subclass", y = "log2(A_mean / B_mean)", title = "5hmCG")
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”
# plot without title

# %%
options(repr.plot.width = 5, repr.plot.height = 9, repr.plot.res = 100)
ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.border = element_rect(color = "black", fill = NA, size = 1, 
                                linetype = "solid"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = "5hmCG")
# Out:
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 9, repr.plot.res = 100)
ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = "5hmCG") + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_col()`).”
# plot without title

# %%
plot_AB_diff1 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("%s/03-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",indir,group), stringsAsFactors = FALSE, check.names = FALSE)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  

  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.1, 0.1),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_hmCG <- plot_AB_diff1("5hmC_CG","5hmCG")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_hmCG
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_col()`).”
# plot without title

# %%
plot_AB_diff2 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("%s/03-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",indir,group), stringsAsFactors = FALSE, check.names = FALSE)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  

  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.01, 0.01),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_hmCH <- plot_AB_diff2("5hmC_CH","5hmCH")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_hmCH
# Out:
# plot without title

# %%
P_mCG <- plot_AB_diff1("5mC_CG","5mCG+5hmCG")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_mCG
# Out:
# plot without title

# %%
P_mCH <- plot_AB_diff2("5mC_CH","5mCH+5hmCH")

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_mCH
# Out:
# plot without title

# %%
plot_AB_diff3 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("%s/03-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",indir,group), stringsAsFactors = FALSE, check.names = FALSE)
  
  check_and_fix_first_column_name <- function(data) {
      if (is.na(names(data)[1]) || names(data)[1] == "") {
          names(data)[1] <- "chrom100k"
          print("第一列的列名为空，已更改为 'chrom100k'")
      } else {
          print("第一列的列名为: ", names(data)[1])
      }
      return(data)
  }
  
  data <- check_and_fix_first_column_name(data)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  
  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.1, 0.1),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_true5mC_CG <- plot_AB_diff3("true5mC_CG","5mCG")
# Out:
# [1] "第一列的列名为空，已更改为 'chrom100k'"

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_true5mC_CG
# Out:
# plot without title

# %%
plot_AB_diff4 <- function(group,label) { # "5hmC_CG","5hmCG"

  data <- read.csv(sprintf("%s/03-%s_chrom100k_subclass_mean_dat_final_with_compartment.csv",indir,group), stringsAsFactors = FALSE, check.names = FALSE)
  
  check_and_fix_first_column_name <- function(data) {
      if (is.na(names(data)[1]) || names(data)[1] == "") {
          names(data)[1] <- "chrom100k"
          print("第一列的列名为空，已更改为 'chrom100k'")
      } else {
          print("第一列的列名为: ", names(data)[1])
      }
      return(data)
  }
  
  data <- check_and_fix_first_column_name(data)
  
  label_columns <- grep("_compartment$", names(data), value = TRUE)

  mean_results <- data.frame(Subclass = character(), A_mean = numeric(), B_mean = numeric(), stringsAsFactors = FALSE)

  for (label_col in label_columns) {

    main_col <- sub("_compartment$", "", label_col)
    
    if (main_col %in% names(data)) {

      mean_values <- data %>%
        filter(!is.na(.data[[label_col]])) %>%
        group_by(.data[[label_col]]) %>%
        summarise(mean_value = mean(.data[[main_col]], na.rm = TRUE), .groups = 'drop') %>%
        pivot_wider(names_from = .data[[label_col]], values_from = mean_value, names_prefix = paste0(main_col, "_"))

      A_mean <- mean_values[[paste0(main_col, "_A")]]
      B_mean <- mean_values[[paste0(main_col, "_B")]]

      subclass_results <- data.frame(
        Subclass = main_col,
        A_mean = A_mean,
        B_mean = B_mean,
        stringsAsFactors = FALSE
      )

      mean_results <- rbind(mean_results, subclass_results)
      
    } else {
      warning(paste("Main column not found for label column:", label_col))
    }
  }
  
#   mean_results$diff <- mean_results$A_mean - mean_results$B_mean
  mean_results <- mean_results %>%
  mutate(
    logFC = log2(A_mean / B_mean)
  )
  mean_results$Subclass <- factor(mean_results$Subclass, levels = rev(subclass))
  mean_results$color_flag <- ifelse(mean_results$logFC > 0, "positive", "negative")
  
  p1 <- ggplot(mean_results, aes(y = Subclass, x = logFC, fill = logFC > 0)) + 
  geom_col() + 
  scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
                    labels = c("FALSE" = "Negative", "TRUE" = "Positive")) + 
  theme_minimal(base_size = 15) + 
  theme(
    panel.background = element_blank(),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", size = 1),
    axis.line.y = element_blank(),
    axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
    axis.text.y = element_text(color = "black", size = 12),
    axis.title.x = element_text(color = "black", size = 14),
    axis.title.y = element_text(color = "black", size = 14),
    plot.title = element_text(size = 16, hjust = 0.5),
    axis.ticks.y = element_blank(),
    axis.ticks.x = element_line(color = "black")
  ) + 
  labs(x = "log2(A_mean / B_mean)", y = "Subclass", title = label) + 
  scale_x_continuous(breaks = c(-0.3, 0, 0.3), limits = c(-0.3, 0.3))

#   p1 <- ggplot(mean_results, aes(x = Subclass, y = diff, fill = diff > 0)) +
#   geom_col() +
#   scale_fill_manual(values = c("FALSE" = "#2077B5", "TRUE" = "#D7272A"), 
#                     labels = c("FALSE" = "Negative", "TRUE" = "Positive")) +
#   scale_y_continuous(limits = c(-0.01, 0.01),
#                      labels = function(x) format(x, nsmall = 0, scientific = FALSE)) +  # 不使用科学计数法
#   theme_minimal(base_size = 15) +
#   theme(
#     panel.background = element_blank(),
#     panel.border = element_rect(color = "black", fill = NA, size = 1),
#     panel.grid.major = element_blank(),
#     panel.grid.minor = element_blank(),
#     axis.text.x = element_text(angle = 45, hjust = 1, color = "black", size = 12),
#     axis.text.y = element_text(color = "black", size = 12),
#     axis.title.x = element_text(color = "black", size = 14),
#     axis.title.y = element_text(color = "black", size = 14),
#     plot.title = element_text(size = 16, hjust = 0.5)
#   ) +
#   labs(x = "Subclass", y = "Difference value (A-B)", title = label)
    
  return(p1)
}

# %%
P_true5mC_CH <- plot_AB_diff4("true5mC_CH","5mCH")
# Out:
# [1] "第一列的列名为空，已更改为 'chrom100k'"

# %%
options(repr.plot.width = 7, repr.plot.height = 8, repr.plot.res = 100)
P_true5mC_CH
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_col()`).”
# plot without title

# %%
library(gridExtra)
library(ggplot2)
# Out:
# 载入程辑包：‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
g1 <- arrangeGrob(P_hmCG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g2 <- arrangeGrob(P_true5mC_CG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g3 <- arrangeGrob(P_mCG, heights = unit(8, "inches"), widths = unit(7, "inches"))
g4 <- arrangeGrob(P_hmCH, heights = unit(8, "inches"), widths = unit(7, "inches"))
g5 <- arrangeGrob(P_true5mC_CH, heights = unit(8, "inches"), widths = unit(7, "inches"))
g6 <- arrangeGrob(P_mCH, heights = unit(8, "inches"), widths = unit(7, "inches"))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_col()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_col()`).”

# %%
combined_plot <- arrangeGrob(g3, g1, g2, g6, g4, g5, ncol = 6, nrow = 1)

# %%
ggsave("../../../output/01.Young_Mouse/05-AB_compartment/07-Subclass_AB_compartment_DNA_methyl_log2FC_20250207.pdf", combined_plot, width = 42, height = 8)
