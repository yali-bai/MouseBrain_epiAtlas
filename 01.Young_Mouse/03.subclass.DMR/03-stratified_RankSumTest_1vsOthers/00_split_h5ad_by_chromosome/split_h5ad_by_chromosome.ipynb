# %%
import anndata

# %%
import pandas as pd
import numpy as np

# %%
# "indir" is a custom input path, and "outdir" is a custom output path.
# indir=""
# outdir=""

# %%
adata_5mCG = anndata.read_h5ad(f'{indir}/5mCG_frac_segment_by_cell.h5ad')

# %%
adata_5hmCG = anndata.read_h5ad(f'{indir}/5hmCG_frac_segment_by_cell.h5ad')

# %%
adata_5mCG
# Out:
# AnnData object with n_obs × n_vars = 47712 × 2104791
#     var: 'chrom', 'end', 'start'

# %%
adata_5hmCG
# Out:
# AnnData object with n_obs × n_vars = 47712 × 1777377
#     var: 'chrom', 'end', 'start'

# %%
adata_5mCG.X
# Out:
# array([[nan, nan, nan, ..., nan, nan,  1.],
#        [nan, nan, nan, ...,  1., nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan,  1.,  1., ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
adata_5hmCG.X
# Out:
# array([[nan,  0., nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [ 0., nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan,  0.],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
adata_5mCG.obs_names
# Out:
# Index(['allc_P49_Male_240416Mouses_LeftHippo_EXP240421_TSO_joint5mC_plate5.CAATAGCC',
#        'allc_P49_Male_240416Mouses_LeftHippo_EXP240421_TSO_joint5mC_plate5.ATAACGCC',
#        'allc_P49_Male_240416Mouses_LeftHippo_EXP240421_TSO_joint5mC_plate5.CCTTCCAT',
#        'allc_P49_Male_240416Mouses_RightHippo_EXP240419_TSO_joint5mC_plate3.TCATCTCC',
#        'allc_P49_Male_240416Mouses_RightHippo_EXP240419_TSO_joint5mC_plate3.GACGTCAT',
#        'allc_P49_Male_240416Mouses_RightHippo_EXP240420_TSO_joint5mC_plate4.CTTGCTAG',
#        'allc_P49_Male_240416Mouses_RightHippo_EXP240419_TSO_joint5mC_plate3.TCGGATTC',
#        'allc_P49_Male_240416Mouses_LeftCortex_EXP240421_TSO_joint5mC_plate5.CTTCGGTT',
#        'allc_P49_Male_240416Mouses_LeftCortex_EXP240421_TSO_joint5mC_plate5.CTGTACCA',
#        'allc_P49_Male_240416Mouses_LeftCortex_EXP240420_TSO_joint5mC_plate4.GGCAAGTT',
#        ...
#        'allc_P56_Male_231204Mouse1_DeepCortex_EXP240104_TSO_joint5mC_plate71.AGCGAGAT',
# ...

# %%
adata_5mCG.var_names
# Out:
# Index(['chr1_3000826_3001630', 'chr1_3003225_3003583', 'chr1_3003720_3004531',
#        'chr1_3007429_3007581', 'chr1_3008544_3010494', 'chr1_3010819_3012306',
#        'chr1_3013931_3014700', 'chr1_3014973_3015985', 'chr1_3016706_3017737',
#        'chr1_3018491_3019022',
#        ...
#        'chr19_61316705_61317702', 'chr19_61317869_61318703',
#        'chr19_61319797_61320884', 'chr19_61321193_61321384',
#        'chr19_61321619_61322729', 'chr19_61323671_61324185',
#        'chr19_61325280_61325656', 'chr19_61326706_61327126',
#        'chr19_61330072_61330238', 'chr19_61330510_61331129'],
#       dtype='object', name='segment', length=2104791)

# %%
df_5mCG=adata_5mCG.to_df().T

# %%
df_5hmCG=adata_5hmCG.to_df().T

# %%
df_5mCG
# Out:
# cell                     allc_P49_Male_240416Mouses_LeftHippo_EXP240421_TSO_joint5mC_plate5.CAATAGCC  \
# segment
# chr1_3000826_3001630                                                   NaN
# chr1_3003225_3003583                                                   NaN
# chr1_3003720_3004531                                                   NaN
# chr1_3007429_3007581                                                   NaN
# chr1_3008544_3010494                                                   NaN
# ...                                                                    ...
# chr19_61323671_61324185                                                1.0
# chr19_61325280_61325656                                                NaN
# chr19_61326706_61327126                                                NaN
# chr19_61330072_61330238                                                NaN
# chr19_61330510_61331129                                                1.0
#
# ...

# %%
df_5hmCG
# Out:
# cell                     allc_P56_Male_231211Mouse1_Striatum_EXP231215_TSO_joint5hmC_plate34.GTCAGTCA  \
# segment
# chr1_3000826_3001630                                                   NaN
# chr1_3003225_3003380                                                   0.0
# chr1_3003720_3003899                                                   NaN
# chr1_3004529_3006188                                                   NaN
# chr1_3008544_3009073                                                   NaN
# ...                                                                    ...
# chr19_61326952_61328153                                                NaN
# chr19_61329595_61329910                                                1.0
# chr19_61329973_61330074                                                NaN
# chr19_61330083_61330182                                                NaN
# chr19_61330185_61331129                                                NaN
#
# ...

# %%
#空出点内存
del adata_5mCG

# %%
df_5mCG.index.str.startswith("chr1_")
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
df_5hmCG.index.str.startswith("chr1_")
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
df_5mCG

# %%
for chr_number in range(1,20,1):
    temp_df=df_5mCG[df_5mCG.index.str.startswith(f"chr{chr_number}_")]
    temp_adata = anndata.AnnData(temp_df.T)
    temp_adata.write(f'{outdir}/5mCG_frac_segment_by_cell_chr{chr_number}.h5ad')
    temp_df=df_5hmCG[df_5hmCG.index.str.startswith(f"chr{chr_number}_")]
    temp_adata = anndata.AnnData(temp_df.T)
    temp_adata.write(f'{outdir}/5hmCG_frac_segment_by_cell_chr{chr_number}.h5ad')

# %%
temp_adata
# Out:
# AnnData object with n_obs × n_vars = 155916 × 47712

# %%
# %%bash
# pwd
# Out:
# /share/home/renlh/analysis/TSO/DMR/05_read_h5ad
